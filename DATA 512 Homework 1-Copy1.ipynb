# %% [markdown]
# # Step 1: Data Acquisition

# %%
import pandas as pd
import matplotlib.pyplot as plt #Source https://www.geeksforgeeks.org/line-chart-in-matplotlib-python/
import datetime

# %% [markdown]
# **Note: The following cells are the professor's work unless specific lines are denoted otherwise**

# %%
# 
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests

# %% [markdown]
# LO: Added my UW email below, changed start and end dates

# %%
#########
#
#    CONSTANTS
#

# The REST API 'pageviews' URL - this is the common URL/endpoint for all 'pageviews' API requests
API_REQUEST_PAGEVIEWS_ENDPOINT = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'

# This is a parameterized string that specifies what kind of pageviews request we are going to make
# In this case it will be a 'per-article' based request. The string is a format string so that we can
# replace each parameter with an appropriate value before making the request
API_REQUEST_PER_ARTICLE_PARAMS = 'per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}'

# The Pageviews API asks that we not exceed 100 requests per second, we add a small delay to each request
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making a request to the Wikimedia API they ask that you include your email address which will allow them
# to contact you if something happens - such as - your code exceeding rate limits - or some other error 
REQUEST_HEADERS = {
    'User-Agent': '<obrienl@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

# This is just a list of English Wikipedia article titles that we can use for example requests
ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This template is used to map parameter values into the API_REQUST_PER_ARTICLE_PARAMS portion of an API request. The dictionary has a
# field/key for each of the required parameters. In the example, below, we only vary the article name, so the majority of the fields
# can stay constant for each request. Of course, these values *could* be changed if necessary.
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE = {
    "project":     "en.wikipedia.org",
    "access":      "desktop",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # start and end dates need to be set
    "end":         "2023093000"    # this is likely the wrong end date
}

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageviews_per_article(article_title = None, 
                                  endpoint_url = API_REQUEST_PAGEVIEWS_ENDPOINT, 
                                  endpoint_params = API_REQUEST_PER_ARTICLE_PARAMS, 
                                  request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE,
                                  headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['article'] = article_title

    if not request_template['article']:
        raise Exception("Must supply an article title to make a pageviews request.")

    # Titles are supposed to have spaces replaced with "_" and be URL encoded
    article_title_encoded = urllib.parse.quote(request_template['article'].replace(' ','_'))
    request_template['article'] = article_title_encoded
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# **end of direct copy of Prof's example**

# %% [markdown]
# ## Get List of Article Names

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %%
df_articles = pd.read_excel('thank_the_academy.AUG.2023.csv - debug.xlsx')
df_articles.describe()
# Out:
#                                      name  \
# count                                1358
# unique                               1358
# top     Everything Everywhere All at Once
# freq                                    1
#
#                                                       url
# count                                                1358
# unique                                               1358
# top     https://en.wikipedia.org/wiki/Everything_Every...
# freq                                                    1

# %%
article_names = df_articles['name']

# %% [markdown]
# ## Pull Monthly Desktop Access

# %% [markdown]
# References:
# - https://www.geeksforgeeks.org/append-to-json-file-using-python/#
# - Things I learned from example:
#     - the structure of the returned data from the API

# %% [markdown]
# **Note: I encountered an issue with the 583rd movie, "Victor/Victoria" that I was unable to resolve, so I removed it from the input file and called the new file "thank_the_academy.AUG.2023.csv - debug.xlsx"**

# %%
# Define articles dictionary
articles_data = {}

article_count = 0

# For each article
for title in article_names:
    
    # Get data from API for article
    article_views = request_pageviews_per_article(title)
    
    month_list = []
    
    # Modify the retrieved data -------------!!!!!!!!!!!! Got idea for this form of iterating from Prof example
    for month in article_views['items']:
        # Remove access key from each month's entry
        del month['access'] # learned from https://www.geeksforgeeks.org/python-ways-to-remove-a-key-from-dictionary/
        
        # Reconstruct list of months
        month_list.append(month)
        
        # Store in a dictionary of articles
        articles_data[title] = month_list
        
    article_count += 1
    print("------ Added {}: {} ----------".format(article_count,title))
        
# Save to JSON file - Reference: https://www.geeksforgeeks.org/writing-to-file-in-python/
my_file1 = open(r"academy_monthly_desktop_201507-202309.json", "w")
my_file1.write(json.dumps(articles_data, indent=4)) # !!!!!borrowed part of a line of code from Prof example
my_file1.close()
print("Done!")
# Out:
# ------ Added 1: Everything Everywhere All at Once ----------
# ------ Added 2: All Quiet on the Western Front (2022 film) ----------
# ------ Added 3: The Whale (2022 film) ----------
# ------ Added 4: Top Gun: Maverick ----------
# ------ Added 5: Black Panther: Wakanda Forever ----------
# ------ Added 6: Avatar: The Way of Water ----------
# ------ Added 7: Women Talking (film) ----------
# ------ Added 8: Guillermo del Toro's Pinocchio ----------
# ------ Added 9: Navalny (film) ----------
# ------ Added 10: The Elephant Whisperers ----------
# ------ Added 11: An Irish Goodbye ----------
# ------ Added 12: The Boy, the Mole, the Fox and the Horse (film) ----------
# ------ Added 13: RRR (film) ----------
# ------ Added 14: CODA (2021 film) ----------
# ------ Added 15: Dune (2021 film) ----------
# ------ Added 16: The Eyes of Tammy Faye (2021 film) ----------
# ------ Added 17: No Time to Die ----------
# ------ Added 18: The Windshield Wiper ----------
# ------ Added 19: The Long Goodbye (Riz Ahmed album) ----------
# ------ Added 20: The Queen of Basketball ----------
# ------ Added 21: Summer of Soul ----------
# ------ Added 22: Drive My Car (film) ----------
# ------ Added 23: Encanto ----------
# ------ Added 24: West Side Story (2021 film) ----------
# ------ Added 25: Belfast (film) ----------
# ------ Added 26: The Power of the Dog (film) ----------
# ------ Added 27: King Richard (film) ----------
# ------ Added 28: Cruella (film) ----------
# ------ Added 29: Nomadland (film) ----------
# ------ Added 30: The Father (2020 film) ----------
# ------ Added 31: Judas and the Black Messiah ----------
# ------ Added 32: Minari (film) ----------
# ------ Added 33: Mank ----------
# ------ Added 34: Sound of Metal ----------
# ------ Added 35: Ma Rainey's Black Bottom (film) ----------
# ------ Added 36: Promising Young Woman ----------
# ------ Added 37: Tenet (film) ----------
# ------ Added 38: Soul (2020 film) ----------
# ------ Added 39: Another Round (film) ----------
# ------ Added 40: My Octopus Teacher ----------
# ------ Added 41: Colette (2020 film) ----------
# ------ Added 42: If Anything Happens I Love You ----------
# ------ Added 43: Two Distant Strangers ----------
# ------ Added 44: Parasite (2019 film) ----------
# ------ Added 45: Ford v Ferrari ----------
# ------ Added 46: Learning to Skateboard in a Warzone (If You're a Girl) ----------
# ------ Added 47: The Neighbors' Window ----------
# ------ Added 48: Little Women (2019 film) ----------
# ------ Added 49: Marriage Story ----------
# ------ Added 50: Jojo Rabbit ----------
# ------ Added 51: Toy Story 4 ----------
# ------ Added 52: Joker (2019 film) ----------
# ------ Added 53: Once Upon a Time in Hollywood ----------
# ------ Added 54: 1917 (2019 film) ----------
# ------ Added 55: Judy (film) ----------
# ------ Added 56: Bombshell (2019 film) ----------
# ------ Added 57: Rocketman (film) ----------
# ------ Added 58: American Factory ----------
# ------ Added 59: Hair Love ----------
# ------ Added 60: Green Book (film) ----------
# ------ Added 61: Bohemian Rhapsody (film) ----------
# ------ Added 62: Roma (2018 film) ----------
# ------ Added 63: Black Panther (film) ----------
# ------ Added 64: The Favourite ----------
# ------ Added 65: A Star Is Born (2018 film) ----------
# ------ Added 66: Vice (2018 film) ----------
# ------ Added 67: BlacKkKlansman ----------
# ------ Added 68: First Man (film) ----------
# ------ Added 69: If Beale Street Could Talk (film) ----------
# ------ Added 70: Bao (film) ----------
# ------ Added 71: Free Solo ----------
# ------ Added 72: Period. End of Sentence. ----------
# ------ Added 73: Skin (2018 short film) ----------
# ------ Added 74: Spider-Man: Into the Spider-Verse ----------
# ------ Added 75: The Shape of Water ----------
# ------ Added 76: Dunkirk (2017 film) ----------
# ------ Added 77: Three Billboards Outside Ebbing, Missouri ----------
# ------ Added 78: Darkest Hour (film) ----------
# ------ Added 79: Blade Runner 2049 ----------
# ------ Added 80: Coco (2017 film) ----------
# ------ Added 81: Phantom Thread ----------
# ------ Added 82: Call Me by Your Name (film) ----------
# ------ Added 83: Get Out ----------
# ------ Added 84: I, Tonya ----------
# ------ Added 85: Dear Basketball ----------
# ------ Added 86: A Fantastic Woman ----------
# ------ Added 87: Heaven Is a Traffic Jam on the 405 ----------
# ------ Added 88: Icarus (2017 film) ----------
# ------ Added 89: The Silent Child ----------
# ------ Added 90: Flesh and Sand ----------
# ------ Added 91: Moonlight (2016 film) ----------
# ------ Added 92: La La Land (film) ----------
# ------ Added 93: Hacksaw Ridge ----------
# ------ Added 94: Manchester by the Sea (film) ----------
# ------ Added 95: Arrival (film) ----------
# ------ Added 96: Fences (film) ----------
# ------ Added 97: Fantastic Beasts and Where to Find Them (film) ----------
# ------ Added 98: The Jungle Book (2016 film) ----------
# ------ Added 99: O.J.: Made in America ----------
# ------ Added 100: Piper (film) ----------
# ------ Added 101: The Salesman (2016 film) ----------
# ------ Added 102: Sing (2016 Hungarian film) ----------
# ------ Added 103: Suicide Squad (2016 film) ----------
# ------ Added 104: The White Helmets (film) ----------
# ------ Added 105: Zootopia ----------
# ------ Added 106: Spotlight (film) ----------
# ------ Added 107: Mad Max: Fury Road ----------
# ------ Added 108: The Revenant (2015 film) ----------
# ------ Added 109: Bridge of Spies (film) ----------
# ------ Added 110: The Big Short (film) ----------
# ------ Added 111: The Danish Girl (film) ----------
# ------ Added 112: Room (2015 film) ----------
# ------ Added 113: The Hateful Eight ----------
# ------ Added 114: Ex Machina (film) ----------
# ------ Added 115: Inside Out (2015 film) ----------
# ------ Added 116: Amy (2015 film) ----------
# ------ Added 117: Bear Story ----------
# ------ Added 118: A Girl in the River: The Price of Forgiveness ----------
# ------ Added 119: Son of Saul ----------
# ------ Added 120: Spectre (2015 film) ----------
# ------ Added 121: Stutterer (film) ----------
# ------ Added 122: Birdman (film) ----------
# ------ Added 123: The Grand Budapest Hotel ----------
# ------ Added 124: Whiplash (2014 film) ----------
# ------ Added 125: The Imitation Game ----------
# ------ Added 126: American Sniper ----------
# ------ Added 127: Boyhood (2014 film) ----------
# ------ Added 128: Interstellar (film) ----------
# ------ Added 129: The Theory of Everything (2014 film) ----------
# ------ Added 130: Ida (film) ----------
# ------ Added 131: Selma (film) ----------
# ------ Added 132: Citizenfour ----------
# ------ Added 133: Big Hero 6 (film) ----------
# ------ Added 134: Crisis Hotline: Veterans Press 1 ----------
# ------ Added 135: The Phone Call (2013 film) ----------
# ------ Added 136: Still Alice ----------
# ------ Added 137: Feast (2014 film) ----------
# ------ Added 138: 12 Years a Slave (film) ----------
# ------ Added 139: Gravity (2013 film) ----------
# ------ Added 140: Dallas Buyers Club ----------
# ------ Added 141: Frozen (2013 film) ----------
# ------ Added 142: The Great Gatsby (2013 film) ----------
# ------ Added 143: Her (film) ----------
# ------ Added 144: Blue Jasmine ----------
# ------ Added 145: Mr Hublot ----------
# ------ Added 146: The Lady in Number 6 ----------
# ------ Added 147: Helium (film) ----------
# ------ Added 148: The Great Beauty ----------
# ------ Added 149: 20 Feet from Stardom ----------
# ------ Added 150: Argo (2012 film) ----------
# ------ Added 151: Life of Pi (film) ----------
# ------ Added 152: Les Misérables (2012 film) ----------
# ------ Added 153: Lincoln (film) ----------
# ------ Added 154: Django Unchained ----------
# ------ Added 155: Skyfall ----------
# ------ Added 156: Silver Linings Playbook ----------
# ------ Added 157: Zero Dark Thirty ----------
# ------ Added 158: Amour (2012 film) ----------
# ------ Added 159: Anna Karenina (2012 film) ----------
# ------ Added 160: Paperman ----------
# ------ Added 161: Brave (2012 film) ----------
# ------ Added 162: Searching for Sugar Man ----------
# ------ Added 163: Inocente ----------
# ------ Added 164: Curfew (2012 film) ----------
# ------ Added 165: The Artist (film) ----------
# ------ Added 166: Hugo (film) ----------
# ------ Added 167: The Iron Lady (film) ----------
# ------ Added 168: The Descendants ----------
# ------ Added 169: The Girl with the Dragon Tattoo (2011 film) ----------
# ------ Added 170: Midnight in Paris ----------
# ------ Added 171: The Help (film) ----------
# ------ Added 172: A Separation ----------
# ------ Added 173: The Fantastic Flying Books of Mr. Morris Lessmore ----------
# ------ Added 174: The Shore (2011 film) ----------
# ------ Added 175: Undefeated (2011 film) ----------
# ------ Added 176: The Muppets (film) ----------
# ------ Added 177: Saving Face (2012 film) ----------
# ------ Added 178: Beginners ----------
# ------ Added 179: Rango (2011 film) ----------
# ------ Added 180: The King's Speech ----------
# ------ Added 181: Inception ----------
# ------ Added 182: The Social Network ----------
# ------ Added 183: The Fighter ----------
# ------ Added 184: Toy Story 3 ----------
# ------ Added 185: Alice in Wonderland (2010 film) ----------
# ------ Added 186: Black Swan (film) ----------
# ------ Added 187: In a Better World ----------
# ------ Added 188: The Lost Thing ----------
# ------ Added 189: God of Love (film) ----------
# ------ Added 190: The Wolfman (2010 film) ----------
# ------ Added 191: Strangers No More ----------
# ------ Added 192: Inside Job (2010 film) ----------
# ------ Added 193: The Hurt Locker ----------
# ------ Added 194: Avatar (2009 film) ----------
# ------ Added 195: Precious (film) ----------
# ------ Added 196: Up (2009 film) ----------
# ------ Added 197: Crazy Heart ----------
# ------ Added 198: Inglourious Basterds ----------
# ------ Added 199: Star Trek (film) ----------
# ------ Added 200: The Young Victoria ----------
# ------ Added 201: The Blind Side (film) ----------
# ------ Added 202: Music by Prudence ----------
# ------ Added 203: The Secret in Their Eyes ----------
# ------ Added 204: The Cove (film) ----------
# ------ Added 205: The New Tenants ----------
# ------ Added 206: Logorama ----------
# ------ Added 207: Slumdog Millionaire ----------
# ------ Added 208: The Curious Case of Benjamin Button (film) ----------
# ------ Added 209: Milk (2008 American film) ----------
# ------ Added 210: The Dark Knight (film) ----------
# ------ Added 211: WALL-E ----------
# ------ Added 212: The Reader (2008 film) ----------
# ------ Added 213: The Duchess (film) ----------
# ------ Added 214: Departures (2008 film) ----------
# ------ Added 215: Vicky Cristina Barcelona ----------
# ------ Added 216: Smile Pinki ----------
# ------ Added 217: Man on Wire ----------
# ------ Added 218: Toyland (film) ----------
# ------ Added 219: La Maison en Petits Cubes ----------
# ------ Added 220: No Country for Old Men (film) ----------
# ------ Added 221: The Bourne Ultimatum (film) ----------
# ------ Added 222: There Will Be Blood ----------
# ------ Added 223: La Vie en rose (film) ----------
# ------ Added 224: Atonement (2007 film) ----------
# ------ Added 225: Michael Clayton (film) ----------
# ------ Added 226: Ratatouille (film) ----------
# ------ Added 227: Juno (film) ----------
# ------ Added 228: Sweeney Todd: The Demon Barber of Fleet Street (2007 film) ----------
# ------ Added 229: The Golden Compass (film) ----------
# ------ Added 230: Elizabeth: The Golden Age ----------
# ------ Added 231: Taxi to the Dark Side ----------
# ------ Added 232: Peter & the Wolf (2006 film) ----------
# ------ Added 233: Once (film) ----------
# ------ Added 234: Le Mozart des pickpockets ----------
# ------ Added 235: The Counterfeiters (2007 film) ----------
# ------ Added 236: Freeheld (2007 film) ----------
# ------ Added 237: The Departed ----------
# ------ Added 238: Pan's Labyrinth ----------
# ------ Added 239: Dreamgirls (film) ----------
# ------ Added 240: Little Miss Sunshine ----------
# ------ Added 241: An Inconvenient Truth ----------
# ------ Added 242: Babel (film) ----------
# ------ Added 243: The Queen (2006 film) ----------
# ------ Added 244: Letters from Iwo Jima ----------
# ------ Added 245: Pirates of the Caribbean: Dead Man's Chest ----------
# ------ Added 246: The Danish Poet ----------
# ------ Added 247: Happy Feet ----------
# ------ Added 248: The Last King of Scotland (film) ----------
# ------ Added 249: The Lives of Others ----------
# ------ Added 250: Marie Antoinette (2006 film) ----------
# ------ Added 251: West Bank Story ----------
# ------ Added 252: The Blood of Yingzhou District ----------
# ------ Added 253: Crash (2004 film) ----------
# ------ Added 254: Brokeback Mountain ----------
# ------ Added 255: Memoirs of a Geisha (film) ----------
# ------ Added 256: King Kong (2005 film) ----------
# ------ Added 257: Capote (film) ----------
# ------ Added 258: Walk the Line ----------
# ------ Added 259: The Constant Gardener (film) ----------
# ------ Added 260: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe ----------
# ------ Added 261: Hustle & Flow ----------
# ------ Added 262: Syriana ----------
# ------ Added 263: March of the Penguins ----------
# ------ Added 264: Six Shooter (film) ----------
# ------ Added 265: The Moon and the Son: An Imagined Conversation ----------
# ------ Added 266: A Note of Triumph: The Golden Age of Norman Corwin ----------
# ------ Added 267: Tsotsi ----------
# ------ Added 268: Wallace & Gromit: The Curse of the Were-Rabbit ----------
# ------ Added 269: Million Dollar Baby ----------
# ------ Added 270: The Aviator (2004 film) ----------
# ------ Added 271: Ray (film) ----------
# ------ Added 272: The Incredibles ----------
# ------ Added 273: Finding Neverland (film) ----------
# ------ Added 274: Sideways ----------
# ------ Added 275: Lemony Snicket's A Series of Unfortunate Events ----------
# ------ Added 276: Spider-Man 2 ----------
# ------ Added 277: Eternal Sunshine of the Spotless Mind ----------
# ------ Added 278: The Motorcycle Diaries (film) ----------
# ------ Added 279: The Sea Inside ----------
# ------ Added 280: Born into Brothels ----------
# ------ Added 281: Mighty Times: The Children's March ----------
# ------ Added 282: Wasp (2003 film) ----------
# ------ Added 283: Ryan (film) ----------
# ------ Added 284: The Lord of the Rings: The Return of the King ----------
# ------ Added 285: Master and Commander: The Far Side of the World ----------
# ------ Added 286: Mystic River (film) ----------
# ------ Added 287: Cold Mountain (film) ----------
# ------ Added 288: Lost in Translation (film) ----------
# ------ Added 289: Finding Nemo ----------
# ------ Added 290: The Barbarian Invasions ----------
# ------ Added 291: Two Soldiers (2003 film) ----------
# ------ Added 292: Monster (2003 film) ----------
# ------ Added 293: Harvie Krumpet ----------
# ------ Added 294: Chernobyl Heart ----------
# ------ Added 295: The Fog of War ----------
# ------ Added 296: Chicago (2002 film) ----------
# ------ Added 297: The Pianist (2002 film) ----------
# ------ Added 298: The Lord of the Rings: The Two Towers ----------
# ------ Added 299: Frida (film) ----------
# ------ Added 300: The Hours (film) ----------
# ------ Added 301: Road to Perdition ----------
# ------ Added 302: Adaptation (film) ----------
# ------ Added 303: Talk to Her ----------
# ------ Added 304: This Charming Man (film) ----------
# ------ Added 305: Spirited Away ----------
# ------ Added 306: Nowhere in Africa ----------
# ------ Added 307: The ChubbChubbs! ----------
# ------ Added 308: Twin Towers (film) ----------
# ------ Added 309: Bowling for Columbine ----------
# ------ Added 310: 8 Mile (film) ----------
# ------ Added 311: A Beautiful Mind (film) ----------
# ------ Added 312: The Lord of the Rings: The Fellowship of the Ring ----------
# ------ Added 313: Moulin Rouge! ----------
# ------ Added 314: Black Hawk Down (film) ----------
# ------ Added 315: Gosford Park ----------
# ------ Added 316: Monsters, Inc. ----------
# ------ Added 317: Pearl Harbor (film) ----------
# ------ Added 318: Iris (2001 film) ----------
# ------ Added 319: Shrek ----------
# ------ Added 320: Training Day ----------
# ------ Added 321: Monster's Ball ----------
# ------ Added 322: Thoth (film) ----------
# ------ Added 323: For the Birds (film) ----------
# ------ Added 324: No Man's Land (2001 film) ----------
# ------ Added 325: Murder on a Sunday Morning ----------
# ------ Added 326: The Accountant (2001 film) ----------
# ------ Added 327: Gladiator (2000 film) ----------
# ------ Added 328: Crouching Tiger, Hidden Dragon ----------
# ------ Added 329: Traffic (2000 film) ----------
# ------ Added 330: Erin Brockovich (film) ----------
# ------ Added 331: Almost Famous ----------
# ------ Added 332: Wonder Boys (film) ----------
# ------ Added 333: How the Grinch Stole Christmas (2000 film) ----------
# ------ Added 334: U-571 (film) ----------
# ------ Added 335: Pollock (film) ----------
# ------ Added 336: Father and Daughter (film) ----------
# ------ Added 337: Into the Arms of Strangers: Stories of the Kindertransport ----------
# ------ Added 338: Quiero ser (I want to be...) ----------
# ------ Added 339: Big Mama (film) ----------
# ------ Added 340: American Beauty (1999 film) ----------
# ------ Added 341: The Matrix ----------
# ------ Added 342: The Cider House Rules (film) ----------
# ------ Added 343: Topsy-Turvy ----------
# ------ Added 344: Sleepy Hollow (film) ----------
# ------ Added 345: Boys Don't Cry (1999 film) ----------
# ------ Added 346: Tarzan (1999 film) ----------
# ------ Added 347: One Day in September ----------
# ------ Added 348: The Red Violin ----------
# ------ Added 349: The Old Man and the Sea (1999 film) ----------
# ------ Added 350: My Mother Dreams the Satan's Disciples in New York ----------
# ------ Added 351: King Gimp ----------
# ------ Added 352: Girl, Interrupted (film) ----------
# ------ Added 353: All About My Mother ----------
# ------ Added 354: Shakespeare in Love ----------
# ------ Added 355: Saving Private Ryan ----------
# ------ Added 356: Life Is Beautiful ----------
# ------ Added 357: Elizabeth (film) ----------
# ------ Added 358: Gods and Monsters (film) ----------
# ------ Added 359: The Prince of Egypt ----------
# ------ Added 360: Affliction (1997 film) ----------
# ------ Added 361: What Dreams May Come (film) ----------
# ------ Added 362: The Personals: Improvisations on Romance in the Golden Years ----------
# ------ Added 363: The Last Days ----------
# ------ Added 364: Election Night (1998 film) ----------
# ------ Added 365: Bunny (1998 film) ----------
# ------ Added 366: Titanic (1997 film) ----------
# ------ Added 367: Good Will Hunting ----------
# ------ Added 368: L.A. Confidential (film) ----------
# ------ Added 369: As Good as It Gets ----------
# ------ Added 370: The Full Monty ----------
# ------ Added 371: Men in Black (1997 film) ----------
# ------ Added 372: Visas and Virtue ----------
# ------ Added 373: Character (film) ----------
# ------ Added 374: Geri's Game ----------
# ------ Added 375: A Story of Healing ----------
# ------ Added 376: The Long Way Home (1997 film) ----------
# ------ Added 377: The English Patient (film) ----------
# ------ Added 378: Fargo (1996 film) ----------
# ------ Added 379: Shine (film) ----------
# ------ Added 380: Evita (1996 film) ----------
# ------ Added 381: Jerry Maguire ----------
# ------ Added 382: Independence Day (1996 film) ----------
# ------ Added 383: Emma (1996 theatrical film) ----------
# ------ Added 384: Sling Blade (film) ----------
# ------ Added 385: The Ghost and the Darkness ----------
# ------ Added 386: Kolya ----------
# ------ Added 387: The Nutty Professor (1996 film) ----------
# ------ Added 388: Quest (1996 film) ----------
# ------ Added 389: When We Were Kings ----------
# ------ Added 390: Breathing Lessons: The Life and Work of Mark O'Brien ----------
# ------ Added 391: Dear Diary (1996 film) ----------
# ------ Added 392: Braveheart ----------
# ------ Added 393: Apollo 13 (film) ----------
# ------ Added 394: Pocahontas (1995 film) ----------
# ------ Added 395: The Usual Suspects ----------
# ------ Added 396: Restoration (1995 film) ----------
# ------ Added 397: Babe (film) ----------
# ------ Added 398: Sense and Sensibility (film) ----------
# ------ Added 399: Il Postino: The Postman ----------
# ------ Added 400: Dead Man Walking (film) ----------
# ------ Added 401: Leaving Las Vegas ----------
# ------ Added 402: Mighty Aphrodite ----------
# ------ Added 403: Anne Frank Remembered ----------
# ------ Added 404: A Close Shave ----------
# ------ Added 405: Lieberman in Love ----------
# ------ Added 406: One Survivor Remembers ----------
# ------ Added 407: Antonia's Line ----------
# ------ Added 408: Toy Story ----------
# ------ Added 409: Forrest Gump ----------
# ------ Added 410: The Lion King ----------
# ------ Added 411: Speed (1994 film) ----------
# ------ Added 412: Ed Wood (film) ----------
# ------ Added 413: Pulp Fiction ----------
# ------ Added 414: Bullets Over Broadway ----------
# ------ Added 415: The Madness of King George ----------
# ------ Added 416: Legends of the Fall ----------
# ------ Added 417: A Time for Justice ----------
# ------ Added 418: Franz Kafka's It's a Wonderful Life ----------
# ------ Added 419: Maya Lin: A Strong Clear Vision ----------
# ------ Added 420: Burnt by the Sun ----------
# ------ Added 421: Trevor (film) ----------
# ------ Added 422: The Adventures of Priscilla, Queen of the Desert ----------
# ------ Added 423: Bob's Birthday ----------
# ------ Added 424: Blue Sky (1994 film) ----------
# ------ Added 425: Schindler's List ----------
# ------ Added 426: The Piano ----------
# ------ Added 427: Jurassic Park (film) ----------
# ------ Added 428: Philadelphia (film) ----------
# ------ Added 429: The Fugitive (1993 film) ----------
# ------ Added 430: The Age of Innocence (1993 film) ----------
# ------ Added 431: The Wrong Trousers ----------
# ------ Added 432: Belle Epoque (film) ----------
# ------ Added 433: I Am a Promise: The Children of Stanton Elementary School ----------
# ------ Added 434: Mrs. Doubtfire ----------
# ------ Added 435: Schwarzfahrer ----------
# ------ Added 436: Defending Our Lives ----------
# ------ Added 437: Unforgiven ----------
# ------ Added 438: Howards End (film) ----------
# ------ Added 439: Bram Stoker's Dracula (1992 film) ----------
# ------ Added 440: Aladdin (1992 Disney film) ----------
# ------ Added 441: The Crying Game ----------
# ------ Added 442: Scent of a Woman (1992 film) ----------
# ------ Added 443: A River Runs Through It (film) ----------
# ------ Added 444: Indochine (film) ----------
# ------ Added 445: My Cousin Vinny ----------
# ------ Added 446: The Panama Deception ----------
# ------ Added 447: Educating Peter ----------
# ------ Added 448: The Last of the Mohicans (1992 film) ----------
# ------ Added 449: Death Becomes Her ----------
# ------ Added 450: Omnibus (film) ----------
# ------ Added 451: Mona Lisa Descending a Staircase ----------
# ------ Added 452: The Silence of the Lambs (film) ----------
# ------ Added 453: Terminator 2: Judgment Day ----------
# ------ Added 454: Bugsy ----------
# ------ Added 455: JFK (film) ----------
# ------ Added 456: Beauty and the Beast (1991 film) ----------
# ------ Added 457: Thelma & Louise ----------
# ------ Added 458: The Fisher King ----------
# ------ Added 459: In the Shadow of the Stars ----------
# ------ Added 460: Manipulation (film) ----------
# ------ Added 461: Mediterraneo ----------
# ------ Added 462: Session Man (film) ----------
# ------ Added 463: City Slickers ----------
# ------ Added 464: Deadly Deception: General Electric, Nuclear Weapons and Our Environment ----------
# ------ Added 465: Dances with Wolves ----------
# ------ Added 466: Dick Tracy (1990 film) ----------
# ------ Added 467: Ghost (1990 film) ----------
# ------ Added 468: Goodfellas ----------
# ------ Added 469: The Hunt for Red October (film) ----------
# ------ Added 470: Reversal of Fortune ----------
# ------ Added 471: Cyrano de Bergerac (1990 film) ----------
# ------ Added 472: American Dream (film) ----------
# ------ Added 473: Journey of Hope (film) ----------
# ------ Added 474: Days of Waiting: The Life & Art of Estelle Ishigo ----------
# ------ Added 475: Creature Comforts ----------
# ------ Added 476: The Lunch Date ----------
# ------ Added 477: Misery (film) ----------
# ------ Added 478: Total Recall (1990 film) ----------
# ------ Added 479: Driving Miss Daisy ----------
# ------ Added 480: Glory (1989 film) ----------
# ------ Added 481: Born on the Fourth of July (film) ----------
# ------ Added 482: My Left Foot ----------
# ------ Added 483: The Little Mermaid (1989 film) ----------
# ------ Added 484: Dead Poets Society ----------
# ------ Added 485: The Abyss ----------
# ------ Added 486: Indiana Jones and the Last Crusade ----------
# ------ Added 487: Henry V (1989 film) ----------
# ------ Added 488: The Johnstown Flood (1989 film) ----------
# ------ Added 489: Common Threads: Stories from the Quilt ----------
# ------ Added 490: Cinema Paradiso ----------
# ------ Added 491: Work Experience (film) ----------
# ------ Added 492: Batman (1989 film) ----------
# ------ Added 493: Balance (1989 film) ----------
# ------ Added 494: Rain Man ----------
# ------ Added 495: Dangerous Liaisons ----------
# ------ Added 496: Who Framed Roger Rabbit ----------
# ------ Added 497: Mississippi Burning ----------
# ------ Added 498: Working Girl ----------
# ------ Added 499: The Accidental Tourist (film) ----------
# ------ Added 500: A Fish Called Wanda ----------
# ------ Added 501: Pelle the Conqueror ----------
# ------ Added 502: The Accused (1988 film) ----------
# ------ Added 503: The Appointments of Dennis Jennings ----------
# ------ Added 504: Beetlejuice ----------
# ------ Added 505: Bird (1988 film) ----------
# ------ Added 506: Hôtel Terminus: The Life and Times of Klaus Barbie ----------
# ------ Added 507: The Milagro Beanfield War ----------
# ------ Added 508: Tin Toy ----------
# ------ Added 509: You Don't Have to Die ----------
# ------ Added 510: The Last Emperor ----------
# ------ Added 511: Moonstruck ----------
# ------ Added 512: The Untouchables (film) ----------
# ------ Added 513: Babette's Feast ----------
# ------ Added 514: Dirty Dancing ----------
# ------ Added 515: Harry and the Hendersons ----------
# ------ Added 516: Innerspace ----------
# ------ Added 517: The Man Who Planted Trees (film) ----------
# ------ Added 518: Ray's Male Heterosexual Dance Hall ----------
# ------ Added 519: The Ten-Year Lunch ----------
# ------ Added 520: Wall Street (1987 film) ----------
# ------ Added 521: Young at Heart (1987 film) ----------
# ------ Added 522: RoboCop ----------
# ------ Added 523: Platoon (film) ----------
# ------ Added 524: A Room with a View (1985 film) ----------
# ------ Added 525: Hannah and Her Sisters ----------
# ------ Added 526: Aliens (film) ----------
# ------ Added 527: The Mission (1986 film) ----------
# ------ Added 528: Children of a Lesser God (film) ----------
# ------ Added 529: The Color of Money ----------
# ------ Added 530: Top Gun ----------
# ------ Added 531: Round Midnight (film) ----------
# ------ Added 532: Artie Shaw: Time Is All You've Got ----------
# ------ Added 533: The Assault (1986 film) ----------
# ------ Added 534: Down and Out in America ----------
# ------ Added 535: The Fly (1986 film) ----------
# ------ Added 536: A Greek Tragedy ----------
# ------ Added 537: Precious Images ----------
# ------ Added 538: Women – for America, for the World ----------
# ------ Added 539: Out of Africa (film) ----------
# ------ Added 540: Witness (1985 film) ----------
# ------ Added 541: Cocoon (film) ----------
# ------ Added 542: Prizzi's Honor ----------
# ------ Added 543: Back to the Future ----------
# ------ Added 544: Kiss of the Spider Woman (film) ----------
# ------ Added 545: Ran (film) ----------
# ------ Added 546: The Official Story ----------
# ------ Added 547: The Trip to Bountiful ----------
# ------ Added 548: White Nights (1985 film) ----------
# ------ Added 549: Anna & Bella ----------
# ------ Added 550: Broken Rainbow (film) ----------
# ------ Added 551: Mask (1985 film) ----------
# ------ Added 552: Molly's Pilgrim ----------
# ------ Added 553: Witness to War: Dr. Charlie Clements ----------
# ------ Added 554: Amadeus (film) ----------
# ------ Added 555: The Killing Fields (film) ----------
# ------ Added 556: A Passage to India (film) ----------
# ------ Added 557: Places in the Heart ----------
# ------ Added 558: Indiana Jones and the Temple of Doom ----------
# ------ Added 559: Charade (1984 film) ----------
# ------ Added 560: Dangerous Moves ----------
# ------ Added 561: Purple Rain (film) ----------
# ------ Added 562: The Stone Carvers (film) ----------
# ------ Added 563: The Times of Harvey Milk ----------
# ------ Added 564: Up (1984 film) ----------
# ------ Added 565: The Woman in Red (1984 film) ----------
# ------ Added 566: The River (1984 film) ----------
# ------ Added 567: Terms of Endearment ----------
# ------ Added 568: The Right Stuff (film) ----------
# ------ Added 569: Fanny and Alexander ----------
# ------ Added 570: Tender Mercies ----------
# ------ Added 571: Yentl (film) ----------
# ------ Added 572: Flashdance ----------
# ------ Added 573: Boys and Girls (1983 film) ----------
# ------ Added 574: Flamenco at 5:15 ----------
# ------ Added 575: He Makes Me Feel Like Dancin' ----------
# ------ Added 576: Sundae in New York ----------
# ------ Added 577: The Year of Living Dangerously (film) ----------
# ------ Added 578: Return of the Jedi ----------
# ------ Added 579: Gandhi (film) ----------
# ------ Added 580: E.T. the Extra-Terrestrial ----------
# ------ Added 581: An Officer and a Gentleman ----------
# ------ Added 582: Tootsie ----------
# ------ Added 583: Sophie's Choice (film) ----------
# ------ Added 584: Missing (1982 film) ----------
# ------ Added 585: If You Love This Planet ----------
# ------ Added 586: Just Another Missing Kid ----------
# ------ Added 587: A Shocking Accident ----------
# ------ Added 588: Tango (1981 film) ----------
# ------ Added 589: Begin the Beguine (film) ----------
# ------ Added 590: Quest for Fire (film) ----------
# ------ Added 591: Chariots of Fire ----------
# ------ Added 592: Raiders of the Lost Ark ----------
# ------ Added 593: Reds (film) ----------
# ------ Added 594: On Golden Pond (1981 film) ----------
# ------ Added 595: Arthur (1981 film) ----------
# ------ Added 596: An American Werewolf in London ----------
# ------ Added 597: Close Harmony (1981 film) ----------
# ------ Added 598: Crac ----------
# ------ Added 599: Genocide (1981 film) ----------
# ------ Added 600: Mephisto (1981 film) ----------
# ------ Added 601: Violet (1981 film) ----------
# ------ Added 602: Ordinary People ----------
# ------ Added 603: Tess (1979 film) ----------
# ------ Added 604: Raging Bull ----------
# ------ Added 605: Fame (1980 film) ----------
# ------ Added 606: Melvin and Howard ----------
# ------ Added 607: Coal Miner's Daughter (film) ----------
# ------ Added 608: The Empire Strikes Back ----------
# ------ Added 609: The Dollar Bottom ----------
# ------ Added 610: The Fly (1980 film) ----------
# ------ Added 611: From Mao to Mozart: Isaac Stern in China ----------
# ------ Added 612: Karl Hess: Toward Liberty ----------
# ------ Added 613: Moscow Does Not Believe in Tears ----------
# ------ Added 614: Kramer vs. Kramer ----------
# ------ Added 615: All That Jazz (film) ----------
# ------ Added 616: Apocalypse Now ----------
# ------ Added 617: Norma Rae ----------
# ------ Added 618: Breaking Away ----------
# ------ Added 619: Alien (film) ----------
# ------ Added 620: Being There ----------
# ------ Added 621: A Little Romance ----------
# ------ Added 622: Best Boy (film) ----------
# ------ Added 623: Board and Care ----------
# ------ Added 624: Every Child (film) ----------
# ------ Added 625: Paul Robeson: Tribute to an Artist ----------
# ------ Added 626: The Tin Drum (film) ----------
# ------ Added 627: The Black Stallion (film) ----------
# ------ Added 628: The Deer Hunter ----------
# ------ Added 629: Coming Home (1978 film) ----------
# ------ Added 630: Midnight Express (film) ----------
# ------ Added 631: Heaven Can Wait (1978 film) ----------
# ------ Added 632: Days of Heaven ----------
# ------ Added 633: California Suite (film) ----------
# ------ Added 634: The Buddy Holly Story ----------
# ------ Added 635: Death on the Nile (1978 film) ----------
# ------ Added 636: The Flight of the Gossamer Condor ----------
# ------ Added 637: Get Out Your Handkerchiefs ----------
# ------ Added 638: Scared Straight! ----------
# ------ Added 639: Special Delivery (1978 film) ----------
# ------ Added 640: Teenage Father ----------
# ------ Added 641: Thank God It's Friday (film) ----------
# ------ Added 642: Superman (1978 film) ----------
# ------ Added 643: Annie Hall ----------
# ------ Added 644: Star Wars (film) ----------
# ------ Added 645: Julia (1977 film) ----------
# ------ Added 646: Close Encounters of the Third Kind ----------
# ------ Added 647: The Goodbye Girl ----------
# ------ Added 648: A Little Night Music (film) ----------
# ------ Added 649: Gravity Is My Enemy ----------
# ------ Added 650: I'll Find a Way ----------
# ------ Added 651: Madame Rosa ----------
# ------ Added 652: The Sand Castle (film) ----------
# ------ Added 653: Who Are the DeBolts? And Where Did They Get Nineteen Kids? ----------
# ------ Added 654: You Light Up My Life (film) ----------
# ------ Added 655: Rocky ----------
# ------ Added 656: Network (1976 film) ----------
# ------ Added 657: All the President's Men (film) ----------
# ------ Added 658: Bound for Glory (1976 film) ----------
# ------ Added 659: A Star Is Born (1976 film) ----------
# ------ Added 660: Fellini's Casanova ----------
# ------ Added 661: The Omen ----------
# ------ Added 662: Black and White in Color ----------
# ------ Added 663: Harlan County, USA ----------
# ------ Added 664: In the Region of Ice ----------
# ------ Added 665: Leisure (film) ----------
# ------ Added 666: Number Our Days ----------
# ------ Added 667: King Kong (1976 film) ----------
# ------ Added 668: Logan's Run (film) ----------
# ------ Added 669: One Flew Over the Cuckoo's Nest (film) ----------
# ------ Added 670: Barry Lyndon ----------
# ------ Added 671: Jaws (film) ----------
# ------ Added 672: Dog Day Afternoon ----------
# ------ Added 673: Nashville (film) ----------
# ------ Added 674: Shampoo (film) ----------
# ------ Added 675: The Sunshine Boys (1975 film) ----------
# ------ Added 676: Angel and Big Joe ----------
# ------ Added 677: Dersu Uzala (1975 film) ----------
# ------ Added 678: The End of the Game (1975 film) ----------
# ------ Added 679: Great (1975 film) ----------
# ------ Added 680: The Man Who Skied Down Everest ----------
# ------ Added 681: The Hindenburg (film) ----------
# ------ Added 682: The Godfather: Part II ----------
# ------ Added 683: The Towering Inferno ----------
# ------ Added 684: The Great Gatsby (1974 film) ----------
# ------ Added 685: Chinatown (1974 film) ----------
# ------ Added 686: Murder on the Orient Express (1974 film) ----------
# ------ Added 687: Earthquake (1974 film) ----------
# ------ Added 688: Alice Doesn't Live Here Anymore ----------
# ------ Added 689: Amarcord ----------
# ------ Added 690: Harry and Tonto ----------
# ------ Added 691: Closed Mondays ----------
# ------ Added 692: Don't (1974 film) ----------
# ------ Added 693: Hearts and Minds (film) ----------
# ------ Added 694: One-Eyed Men Are Kings ----------
# ------ Added 695: The Sting ----------
# ------ Added 696: The Exorcist (film) ----------
# ------ Added 697: The Way We Were ----------
# ------ Added 698: Cries and Whispers ----------
# ------ Added 699: A Touch of Class (film) ----------
# ------ Added 700: Day for Night (film) ----------
# ------ Added 701: Paper Moon (film) ----------
# ------ Added 702: The Paper Chase (film) ----------
# ------ Added 703: Save the Tiger ----------
# ------ Added 704: The Bolero ----------
# ------ Added 705: Frank Film ----------
# ------ Added 706: The Great American Cowboy ----------
# ------ Added 707: Princeton: A Search for Answers ----------
# ------ Added 708: The Godfather ----------
# ------ Added 709: Cabaret (1972 film) ----------
# ------ Added 710: The Poseidon Adventure (1972 film) ----------
# ------ Added 711: Travels with My Aunt (film) ----------
# ------ Added 712: Butterflies Are Free ----------
# ------ Added 713: The Candidate (1972 film) ----------
# ------ Added 714: The Discreet Charm of the Bourgeoisie ----------
# ------ Added 715: A Christmas Carol (1971 film) ----------
# ------ Added 716: Limelight (1952 film) ----------
# ------ Added 717: Marjoe ----------
# ------ Added 718: Norman Rockwell's World... An American Dream ----------
# ------ Added 719: This Tiny World ----------
# ------ Added 720: The French Connection (film) ----------
# ------ Added 721: Fiddler on the Roof (film) ----------
# ------ Added 722: The Last Picture Show ----------
# ------ Added 723: Nicholas and Alexandra ----------
# ------ Added 724: Sentinels of Silence ----------
# ------ Added 725: Bedknobs and Broomsticks ----------
# ------ Added 726: Summer of '42 ----------
# ------ Added 727: The Garden of the Finzi-Continis (film) ----------
# ------ Added 728: The Hospital ----------
# ------ Added 729: Klute ----------
# ------ Added 730: Shaft (1971 film) ----------
# ------ Added 731: The Crunch Bird ----------
# ------ Added 732: The Hellstrom Chronicle ----------
# ------ Added 733: Patton (film) ----------
# ------ Added 734: Ryan's Daughter ----------
# ------ Added 735: Airport (1970 film) ----------
# ------ Added 736: Love Story (1970 film) ----------
# ------ Added 737: MASH (film) ----------
# ------ Added 738: Tora! Tora! Tora! ----------
# ------ Added 739: Women in Love (film) ----------
# ------ Added 740: Lovers and Other Strangers ----------
# ------ Added 741: Woodstock (film) ----------
# ------ Added 742: Cromwell (film) ----------
# ------ Added 743: Investigation of a Citizen Above Suspicion ----------
# ------ Added 744: Interviews with My Lai Veterans ----------
# ------ Added 745: Is It Always Right to Be Right? ----------
# ------ Added 746: Let It Be (1970 film) ----------
# ------ Added 747: The Resurrection of Broncho Billy ----------
# ------ Added 748: Midnight Cowboy ----------
# ------ Added 749: Butch Cassidy and the Sundance Kid ----------
# ------ Added 750: Hello, Dolly! (film) ----------
# ------ Added 751: Z (1969 film) ----------
# ------ Added 752: Anne of the Thousand Days ----------
# ------ Added 753: They Shoot Horses, Don't They? (film) ----------
# ------ Added 754: Marooned (1969 film) ----------
# ------ Added 755: The Magic Machines ----------
# ------ Added 756: The Prime of Miss Jean Brodie (film) ----------
# ------ Added 757: True Grit (1969 film) ----------
# ------ Added 758: Arthur Rubinstein – The Love of Life ----------
# ------ Added 759: Cactus Flower (film) ----------
# ------ Added 760: Czechoslovakia 1968 ----------
# ------ Added 761: It's Tough to Be a Bird ----------
# ------ Added 762: Oliver! (film) ----------
# ------ Added 763: The Lion in Winter (1968 film) ----------
# ------ Added 764: Romeo and Juliet (1968 film) ----------
# ------ Added 765: Funny Girl (film) ----------
# ------ Added 766: 2001: A Space Odyssey (film) ----------
# ------ Added 767: Bullitt ----------
# ------ Added 768: The Producers (1967 film) ----------
# ------ Added 769: Rosemary's Baby (film) ----------
# ------ Added 770: The Subject Was Roses (film) ----------
# ------ Added 771: The Thomas Crown Affair (1968 film) ----------
# ------ Added 772: War and Peace (film series) ----------
# ------ Added 773: Charly ----------
# ------ Added 774: Journey into Self (1968 film) ----------
# ------ Added 775: Robert Kennedy Remembered ----------
# ------ Added 776: Why Man Creates ----------
# ------ Added 777: Winnie the Pooh and the Blustery Day ----------
# ------ Added 778: Planet of the Apes (1968 film) ----------
# ------ Added 779: In the Heat of the Night (film) ----------
# ------ Added 780: Camelot (film) ----------
# ------ Added 781: Bonnie and Clyde (film) ----------
# ------ Added 782: Guess Who's Coming to Dinner ----------
# ------ Added 783: Doctor Dolittle (1967 film) ----------
# ------ Added 784: The Graduate ----------
# ------ Added 785: Thoroughly Modern Millie ----------
# ------ Added 786: Cool Hand Luke ----------
# ------ Added 787: The Dirty Dozen ----------
# ------ Added 788: A Place to Stand (film) ----------
# ------ Added 789: The Anderson Platoon ----------
# ------ Added 790: The Box (1967 film) ----------
# ------ Added 791: Closely Watched Trains ----------
# ------ Added 792: The Redwoods ----------
# ------ Added 793: A Man for All Seasons (1966 film) ----------
# ------ Added 794: Who's Afraid of Virginia Woolf? (film) ----------
# ------ Added 795: Grand Prix (1966 film) ----------
# ------ Added 796: Fantastic Voyage ----------
# ------ Added 797: A Man and a Woman ----------
# ------ Added 798: Born Free ----------
# ------ Added 799: The Fortune Cookie ----------
# ------ Added 800: A Funny Thing Happened on the Way to the Forum (film) ----------
# ------ Added 801: A Herb Alpert and the Tijuana Brass Double Feature ----------
# ------ Added 802: The War Game ----------
# ------ Added 803: Wild Wings ----------
# ------ Added 804: A Year Toward Tomorrow ----------
# ------ Added 805: The Sound of Music (film) ----------
# ------ Added 806: Doctor Zhivago (film) ----------
# ------ Added 807: Darling (1965 film) ----------
# ------ Added 808: Ship of Fools (film) ----------
# ------ Added 809: Cat Ballou ----------
# ------ Added 810: The Great Race ----------
# ------ Added 811: A Patch of Blue ----------
# ------ Added 812: A Thousand Clowns ----------
# ------ Added 813: The Shop on Main Street ----------
# ------ Added 814: The Sandpiper ----------
# ------ Added 815: The Eleanor Roosevelt Story ----------
# ------ Added 816: To Be Alive! ----------
# ------ Added 817: 7 Faces of Dr. Lao ----------
# ------ Added 818: 7th Heaven (1927 film) ----------
# ------ Added 819: 20,000 Leagues Under the Sea (1954 film) ----------
# ------ Added 820: Adventures of Don Juan ----------
# ------ Added 821: The Adventures of Robin Hood ----------
# ------ Added 822: The African Queen (film) ----------
# ------ Added 823: Air Force (film) ----------
# ------ Added 824: The Alamo (1960 film) ----------
# ------ Added 825: The Alaskan Eskimo ----------
# ------ Added 826: Albert Schweitzer (film) ----------
# ------ Added 827: Alexander's Ragtime Band (film) ----------
# ------ Added 828: All About Eve ----------
# ------ Added 829: All Quiet on the Western Front (1930 film) ----------
# ------ Added 830: The Devil and Daniel Webster (film) ----------
# ------ Added 831: All the King's Men (1949 film) ----------
# ------ Added 832: Ama Girls ----------
# ------ Added 833: America America ----------
# ------ Added 834: An American in Paris (film) ----------
# ------ Added 835: Amphibious Fighters ----------
# ------ Added 836: Anastasia (1956 film) ----------
# ------ Added 837: Anchors Aweigh (film) ----------
# ------ Added 838: Anna and the King of Siam (film) ----------
# ------ Added 839: Annie Get Your Gun (film) ----------
# ------ Added 840: Anthony Adverse ----------
# ------ Added 841: The Apartment ----------
# ------ Added 842: Aquatic House Party ----------
# ------ Added 843: Arise, My Love ----------
# ------ Added 844: Around the World in 80 Days (1956 film) ----------
# ------ Added 845: The Awful Truth ----------
# ------ Added 846: The Bachelor and the Bobby-Soxer ----------
# ------ Added 847: The Bad and the Beautiful ----------
# ------ Added 848: Bad Girl (1931 film) ----------
# ------ Added 849: The Barefoot Contessa ----------
# ------ Added 850: The Battle of Midway (film) ----------
# ------ Added 851: Battleground (film) ----------
# ------ Added 852: Bear Country (film) ----------
# ------ Added 853: Becket (1964 film) ----------
# ------ Added 854: The Bells of St. Mary's ----------
# ------ Added 855: Ben-Hur (1959 film) ----------
# ------ Added 856: Benjy (film) ----------
# ------ Added 857: The Bespoke Overcoat ----------
# ------ Added 858: The Best Years of Our Lives ----------
# ------ Added 859: Beyond the Line of Duty ----------
# ------ Added 860: Bicycle Thieves ----------
# ------ Added 861: The Big Broadcast of 1938 ----------
# ------ Added 862: The Big Country ----------
# ------ Added 863: The Big House (1930 film) ----------
# ------ Added 864: Bill and Coo ----------
# ------ Added 865: Birds Anonymous ----------
# ------ Added 866: The Bishop's Wife ----------
# ------ Added 867: Black Fox: The Rise and Fall of Adolf Hitler ----------
# ------ Added 868: Black Narcissus ----------
# ------ Added 869: Black Orpheus ----------
# ------ Added 870: The Black Swan (film) ----------
# ------ Added 871: Blithe Spirit (1945 film) ----------
# ------ Added 872: Blood and Sand (1941 film) ----------
# ------ Added 873: Blood on the Sun ----------
# ------ Added 874: Blossoms in the Dust ----------
# ------ Added 875: Body and Soul (1947 film) ----------
# ------ Added 876: Bored of Education ----------
# ------ Added 877: Born Yesterday (1950 film) ----------
# ------ Added 878: A Boy and His Dog (1946 film) ----------
# ------ Added 879: Boys Town (film) ----------
# ------ Added 880: The Brave One (1956 film) ----------
# ------ Added 881: Breakfast at Tiffany's (film) ----------
# ------ Added 882: The Sound Barrier ----------
# ------ Added 883: The Bridge of San Luis Rey (1929 film) ----------
# ------ Added 884: The Bridge on the River Kwai ----------
# ------ Added 885: The Bridges at Toko-Ri ----------
# ------ Added 886: Broadway Melody of 1936 ----------
# ------ Added 887: The Broadway Melody ----------
# ------ Added 888: Broken Lance ----------
# ------ Added 889: Busy Little Bears ----------
# ------ Added 890: BUtterfield 8 ----------
# ------ Added 891: Calamity Jane (film) ----------
# ------ Added 892: Call Me Madam (film) ----------
# ------ Added 893: Captain Carey, U.S.A. ----------
# ------ Added 894: Captains Courageous (1937 film) ----------
# ------ Added 895: Casablanca (film) ----------
# ------ Added 896: Casals Conducts: 1964 ----------
# ------ Added 897: The Cat Concerto ----------
# ------ Added 898: Cavalcade (1933 film) ----------
# ------ Added 899: Chagall (film) ----------
# ------ Added 900: The Champ (1931 film) ----------
# ------ Added 901: Champion (1949 film) ----------
# ------ Added 902: A Chance to Live ----------
# ------ Added 903: The Charge of the Light Brigade (1936 film) ----------
# ------ Added 904: The Chicken (film) ----------
# ------ Added 905: Churchill's Island ----------
# ------ Added 906: Cimarron (1931 film) ----------
# ------ Added 907: The Circus (1928 film) ----------
# ------ Added 908: Citizen Kane ----------
# ------ Added 909: City of Wax ----------
# ------ Added 910: Cleopatra (1934 film) ----------
# ------ Added 911: Cleopatra (1963 film) ----------
# ------ Added 912: Climbing the Matterhorn ----------
# ------ Added 913: Come and Get It (1936 film) ----------
# ------ Added 914: Come Back, Little Sheba (1952 film) ----------
# ------ Added 915: Coquette (film) ----------
# ------ Added 916: The Country Cousin ----------
# ------ Added 917: The Country Girl (1954 film) ----------
# ------ Added 918: Cover Girl (film) ----------
# ------ Added 919: The Cowboy and the Lady (1938 film) ----------
# ------ Added 920: Crash Dive ----------
# ------ Added 921: Crashing the Water Barrier ----------
# ------ Added 922: The Critic (1963 film) ----------
# ------ Added 923: La Cucaracha (1934 film) ----------
# ------ Added 924: Cyrano de Bergerac (1950 film) ----------
# ------ Added 925: A Damsel in Distress (1937 film) ----------
# ------ Added 926: Dangerous (1935 film) ----------
# ------ Added 927: The Dark Angel (1935 film) ----------
# ------ Added 928: The Dawn Patrol (1930 film) ----------
# ------ Added 929: Day of the Painter ----------
# ------ Added 930: Daybreak in Udi ----------
# ------ Added 931: Days of Wine and Roses (film) ----------
# ------ Added 932: December 7th: The Movie ----------
# ------ Added 933: Declaration of Independence (film) ----------
# ------ Added 934: The Defiant Ones ----------
# ------ Added 935: Der Fuehrer's Face ----------
# ------ Added 936: Desert Victory ----------
# ------ Added 937: Design for Death ----------
# ------ Added 938: Designing Woman ----------
# ------ Added 939: Destination Moon (film) ----------
# ------ Added 940: The Diary of Anne Frank (1959 film) ----------
# ------ Added 941: Disraeli (1929 film) ----------
# ------ Added 942: The Divine Lady ----------
# ------ Added 943: Divorce Italian Style ----------
# ------ Added 944: The Divorcee ----------
# ------ Added 945: Dodsworth (film) ----------
# ...
# ------ Added 1055: Johnny Belinda (1948 film) ----------
# ------ Added 1056: Johnny Eager ----------
# ------ Added 1057: The Joker Is Wild ----------
# ------ Added 1058: The Jolson Story ----------
# ------ Added 1059: Judgment at Nuremberg ----------
# ------ Added 1060: Julius Caesar (1953 film) ----------
# ------ Added 1061: Kentucky (film) ----------
# ------ Added 1062: Key Largo (film) ----------
# ------ Added 1063: The King and I (1956 film) ----------
# ------ Added 1064: King of Jazz ----------
# ------ Added 1065: King Solomon's Mines (1950 film) ----------
# ------ Added 1066: Kitty Foyle (film) ----------
# ------ Added 1067: Knighty Knight Bugs ----------
# ------ Added 1068: Kokoda Front Line! ----------
# ------ Added 1069: Kon-Tiki (1950 film) ----------
# ------ Added 1070: Krakatoa (film) ----------
# ------ Added 1071: Kukan ----------
# ------ Added 1072: La Strada ----------
# ------ Added 1073: La Dolce Vita ----------
# ------ Added 1074: Lady Be Good (1941 film) ----------
# ------ Added 1075: The Last Command (1928 film) ----------
# ------ Added 1076: Laura (1944 film) ----------
# ------ Added 1077: The Lavender Hill Mob ----------
# ------ Added 1078: Lawrence of Arabia (film) ----------
# ------ Added 1079: Leave Her to Heaven ----------
# ------ Added 1080: Lend a Paw ----------
# ------ Added 1081: Les Girls ----------
# ------ Added 1082: A Letter to Three Wives ----------
# ------ Added 1083: The Life of Emile Zola ----------
# ------ Added 1084: Light in the Window ----------
# ------ Added 1085: Lili ----------
# ------ Added 1086: Lilies of the Field (1963 film) ----------
# ------ Added 1087: The Kidnappers ----------
# ------ Added 1088: The Little Orphan ----------
# ------ Added 1089: Little Women (1933 film) ----------
# ------ Added 1090: Little Women (1949 film) ----------
# ------ Added 1091: The Lives of a Bengal Lancer (film) ----------
# ------ Added 1092: The Living Desert ----------
# ------ Added 1093: The Longest Day (film) ----------
# ------ Added 1094: Lost Horizon (1937 film) ----------
# ------ Added 1095: The Lost Weekend (film) ----------
# ------ Added 1096: Love Is a Many-Splendored Thing (film) ----------
# ------ Added 1097: Love Me or Leave Me (film) ----------
# ------ Added 1098: Lust for Life (1956 film) ----------
# ------ Added 1099: Magoo's Puddle Jumper ----------
# ------ Added 1100: Main Street on the March! ----------
# ------ Added 1101: The Man Who Knew Too Much (1956 film) ----------
# ------ Added 1102: Manhattan Melodrama ----------
# ------ Added 1103: Marie-Louise (film) ----------
# ------ Added 1104: Marty (film) ----------
# ------ Added 1105: Mary Poppins (film) ----------
# ------ Added 1106: Men Against the Arctic ----------
# ------ Added 1107: The Merry Widow (1934 film) ----------
# ------ Added 1108: A Midsummer Night's Dream (1935 film) ----------
# ------ Added 1109: Mighty Joe Young (1949 film) ----------
# ------ Added 1110: Mildred Pierce (film) ----------
# ------ Added 1111: The Milky Way (1940 film) ----------
# ------ Added 1112: Min and Bill ----------
# ------ Added 1113: Miracle on 34th Street ----------
# ------ Added 1114: The Miracle Worker (1962 film) ----------
# ------ Added 1115: Mister Roberts (1955 film) ----------
# ------ Added 1116: Monsieur Vincent ----------
# ------ Added 1117: Moonbird ----------
# ------ Added 1118: The More the Merrier ----------
# ------ Added 1119: Morning Glory (1933 film) ----------
# ------ Added 1120: Moscow Strikes Back ----------
# ------ Added 1121: Mother Wore Tights ----------
# ------ Added 1122: Moulin Rouge (1952 film) ----------
# ------ Added 1123: Mouse Trouble ----------
# ------ Added 1124: Mr. Deeds Goes to Town ----------
# ------ Added 1125: Mr. Smith Goes to Washington ----------
# ------ Added 1126: Mrs. Miniver ----------
# ------ Added 1127: Munro (film) ----------
# ------ Added 1128: The Music Box ----------
# ------ Added 1129: The Music Man (1962 film) ----------
# ------ Added 1130: Mutiny on the Bounty (1935 film) ----------
# ------ Added 1131: My Fair Lady (film) ----------
# ------ Added 1132: Mon Oncle ----------
# ------ Added 1133: My Gal Sal ----------
# ------ Added 1134: The Naked City ----------
# ------ Added 1135: National Velvet (film) ----------
# ------ Added 1136: Nature's Half Acre ----------
# ------ Added 1137: Naughty Marietta (film) ----------
# ------ Added 1138: Neighbours (1952 film) ----------
# ------ Added 1139: Neptune's Daughter (1949 film) ----------
# ------ Added 1140: Never on Sunday ----------
# ------ Added 1141: The Night of the Iguana (film) ----------
# ------ Added 1142: Nights of Cabiria ----------
# ------ Added 1143: Nine from Little Rock ----------
# ------ Added 1144: None but the Lonely Heart (film) ----------
# ------ Added 1145: North West Mounted Police (film) ----------
# ------ Added 1146: Now, Voyager ----------
# ------ Added 1147: An Occurrence at Owl Creek Bridge (film) ----------
# ------ Added 1148: Of Pups and Puzzles ----------
# ------ Added 1149: Oklahoma! (1955 film) ----------
# ------ Added 1150: The Old Man and the Sea (1958 film) ----------
# ------ Added 1151: The Old Mill ----------
# ------ Added 1152: On the Town (film) ----------
# ------ Added 1153: On the Waterfront ----------
# ------ Added 1154: One Hundred Men and a Girl ----------
# ------ Added 1155: One Night of Love ----------
# ------ Added 1156: One Way Passage ----------
# ------ Added 1157: Overture to The Merry Wives of Windsor ----------
# ------ Added 1158: The Paleface (1948 film) ----------
# ------ Added 1159: Panic in the Streets (film) ----------
# ------ Added 1160: Papa's Delicate Condition ----------
# ------ Added 1161: The Patriot (1928 film) ----------
# ------ Added 1162: Penny Wisdom ----------
# ------ Added 1163: Phantom of the Opera (1943 film) ----------
# ------ Added 1164: The Philadelphia Story (film) ----------
# ------ Added 1165: Picnic (1955 film) ----------
# ------ Added 1166: The Picture of Dorian Gray (1945 film) ----------
# ------ Added 1167: Pillow Talk (film) ----------
# ------ Added 1168: The Pink Phink ----------
# ------ Added 1169: Pinocchio (1940 film) ----------
# ------ Added 1170: A Place in the Sun (1951 film) ----------
# ------ Added 1171: Plymouth Adventure ----------
# ------ Added 1172: Pollyanna (1960 film) ----------
# ------ Added 1173: Porgy and Bess (film) ----------
# ------ Added 1174: Portrait of Jennie ----------
# ------ Added 1175: Prelude to War ----------
# ------ Added 1176: Pride and Prejudice (1940 film) ----------
# ------ Added 1177: The Pride of the Yankees ----------
# ------ Added 1178: Princess O'Rourke ----------
# ------ Added 1179: The Private Life of Henry VIII ----------
# ------ Added 1180: The Private Life of the Gannets ----------
# ------ Added 1181: Project Hope (film) ----------
# ------ Added 1182: The Public Pays ----------
# ------ Added 1183: Pygmalion (1938 film) ----------
# ------ Added 1184: Quicker'n a Wink ----------
# ------ Added 1185: The Quiet Man ----------
# ------ Added 1186: Quiet Please! ----------
# ------ Added 1187: The Rains Came ----------
# ------ Added 1188: Rashomon ----------
# ------ Added 1189: The Razor's Edge (1946 film) ----------
# ------ Added 1190: Reap the Wild Wind ----------
# ------ Added 1191: Rebecca (1940 film) ----------
# ------ Added 1192: The Red Balloon ----------
# ------ Added 1193: The Red Shoes (1948 film) ----------
# ------ Added 1194: The Robe (film) ----------
# ------ Added 1195: Robert Frost: A Lover's Quarrel with the World ----------
# ------ Added 1196: Roman Holiday ----------
# ------ Added 1197: Room at the Top (1959 film) ----------
# ------ Added 1198: The Rose Tattoo (film) ----------
# ------ Added 1199: Sabrina (1954 film) ----------
# ------ Added 1200: Samson and Delilah (1949 film) ----------
# ------ Added 1201: Samurai I: Musashi Miyamoto ----------
# ------ Added 1202: San Francisco (1936 film) ----------
# ------ Added 1203: Sayonara ----------
# ------ Added 1204: The Scoundrel (1935 film) ----------
# ------ Added 1205: The Sea Around Us (film) ----------
# ------ Added 1206: Seal Island (film) ----------
# ------ Added 1207: The Search ----------
# ------ Added 1208: Seawards the Great Ships ----------
# ------ Added 1209: The Secret Land ----------
# ------ Added 1210: Seeds of Destiny ----------
# ------ Added 1211: Separate Tables (film) ----------
# ------ Added 1212: Serengeti Shall Not Die ----------
# ------ Added 1213: Sergeant York (film) ----------
# ------ Added 1214: Seven Brides for Seven Brothers ----------
# ------ Added 1215: Seven Days to Noon ----------
# ------ Added 1216: The Seventh Veil ----------
# ------ Added 1217: Shane (film) ----------
# ------ Added 1218: Shanghai Express (film) ----------
# ------ Added 1219: She Wore a Yellow Ribbon ----------
# ------ Added 1220: Shoeshine (film) ----------
# ------ Added 1221: The Silent World ----------
# ------ Added 1222: The Sin of Madelon Claudet ----------
# ------ Added 1223: Since You Went Away ----------
# ------ Added 1224: Skippy (film) ----------
# ------ Added 1225: Sky Above and Mud Beneath ----------
# ------ Added 1226: The Snake Pit ----------
# ------ Added 1227: Snow White and the Seven Dwarfs (1937 film) ----------
# ------ Added 1228: So Much for So Little ----------
# ------ Added 1229: So This Is Harris! ----------
# ------ Added 1230: The Solid Gold Cadillac ----------
# ------ Added 1231: Some Like It Hot ----------
# ------ Added 1232: Somebody Up There Likes Me (1956 film) ----------
# ------ Added 1233: The Song of Bernadette (film) ----------
# ------ Added 1234: Song of the South ----------
# ------ Added 1235: Song Without End ----------
# ------ Added 1236: Sons and Lovers (film) ----------
# ------ Added 1237: Sons of Liberty (film) ----------
# ------ Added 1238: South Pacific (1958 film) ----------
# ------ Added 1239: Spartacus (film) ----------
# ------ Added 1240: Spawn of the North ----------
# ------ Added 1241: Speaking of Animals and Their Families ----------
# ------ Added 1242: Speedy Gonzales (film) ----------
# ------ Added 1243: Spellbound (1945 film) ----------
# ------ Added 1244: Splendor in the Grass ----------
# ------ Added 1245: Stagecoach (1939 film) ----------
# ------ Added 1246: Stairway to Light ----------
# ------ Added 1247: Stalag 17 ----------
# ------ Added 1248: Star in the Night ----------
# ------ Added 1249: A Star Is Born (1937 film) ----------
# ------ Added 1250: State Fair (1945 film) ----------
# ------ Added 1251: The Story of Louis Pasteur ----------
# ------ Added 1252: The Stratton Story ----------
# ------ Added 1253: Street Angel (1928 film) ----------
# ------ Added 1254: A Streetcar Named Desire (1951 film) ----------
# ------ Added 1255: Strike Up the Band (film) ----------
# ------ Added 1256: Surogat ----------
# ------ Added 1257: Sundays and Cybele ----------
# ------ Added 1258: Sunrise: A Song of Two Humans ----------
# ------ Added 1259: Sunset Boulevard (film) ----------
# ------ Added 1260: Survival City ----------
# ------ Added 1261: Suspicion (1941 film) ----------
# ------ Added 1262: Sweet Bird of Youth (1962 film) ----------
# ------ Added 1263: Sweethearts (1938 film) ----------
# ------ Added 1264: Swing Time (film) ----------
# ------ Added 1265: Symphony of a City ----------
# ------ Added 1266: Tabu: A Story of the South Seas ----------
# ------ Added 1267: Target for Tonight ----------
# ------ Added 1268: Teddy, the Rough Rider ----------
# ------ Added 1269: Tempest (1928 film) ----------
# ------ Added 1270: The Ten Commandments (1956 film) ----------
# ------ Added 1271: That Hamilton Woman ----------
# ------ Added 1272: That Mothers Might Live ----------
# ------ Added 1273: The Thief of Bagdad (1940 film) ----------
# ------ Added 1274: The Third Man ----------
# ------ Added 1275: Thirty Seconds Over Tokyo ----------
# ------ Added 1276: This Above All (film) ----------
# ------ Added 1277: This Is the Army ----------
# ------ Added 1278: This Land Is Mine (film) ----------
# ------ Added 1279: This Mechanical Age ----------
# ------ Added 1280: Three Coins in the Fountain (film) ----------
# ------ Added 1281: The Three Faces of Eve ----------
# ------ Added 1282: Three Little Pigs (film) ----------
# ------ Added 1283: Three Orphan Kittens ----------
# ------ Added 1284: Through a Glass Darkly (film) ----------
# ------ Added 1285: Thunderball (film) ----------
# ------ Added 1286: Thursday's Children ----------
# ------ Added 1287: The Time Machine (1960 film) ----------
# ------ Added 1288: A Time Out of War ----------
# ------ Added 1289: Tin Pan Alley (film) ----------
# ------ Added 1290: The Titan: Story of Michelangelo ----------
# ------ Added 1291: Titanic (1953 film) ----------
# ------ Added 1292: To Catch a Thief ----------
# ------ Added 1293: To Each His Own (1946 film) ----------
# ------ Added 1294: To Kill a Mockingbird (film) ----------
# ------ Added 1295: Tom Jones (1963 film) ----------
# ------ Added 1296: Tom Thumb (film) ----------
# ------ Added 1297: Toot, Whistle, Plunk and Boom ----------
# ------ Added 1298: Topkapi (film) ----------
# ------ Added 1299: The Tortoise and the Hare (film) ----------
# ------ Added 1300: Torture Money ----------
# ------ Added 1301: Toward Independence ----------
# ------ Added 1302: Transatlantic (1931 film) ----------
# ------ Added 1303: The Treasure of the Sierra Madre (film) ----------
# ------ Added 1304: A Tree Grows in Brooklyn (1945 film) ----------
# ------ Added 1305: The True Glory ----------
# ------ Added 1306: The True Story of the Civil War ----------
# ------ Added 1307: Tweetie Pie ----------
# ------ Added 1308: Twelve O'Clock High ----------
# ------ Added 1309: Two Arabian Knights ----------
# ------ Added 1310: The Two Mouseketeers ----------
# ------ Added 1311: Two Women ----------
# ------ Added 1312: The Ugly Duckling (1939 film) ----------
# ------ Added 1313: Underworld (1927 film) ----------
# ------ Added 1314: The V.I.P.s (film) ----------
# ------ Added 1315: Perfect Strangers (1945 film) ----------
# ------ Added 1316: Van Gogh (1948 film) ----------
# ------ Added 1317: The Vanishing Prairie ----------
# ------ Added 1318: The Virgin Spring ----------
# ------ Added 1319: Viva Villa! ----------
# ------ Added 1320: Viva Zapata! ----------
# ------ Added 1321: Waikiki Wedding ----------
# ------ Added 1322: The Walls of Malapaga ----------
# ------ Added 1323: The War of the Worlds (1953 film) ----------
# ------ Added 1324: Watch on the Rhine ----------
# ------ Added 1325: Water Birds ----------
# ------ Added 1326: The Way of All Flesh (1927 film) ----------
# ------ Added 1327: West Side Story (1961 film) ----------
# ------ Added 1328: The Westerner (1940 film) ----------
# ------ Added 1329: The Wetback Hound ----------
# ------ Added 1330: What Ever Happened to Baby Jane? (1962 film) ----------
# ------ Added 1331: When Tomorrow Comes (film) ----------
# ------ Added 1332: When Magoo Flew ----------
# ------ Added 1333: When Worlds Collide (1951 film) ----------
# ------ Added 1334: White Shadows in the South Seas ----------
# ------ Added 1335: White Wilderness (film) ----------
# ------ Added 1336: Who's Who in Animal Land ----------
# ------ Added 1337: Why Korea? ----------
# ------ Added 1338: Wilson (1944 film) ----------
# ------ Added 1339: Wings (1927 film) ----------
# ------ Added 1340: Wings Over Everest ----------
# ------ Added 1341: With a Song in My Heart (film) ----------
# ------ Added 1342: With Byrd at the South Pole ----------
# ------ Added 1343: With the Marines at Tarawa ----------
# ------ Added 1344: The Wizard of Oz (1939 film) ----------
# ------ Added 1345: Woman of the Year ----------
# ------ Added 1346: Wonder Man (film) ----------
# ------ Added 1347: The Wonderful World of the Brothers Grimm ----------
# ------ Added 1348: World of Kids ----------
# ------ Added 1349: World Without Sun ----------
# ------ Added 1350: Wrestling Swordfish ----------
# ------ Added 1351: Written on the Wind ----------
# ------ Added 1352: Wuthering Heights (1939 film) ----------
# ------ Added 1353: Yankee Doodle Dandy ----------
# ------ Added 1354: The Yankee Doodle Mouse ----------
# ------ Added 1355: The Yearling (1946 film) ----------
# ------ Added 1356: Yesterday, Today and Tomorrow ----------
# ------ Added 1357: You Can't Take It with You (film) ----------
# ------ Added 1358: Zorba the Greek (film) ----------

# %% [markdown]
# ## Pull Monthly Mobile Access

# %% [markdown]
# References:
# - https://www.geeksforgeeks.org/append-to-json-file-using-python/#
# - Things I learned from example:
#     - the structure of the returned data from the API

# %%
# test_list = ['Everything Everywhere All at Once', 'The Whale (2022 film)']

# %% [markdown]
# Provide new values for page parameter dictionary

# %%
page_params_mobile_app = {
    "project":     "en.wikipedia.org",
    "access":      "mobile-app",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # start and end dates need to be set
    "end":         "2023093000"    # this is likely the wrong end date
}

page_params_mobile_web = {
    "project":     "en.wikipedia.org",
    "access":      "mobile-web",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # start and end dates need to be set
    "end":         "2023093000"    # this is likely the wrong end date
}

# %% [markdown]
# **Pull each type of mobile data and then combine into a new file**

# %% [markdown]
# Pull mobile-app data

# %%
# Define articles dictionary
articles_mobile_app_data = {}

article_count = 0

# For each article
for title in article_names:
    
    # Get data from API for article
    mobile_app_article_views = request_pageviews_per_article(title, request_template=page_params_mobile_app)
    
    month_list = []
    
    # Modify the retrieved data -------------!!!!!!!!!!!! Got idea for this form of iterating from Prof example
    for month in mobile_app_article_views['items']:
        # Remove access key from each month's entry
        del month['access'] # learned from https://www.geeksforgeeks.org/python-ways-to-remove-a-key-from-dictionary/
        
        # Reconstruct list of months
        month_list.append(month)
        
        # Store in a dictionary of articles
        articles_mobile_app_data[title] = month_list
        
    article_count += 1
    print("------ Added {}: {} ----------".format(article_count,title))

print("Finished mobile-app")



# Define articles dictionary
articles_mobile_data = {}

article_count = 0

# For each article
for title in article_names:
    
    # Get data from API for article
    mobile_web_article_views = request_pageviews_per_article(title, request_template=page_params_mobile_web)
    
    month_list = []
    
    # Modify the retrieved data -------------!!!!!!!!!!!! Got idea for this form of iterating from Prof example
    month_index = 0
    for month in mobile_web_article_views['items']:
        # Remove access key from each month's entry
        del month['access'] # learned from https://www.geeksforgeeks.org/python-ways-to-remove-a-key-from-dictionary/
        
        # Add mobile web and mobile app counts
        mobile_app_month_views = articles_mobile_app_data[title][month_index]['views']
        month['views'] = month['views'] + mobile_app_month_views
        
        # Reconstruct list of months
        month_list.append(month)
        
        # Store in a dictionary of articles
        articles_mobile_data[title] = month_list
        
    article_count += 1
    print("------ Added {}: {} ----------".format(article_count,title))

    
# Save to JSON file - Reference: https://www.geeksforgeeks.org/writing-to-file-in-python/
my_file2 = open(r"academy_monthly_mobile_201507-202309.json", "w")
my_file2.write(json.dumps(articles_mobile_data, indent=4)) # !!!!!borrowed part of a line of code from Prof example
my_file2.close()
print("Finished mobile data")

# Combine Counts
# Out:
# ------ Added 1: Everything Everywhere All at Once ----------
# ------ Added 2: All Quiet on the Western Front (2022 film) ----------
# ------ Added 3: The Whale (2022 film) ----------
# ------ Added 4: Top Gun: Maverick ----------
# ------ Added 5: Black Panther: Wakanda Forever ----------
# ------ Added 6: Avatar: The Way of Water ----------
# ------ Added 7: Women Talking (film) ----------
# ------ Added 8: Guillermo del Toro's Pinocchio ----------
# ------ Added 9: Navalny (film) ----------
# ------ Added 10: The Elephant Whisperers ----------
# ------ Added 11: An Irish Goodbye ----------
# ------ Added 12: The Boy, the Mole, the Fox and the Horse (film) ----------
# ------ Added 13: RRR (film) ----------
# ------ Added 14: CODA (2021 film) ----------
# ------ Added 15: Dune (2021 film) ----------
# ------ Added 16: The Eyes of Tammy Faye (2021 film) ----------
# ------ Added 17: No Time to Die ----------
# ------ Added 18: The Windshield Wiper ----------
# ------ Added 19: The Long Goodbye (Riz Ahmed album) ----------
# ------ Added 20: The Queen of Basketball ----------
# ------ Added 21: Summer of Soul ----------
# ------ Added 22: Drive My Car (film) ----------
# ------ Added 23: Encanto ----------
# ------ Added 24: West Side Story (2021 film) ----------
# ------ Added 25: Belfast (film) ----------
# ------ Added 26: The Power of the Dog (film) ----------
# ------ Added 27: King Richard (film) ----------
# ------ Added 28: Cruella (film) ----------
# ------ Added 29: Nomadland (film) ----------
# ------ Added 30: The Father (2020 film) ----------
# ------ Added 31: Judas and the Black Messiah ----------
# ------ Added 32: Minari (film) ----------
# ------ Added 33: Mank ----------
# ------ Added 34: Sound of Metal ----------
# ------ Added 35: Ma Rainey's Black Bottom (film) ----------
# ------ Added 36: Promising Young Woman ----------
# ------ Added 37: Tenet (film) ----------
# ------ Added 38: Soul (2020 film) ----------
# ------ Added 39: Another Round (film) ----------
# ------ Added 40: My Octopus Teacher ----------
# ------ Added 41: Colette (2020 film) ----------
# ------ Added 42: If Anything Happens I Love You ----------
# ------ Added 43: Two Distant Strangers ----------
# ------ Added 44: Parasite (2019 film) ----------
# ------ Added 45: Ford v Ferrari ----------
# ------ Added 46: Learning to Skateboard in a Warzone (If You're a Girl) ----------
# ------ Added 47: The Neighbors' Window ----------
# ------ Added 48: Little Women (2019 film) ----------
# ------ Added 49: Marriage Story ----------
# ------ Added 50: Jojo Rabbit ----------
# ------ Added 51: Toy Story 4 ----------
# ------ Added 52: Joker (2019 film) ----------
# ------ Added 53: Once Upon a Time in Hollywood ----------
# ------ Added 54: 1917 (2019 film) ----------
# ------ Added 55: Judy (film) ----------
# ------ Added 56: Bombshell (2019 film) ----------
# ------ Added 57: Rocketman (film) ----------
# ------ Added 58: American Factory ----------
# ------ Added 59: Hair Love ----------
# ------ Added 60: Green Book (film) ----------
# ------ Added 61: Bohemian Rhapsody (film) ----------
# ------ Added 62: Roma (2018 film) ----------
# ------ Added 63: Black Panther (film) ----------
# ------ Added 64: The Favourite ----------
# ------ Added 65: A Star Is Born (2018 film) ----------
# ------ Added 66: Vice (2018 film) ----------
# ------ Added 67: BlacKkKlansman ----------
# ------ Added 68: First Man (film) ----------
# ------ Added 69: If Beale Street Could Talk (film) ----------
# ------ Added 70: Bao (film) ----------
# ------ Added 71: Free Solo ----------
# ------ Added 72: Period. End of Sentence. ----------
# ------ Added 73: Skin (2018 short film) ----------
# ------ Added 74: Spider-Man: Into the Spider-Verse ----------
# ------ Added 75: The Shape of Water ----------
# ------ Added 76: Dunkirk (2017 film) ----------
# ------ Added 77: Three Billboards Outside Ebbing, Missouri ----------
# ------ Added 78: Darkest Hour (film) ----------
# ------ Added 79: Blade Runner 2049 ----------
# ------ Added 80: Coco (2017 film) ----------
# ------ Added 81: Phantom Thread ----------
# ------ Added 82: Call Me by Your Name (film) ----------
# ------ Added 83: Get Out ----------
# ------ Added 84: I, Tonya ----------
# ------ Added 85: Dear Basketball ----------
# ------ Added 86: A Fantastic Woman ----------
# ------ Added 87: Heaven Is a Traffic Jam on the 405 ----------
# ------ Added 88: Icarus (2017 film) ----------
# ------ Added 89: The Silent Child ----------
# ------ Added 90: Flesh and Sand ----------
# ------ Added 91: Moonlight (2016 film) ----------
# ------ Added 92: La La Land (film) ----------
# ------ Added 93: Hacksaw Ridge ----------
# ------ Added 94: Manchester by the Sea (film) ----------
# ------ Added 95: Arrival (film) ----------
# ------ Added 96: Fences (film) ----------
# ------ Added 97: Fantastic Beasts and Where to Find Them (film) ----------
# ------ Added 98: The Jungle Book (2016 film) ----------
# ------ Added 99: O.J.: Made in America ----------
# ------ Added 100: Piper (film) ----------
# ------ Added 101: The Salesman (2016 film) ----------
# ------ Added 102: Sing (2016 Hungarian film) ----------
# ------ Added 103: Suicide Squad (2016 film) ----------
# ------ Added 104: The White Helmets (film) ----------
# ------ Added 105: Zootopia ----------
# ------ Added 106: Spotlight (film) ----------
# ------ Added 107: Mad Max: Fury Road ----------
# ------ Added 108: The Revenant (2015 film) ----------
# ------ Added 109: Bridge of Spies (film) ----------
# ------ Added 110: The Big Short (film) ----------
# ------ Added 111: The Danish Girl (film) ----------
# ------ Added 112: Room (2015 film) ----------
# ------ Added 113: The Hateful Eight ----------
# ------ Added 114: Ex Machina (film) ----------
# ------ Added 115: Inside Out (2015 film) ----------
# ------ Added 116: Amy (2015 film) ----------
# ------ Added 117: Bear Story ----------
# ------ Added 118: A Girl in the River: The Price of Forgiveness ----------
# ------ Added 119: Son of Saul ----------
# ------ Added 120: Spectre (2015 film) ----------
# ------ Added 121: Stutterer (film) ----------
# ------ Added 122: Birdman (film) ----------
# ------ Added 123: The Grand Budapest Hotel ----------
# ------ Added 124: Whiplash (2014 film) ----------
# ------ Added 125: The Imitation Game ----------
# ------ Added 126: American Sniper ----------
# ------ Added 127: Boyhood (2014 film) ----------
# ------ Added 128: Interstellar (film) ----------
# ------ Added 129: The Theory of Everything (2014 film) ----------
# ------ Added 130: Ida (film) ----------
# ------ Added 131: Selma (film) ----------
# ------ Added 132: Citizenfour ----------
# ------ Added 133: Big Hero 6 (film) ----------
# ------ Added 134: Crisis Hotline: Veterans Press 1 ----------
# ------ Added 135: The Phone Call (2013 film) ----------
# ------ Added 136: Still Alice ----------
# ------ Added 137: Feast (2014 film) ----------
# ------ Added 138: 12 Years a Slave (film) ----------
# ------ Added 139: Gravity (2013 film) ----------
# ------ Added 140: Dallas Buyers Club ----------
# ------ Added 141: Frozen (2013 film) ----------
# ------ Added 142: The Great Gatsby (2013 film) ----------
# ------ Added 143: Her (film) ----------
# ------ Added 144: Blue Jasmine ----------
# ------ Added 145: Mr Hublot ----------
# ------ Added 146: The Lady in Number 6 ----------
# ------ Added 147: Helium (film) ----------
# ------ Added 148: The Great Beauty ----------
# ------ Added 149: 20 Feet from Stardom ----------
# ------ Added 150: Argo (2012 film) ----------
# ------ Added 151: Life of Pi (film) ----------
# ------ Added 152: Les Misérables (2012 film) ----------
# ------ Added 153: Lincoln (film) ----------
# ------ Added 154: Django Unchained ----------
# ------ Added 155: Skyfall ----------
# ------ Added 156: Silver Linings Playbook ----------
# ------ Added 157: Zero Dark Thirty ----------
# ------ Added 158: Amour (2012 film) ----------
# ------ Added 159: Anna Karenina (2012 film) ----------
# ------ Added 160: Paperman ----------
# ------ Added 161: Brave (2012 film) ----------
# ------ Added 162: Searching for Sugar Man ----------
# ------ Added 163: Inocente ----------
# ------ Added 164: Curfew (2012 film) ----------
# ------ Added 165: The Artist (film) ----------
# ------ Added 166: Hugo (film) ----------
# ------ Added 167: The Iron Lady (film) ----------
# ------ Added 168: The Descendants ----------
# ------ Added 169: The Girl with the Dragon Tattoo (2011 film) ----------
# ------ Added 170: Midnight in Paris ----------
# ------ Added 171: The Help (film) ----------
# ------ Added 172: A Separation ----------
# ------ Added 173: The Fantastic Flying Books of Mr. Morris Lessmore ----------
# ------ Added 174: The Shore (2011 film) ----------
# ------ Added 175: Undefeated (2011 film) ----------
# ------ Added 176: The Muppets (film) ----------
# ------ Added 177: Saving Face (2012 film) ----------
# ------ Added 178: Beginners ----------
# ------ Added 179: Rango (2011 film) ----------
# ------ Added 180: The King's Speech ----------
# ------ Added 181: Inception ----------
# ------ Added 182: The Social Network ----------
# ------ Added 183: The Fighter ----------
# ------ Added 184: Toy Story 3 ----------
# ------ Added 185: Alice in Wonderland (2010 film) ----------
# ------ Added 186: Black Swan (film) ----------
# ------ Added 187: In a Better World ----------
# ------ Added 188: The Lost Thing ----------
# ------ Added 189: God of Love (film) ----------
# ------ Added 190: The Wolfman (2010 film) ----------
# ------ Added 191: Strangers No More ----------
# ------ Added 192: Inside Job (2010 film) ----------
# ------ Added 193: The Hurt Locker ----------
# ------ Added 194: Avatar (2009 film) ----------
# ------ Added 195: Precious (film) ----------
# ------ Added 196: Up (2009 film) ----------
# ------ Added 197: Crazy Heart ----------
# ------ Added 198: Inglourious Basterds ----------
# ------ Added 199: Star Trek (film) ----------
# ------ Added 200: The Young Victoria ----------
# ------ Added 201: The Blind Side (film) ----------
# ------ Added 202: Music by Prudence ----------
# ------ Added 203: The Secret in Their Eyes ----------
# ------ Added 204: The Cove (film) ----------
# ------ Added 205: The New Tenants ----------
# ------ Added 206: Logorama ----------
# ------ Added 207: Slumdog Millionaire ----------
# ------ Added 208: The Curious Case of Benjamin Button (film) ----------
# ------ Added 209: Milk (2008 American film) ----------
# ------ Added 210: The Dark Knight (film) ----------
# ------ Added 211: WALL-E ----------
# ------ Added 212: The Reader (2008 film) ----------
# ------ Added 213: The Duchess (film) ----------
# ------ Added 214: Departures (2008 film) ----------
# ------ Added 215: Vicky Cristina Barcelona ----------
# ------ Added 216: Smile Pinki ----------
# ------ Added 217: Man on Wire ----------
# ------ Added 218: Toyland (film) ----------
# ------ Added 219: La Maison en Petits Cubes ----------
# ------ Added 220: No Country for Old Men (film) ----------
# ------ Added 221: The Bourne Ultimatum (film) ----------
# ------ Added 222: There Will Be Blood ----------
# ------ Added 223: La Vie en rose (film) ----------
# ------ Added 224: Atonement (2007 film) ----------
# ------ Added 225: Michael Clayton (film) ----------
# ------ Added 226: Ratatouille (film) ----------
# ------ Added 227: Juno (film) ----------
# ------ Added 228: Sweeney Todd: The Demon Barber of Fleet Street (2007 film) ----------
# ------ Added 229: The Golden Compass (film) ----------
# ------ Added 230: Elizabeth: The Golden Age ----------
# ------ Added 231: Taxi to the Dark Side ----------
# ------ Added 232: Peter & the Wolf (2006 film) ----------
# ------ Added 233: Once (film) ----------
# ------ Added 234: Le Mozart des pickpockets ----------
# ------ Added 235: The Counterfeiters (2007 film) ----------
# ------ Added 236: Freeheld (2007 film) ----------
# ------ Added 237: The Departed ----------
# ------ Added 238: Pan's Labyrinth ----------
# ------ Added 239: Dreamgirls (film) ----------
# ------ Added 240: Little Miss Sunshine ----------
# ------ Added 241: An Inconvenient Truth ----------
# ------ Added 242: Babel (film) ----------
# ------ Added 243: The Queen (2006 film) ----------
# ------ Added 244: Letters from Iwo Jima ----------
# ------ Added 245: Pirates of the Caribbean: Dead Man's Chest ----------
# ------ Added 246: The Danish Poet ----------
# ------ Added 247: Happy Feet ----------
# ------ Added 248: The Last King of Scotland (film) ----------
# ------ Added 249: The Lives of Others ----------
# ------ Added 250: Marie Antoinette (2006 film) ----------
# ------ Added 251: West Bank Story ----------
# ------ Added 252: The Blood of Yingzhou District ----------
# ------ Added 253: Crash (2004 film) ----------
# ------ Added 254: Brokeback Mountain ----------
# ------ Added 255: Memoirs of a Geisha (film) ----------
# ------ Added 256: King Kong (2005 film) ----------
# ------ Added 257: Capote (film) ----------
# ------ Added 258: Walk the Line ----------
# ------ Added 259: The Constant Gardener (film) ----------
# ------ Added 260: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe ----------
# ------ Added 261: Hustle & Flow ----------
# ------ Added 262: Syriana ----------
# ------ Added 263: March of the Penguins ----------
# ------ Added 264: Six Shooter (film) ----------
# ------ Added 265: The Moon and the Son: An Imagined Conversation ----------
# ------ Added 266: A Note of Triumph: The Golden Age of Norman Corwin ----------
# ------ Added 267: Tsotsi ----------
# ------ Added 268: Wallace & Gromit: The Curse of the Were-Rabbit ----------
# ------ Added 269: Million Dollar Baby ----------
# ------ Added 270: The Aviator (2004 film) ----------
# ------ Added 271: Ray (film) ----------
# ------ Added 272: The Incredibles ----------
# ------ Added 273: Finding Neverland (film) ----------
# ------ Added 274: Sideways ----------
# ------ Added 275: Lemony Snicket's A Series of Unfortunate Events ----------
# ------ Added 276: Spider-Man 2 ----------
# ------ Added 277: Eternal Sunshine of the Spotless Mind ----------
# ------ Added 278: The Motorcycle Diaries (film) ----------
# ------ Added 279: The Sea Inside ----------
# ------ Added 280: Born into Brothels ----------
# ------ Added 281: Mighty Times: The Children's March ----------
# ------ Added 282: Wasp (2003 film) ----------
# ------ Added 283: Ryan (film) ----------
# ------ Added 284: The Lord of the Rings: The Return of the King ----------
# ------ Added 285: Master and Commander: The Far Side of the World ----------
# ------ Added 286: Mystic River (film) ----------
# ------ Added 287: Cold Mountain (film) ----------
# ------ Added 288: Lost in Translation (film) ----------
# ------ Added 289: Finding Nemo ----------
# ------ Added 290: The Barbarian Invasions ----------
# ------ Added 291: Two Soldiers (2003 film) ----------
# ------ Added 292: Monster (2003 film) ----------
# ------ Added 293: Harvie Krumpet ----------
# ------ Added 294: Chernobyl Heart ----------
# ------ Added 295: The Fog of War ----------
# ------ Added 296: Chicago (2002 film) ----------
# ------ Added 297: The Pianist (2002 film) ----------
# ------ Added 298: The Lord of the Rings: The Two Towers ----------
# ------ Added 299: Frida (film) ----------
# ------ Added 300: The Hours (film) ----------
# ------ Added 301: Road to Perdition ----------
# ------ Added 302: Adaptation (film) ----------
# ------ Added 303: Talk to Her ----------
# ------ Added 304: This Charming Man (film) ----------
# ------ Added 305: Spirited Away ----------
# ------ Added 306: Nowhere in Africa ----------
# ------ Added 307: The ChubbChubbs! ----------
# ------ Added 308: Twin Towers (film) ----------
# ------ Added 309: Bowling for Columbine ----------
# ------ Added 310: 8 Mile (film) ----------
# ------ Added 311: A Beautiful Mind (film) ----------
# ------ Added 312: The Lord of the Rings: The Fellowship of the Ring ----------
# ------ Added 313: Moulin Rouge! ----------
# ------ Added 314: Black Hawk Down (film) ----------
# ------ Added 315: Gosford Park ----------
# ------ Added 316: Monsters, Inc. ----------
# ------ Added 317: Pearl Harbor (film) ----------
# ------ Added 318: Iris (2001 film) ----------
# ------ Added 319: Shrek ----------
# ------ Added 320: Training Day ----------
# ------ Added 321: Monster's Ball ----------
# ------ Added 322: Thoth (film) ----------
# ------ Added 323: For the Birds (film) ----------
# ------ Added 324: No Man's Land (2001 film) ----------
# ------ Added 325: Murder on a Sunday Morning ----------
# ------ Added 326: The Accountant (2001 film) ----------
# ------ Added 327: Gladiator (2000 film) ----------
# ------ Added 328: Crouching Tiger, Hidden Dragon ----------
# ------ Added 329: Traffic (2000 film) ----------
# ------ Added 330: Erin Brockovich (film) ----------
# ------ Added 331: Almost Famous ----------
# ------ Added 332: Wonder Boys (film) ----------
# ------ Added 333: How the Grinch Stole Christmas (2000 film) ----------
# ------ Added 334: U-571 (film) ----------
# ------ Added 335: Pollock (film) ----------
# ------ Added 336: Father and Daughter (film) ----------
# ------ Added 337: Into the Arms of Strangers: Stories of the Kindertransport ----------
# ------ Added 338: Quiero ser (I want to be...) ----------
# ------ Added 339: Big Mama (film) ----------
# ------ Added 340: American Beauty (1999 film) ----------
# ------ Added 341: The Matrix ----------
# ------ Added 342: The Cider House Rules (film) ----------
# ------ Added 343: Topsy-Turvy ----------
# ------ Added 344: Sleepy Hollow (film) ----------
# ------ Added 345: Boys Don't Cry (1999 film) ----------
# ------ Added 346: Tarzan (1999 film) ----------
# ------ Added 347: One Day in September ----------
# ------ Added 348: The Red Violin ----------
# ------ Added 349: The Old Man and the Sea (1999 film) ----------
# ------ Added 350: My Mother Dreams the Satan's Disciples in New York ----------
# ------ Added 351: King Gimp ----------
# ------ Added 352: Girl, Interrupted (film) ----------
# ------ Added 353: All About My Mother ----------
# ------ Added 354: Shakespeare in Love ----------
# ------ Added 355: Saving Private Ryan ----------
# ------ Added 356: Life Is Beautiful ----------
# ------ Added 357: Elizabeth (film) ----------
# ------ Added 358: Gods and Monsters (film) ----------
# ------ Added 359: The Prince of Egypt ----------
# ------ Added 360: Affliction (1997 film) ----------
# ------ Added 361: What Dreams May Come (film) ----------
# ------ Added 362: The Personals: Improvisations on Romance in the Golden Years ----------
# ------ Added 363: The Last Days ----------
# ------ Added 364: Election Night (1998 film) ----------
# ------ Added 365: Bunny (1998 film) ----------
# ------ Added 366: Titanic (1997 film) ----------
# ------ Added 367: Good Will Hunting ----------
# ------ Added 368: L.A. Confidential (film) ----------
# ------ Added 369: As Good as It Gets ----------
# ------ Added 370: The Full Monty ----------
# ------ Added 371: Men in Black (1997 film) ----------
# ------ Added 372: Visas and Virtue ----------
# ------ Added 373: Character (film) ----------
# ------ Added 374: Geri's Game ----------
# ------ Added 375: A Story of Healing ----------
# ------ Added 376: The Long Way Home (1997 film) ----------
# ------ Added 377: The English Patient (film) ----------
# ------ Added 378: Fargo (1996 film) ----------
# ------ Added 379: Shine (film) ----------
# ------ Added 380: Evita (1996 film) ----------
# ------ Added 381: Jerry Maguire ----------
# ------ Added 382: Independence Day (1996 film) ----------
# ------ Added 383: Emma (1996 theatrical film) ----------
# ------ Added 384: Sling Blade (film) ----------
# ------ Added 385: The Ghost and the Darkness ----------
# ------ Added 386: Kolya ----------
# ------ Added 387: The Nutty Professor (1996 film) ----------
# ------ Added 388: Quest (1996 film) ----------
# ------ Added 389: When We Were Kings ----------
# ------ Added 390: Breathing Lessons: The Life and Work of Mark O'Brien ----------
# ------ Added 391: Dear Diary (1996 film) ----------
# ------ Added 392: Braveheart ----------
# ------ Added 393: Apollo 13 (film) ----------
# ------ Added 394: Pocahontas (1995 film) ----------
# ------ Added 395: The Usual Suspects ----------
# ------ Added 396: Restoration (1995 film) ----------
# ------ Added 397: Babe (film) ----------
# ------ Added 398: Sense and Sensibility (film) ----------
# ------ Added 399: Il Postino: The Postman ----------
# ------ Added 400: Dead Man Walking (film) ----------
# ------ Added 401: Leaving Las Vegas ----------
# ------ Added 402: Mighty Aphrodite ----------
# ------ Added 403: Anne Frank Remembered ----------
# ------ Added 404: A Close Shave ----------
# ------ Added 405: Lieberman in Love ----------
# ------ Added 406: One Survivor Remembers ----------
# ------ Added 407: Antonia's Line ----------
# ------ Added 408: Toy Story ----------
# ------ Added 409: Forrest Gump ----------
# ------ Added 410: The Lion King ----------
# ------ Added 411: Speed (1994 film) ----------
# ------ Added 412: Ed Wood (film) ----------
# ------ Added 413: Pulp Fiction ----------
# ------ Added 414: Bullets Over Broadway ----------
# ------ Added 415: The Madness of King George ----------
# ------ Added 416: Legends of the Fall ----------
# ------ Added 417: A Time for Justice ----------
# ------ Added 418: Franz Kafka's It's a Wonderful Life ----------
# ------ Added 419: Maya Lin: A Strong Clear Vision ----------
# ------ Added 420: Burnt by the Sun ----------
# ------ Added 421: Trevor (film) ----------
# ------ Added 422: The Adventures of Priscilla, Queen of the Desert ----------
# ------ Added 423: Bob's Birthday ----------
# ------ Added 424: Blue Sky (1994 film) ----------
# ------ Added 425: Schindler's List ----------
# ------ Added 426: The Piano ----------
# ------ Added 427: Jurassic Park (film) ----------
# ------ Added 428: Philadelphia (film) ----------
# ------ Added 429: The Fugitive (1993 film) ----------
# ------ Added 430: The Age of Innocence (1993 film) ----------
# ------ Added 431: The Wrong Trousers ----------
# ------ Added 432: Belle Epoque (film) ----------
# ------ Added 433: I Am a Promise: The Children of Stanton Elementary School ----------
# ------ Added 434: Mrs. Doubtfire ----------
# ------ Added 435: Schwarzfahrer ----------
# ------ Added 436: Defending Our Lives ----------
# ------ Added 437: Unforgiven ----------
# ------ Added 438: Howards End (film) ----------
# ------ Added 439: Bram Stoker's Dracula (1992 film) ----------
# ------ Added 440: Aladdin (1992 Disney film) ----------
# ------ Added 441: The Crying Game ----------
# ------ Added 442: Scent of a Woman (1992 film) ----------
# ------ Added 443: A River Runs Through It (film) ----------
# ------ Added 444: Indochine (film) ----------
# ------ Added 445: My Cousin Vinny ----------
# ------ Added 446: The Panama Deception ----------
# ------ Added 447: Educating Peter ----------
# ------ Added 448: The Last of the Mohicans (1992 film) ----------
# ------ Added 449: Death Becomes Her ----------
# ------ Added 450: Omnibus (film) ----------
# ------ Added 451: Mona Lisa Descending a Staircase ----------
# ------ Added 452: The Silence of the Lambs (film) ----------
# ------ Added 453: Terminator 2: Judgment Day ----------
# ------ Added 454: Bugsy ----------
# ------ Added 455: JFK (film) ----------
# ------ Added 456: Beauty and the Beast (1991 film) ----------
# ------ Added 457: Thelma & Louise ----------
# ------ Added 458: The Fisher King ----------
# ------ Added 459: In the Shadow of the Stars ----------
# ------ Added 460: Manipulation (film) ----------
# ------ Added 461: Mediterraneo ----------
# ------ Added 462: Session Man (film) ----------
# ------ Added 463: City Slickers ----------
# ------ Added 464: Deadly Deception: General Electric, Nuclear Weapons and Our Environment ----------
# ------ Added 465: Dances with Wolves ----------
# ------ Added 466: Dick Tracy (1990 film) ----------
# ------ Added 467: Ghost (1990 film) ----------
# ------ Added 468: Goodfellas ----------
# ------ Added 469: The Hunt for Red October (film) ----------
# ------ Added 470: Reversal of Fortune ----------
# ------ Added 471: Cyrano de Bergerac (1990 film) ----------
# ------ Added 472: American Dream (film) ----------
# ------ Added 473: Journey of Hope (film) ----------
# ------ Added 474: Days of Waiting: The Life & Art of Estelle Ishigo ----------
# ------ Added 475: Creature Comforts ----------
# ------ Added 476: The Lunch Date ----------
# ------ Added 477: Misery (film) ----------
# ------ Added 478: Total Recall (1990 film) ----------
# ------ Added 479: Driving Miss Daisy ----------
# ------ Added 480: Glory (1989 film) ----------
# ------ Added 481: Born on the Fourth of July (film) ----------
# ------ Added 482: My Left Foot ----------
# ------ Added 483: The Little Mermaid (1989 film) ----------
# ------ Added 484: Dead Poets Society ----------
# ------ Added 485: The Abyss ----------
# ------ Added 486: Indiana Jones and the Last Crusade ----------
# ------ Added 487: Henry V (1989 film) ----------
# ------ Added 488: The Johnstown Flood (1989 film) ----------
# ------ Added 489: Common Threads: Stories from the Quilt ----------
# ------ Added 490: Cinema Paradiso ----------
# ------ Added 491: Work Experience (film) ----------
# ------ Added 492: Batman (1989 film) ----------
# ------ Added 493: Balance (1989 film) ----------
# ------ Added 494: Rain Man ----------
# ------ Added 495: Dangerous Liaisons ----------
# ------ Added 496: Who Framed Roger Rabbit ----------
# ------ Added 497: Mississippi Burning ----------
# ------ Added 498: Working Girl ----------
# ------ Added 499: The Accidental Tourist (film) ----------
# ------ Added 500: A Fish Called Wanda ----------
# ------ Added 501: Pelle the Conqueror ----------
# ------ Added 502: The Accused (1988 film) ----------
# ------ Added 503: The Appointments of Dennis Jennings ----------
# ------ Added 504: Beetlejuice ----------
# ------ Added 505: Bird (1988 film) ----------
# ------ Added 506: Hôtel Terminus: The Life and Times of Klaus Barbie ----------
# ------ Added 507: The Milagro Beanfield War ----------
# ------ Added 508: Tin Toy ----------
# ------ Added 509: You Don't Have to Die ----------
# ------ Added 510: The Last Emperor ----------
# ------ Added 511: Moonstruck ----------
# ------ Added 512: The Untouchables (film) ----------
# ------ Added 513: Babette's Feast ----------
# ------ Added 514: Dirty Dancing ----------
# ------ Added 515: Harry and the Hendersons ----------
# ------ Added 516: Innerspace ----------
# ------ Added 517: The Man Who Planted Trees (film) ----------
# ------ Added 518: Ray's Male Heterosexual Dance Hall ----------
# ------ Added 519: The Ten-Year Lunch ----------
# ------ Added 520: Wall Street (1987 film) ----------
# ------ Added 521: Young at Heart (1987 film) ----------
# ------ Added 522: RoboCop ----------
# ------ Added 523: Platoon (film) ----------
# ------ Added 524: A Room with a View (1985 film) ----------
# ------ Added 525: Hannah and Her Sisters ----------
# ------ Added 526: Aliens (film) ----------
# ------ Added 527: The Mission (1986 film) ----------
# ------ Added 528: Children of a Lesser God (film) ----------
# ------ Added 529: The Color of Money ----------
# ------ Added 530: Top Gun ----------
# ------ Added 531: Round Midnight (film) ----------
# ------ Added 532: Artie Shaw: Time Is All You've Got ----------
# ------ Added 533: The Assault (1986 film) ----------
# ------ Added 534: Down and Out in America ----------
# ------ Added 535: The Fly (1986 film) ----------
# ------ Added 536: A Greek Tragedy ----------
# ------ Added 537: Precious Images ----------
# ------ Added 538: Women – for America, for the World ----------
# ------ Added 539: Out of Africa (film) ----------
# ------ Added 540: Witness (1985 film) ----------
# ------ Added 541: Cocoon (film) ----------
# ------ Added 542: Prizzi's Honor ----------
# ------ Added 543: Back to the Future ----------
# ------ Added 544: Kiss of the Spider Woman (film) ----------
# ------ Added 545: Ran (film) ----------
# ------ Added 546: The Official Story ----------
# ------ Added 547: The Trip to Bountiful ----------
# ------ Added 548: White Nights (1985 film) ----------
# ------ Added 549: Anna & Bella ----------
# ------ Added 550: Broken Rainbow (film) ----------
# ------ Added 551: Mask (1985 film) ----------
# ------ Added 552: Molly's Pilgrim ----------
# ------ Added 553: Witness to War: Dr. Charlie Clements ----------
# ------ Added 554: Amadeus (film) ----------
# ------ Added 555: The Killing Fields (film) ----------
# ------ Added 556: A Passage to India (film) ----------
# ------ Added 557: Places in the Heart ----------
# ------ Added 558: Indiana Jones and the Temple of Doom ----------
# ------ Added 559: Charade (1984 film) ----------
# ------ Added 560: Dangerous Moves ----------
# ------ Added 561: Purple Rain (film) ----------
# ------ Added 562: The Stone Carvers (film) ----------
# ------ Added 563: The Times of Harvey Milk ----------
# ------ Added 564: Up (1984 film) ----------
# ------ Added 565: The Woman in Red (1984 film) ----------
# ------ Added 566: The River (1984 film) ----------
# ------ Added 567: Terms of Endearment ----------
# ------ Added 568: The Right Stuff (film) ----------
# ------ Added 569: Fanny and Alexander ----------
# ------ Added 570: Tender Mercies ----------
# ------ Added 571: Yentl (film) ----------
# ------ Added 572: Flashdance ----------
# ------ Added 573: Boys and Girls (1983 film) ----------
# ------ Added 574: Flamenco at 5:15 ----------
# ------ Added 575: He Makes Me Feel Like Dancin' ----------
# ------ Added 576: Sundae in New York ----------
# ------ Added 577: The Year of Living Dangerously (film) ----------
# ------ Added 578: Return of the Jedi ----------
# ------ Added 579: Gandhi (film) ----------
# ------ Added 580: E.T. the Extra-Terrestrial ----------
# ------ Added 581: An Officer and a Gentleman ----------
# ------ Added 582: Tootsie ----------
# ------ Added 583: Sophie's Choice (film) ----------
# ------ Added 584: Missing (1982 film) ----------
# ------ Added 585: If You Love This Planet ----------
# ------ Added 586: Just Another Missing Kid ----------
# ------ Added 587: A Shocking Accident ----------
# ------ Added 588: Tango (1981 film) ----------
# ------ Added 589: Begin the Beguine (film) ----------
# ------ Added 590: Quest for Fire (film) ----------
# ------ Added 591: Chariots of Fire ----------
# ------ Added 592: Raiders of the Lost Ark ----------
# ------ Added 593: Reds (film) ----------
# ------ Added 594: On Golden Pond (1981 film) ----------
# ------ Added 595: Arthur (1981 film) ----------
# ------ Added 596: An American Werewolf in London ----------
# ------ Added 597: Close Harmony (1981 film) ----------
# ------ Added 598: Crac ----------
# ------ Added 599: Genocide (1981 film) ----------
# ------ Added 600: Mephisto (1981 film) ----------
# ------ Added 601: Violet (1981 film) ----------
# ------ Added 602: Ordinary People ----------
# ------ Added 603: Tess (1979 film) ----------
# ------ Added 604: Raging Bull ----------
# ------ Added 605: Fame (1980 film) ----------
# ------ Added 606: Melvin and Howard ----------
# ------ Added 607: Coal Miner's Daughter (film) ----------
# ------ Added 608: The Empire Strikes Back ----------
# ------ Added 609: The Dollar Bottom ----------
# ------ Added 610: The Fly (1980 film) ----------
# ------ Added 611: From Mao to Mozart: Isaac Stern in China ----------
# ------ Added 612: Karl Hess: Toward Liberty ----------
# ------ Added 613: Moscow Does Not Believe in Tears ----------
# ------ Added 614: Kramer vs. Kramer ----------
# ------ Added 615: All That Jazz (film) ----------
# ------ Added 616: Apocalypse Now ----------
# ------ Added 617: Norma Rae ----------
# ------ Added 618: Breaking Away ----------
# ------ Added 619: Alien (film) ----------
# ------ Added 620: Being There ----------
# ------ Added 621: A Little Romance ----------
# ------ Added 622: Best Boy (film) ----------
# ------ Added 623: Board and Care ----------
# ------ Added 624: Every Child (film) ----------
# ------ Added 625: Paul Robeson: Tribute to an Artist ----------
# ------ Added 626: The Tin Drum (film) ----------
# ------ Added 627: The Black Stallion (film) ----------
# ------ Added 628: The Deer Hunter ----------
# ------ Added 629: Coming Home (1978 film) ----------
# ------ Added 630: Midnight Express (film) ----------
# ------ Added 631: Heaven Can Wait (1978 film) ----------
# ------ Added 632: Days of Heaven ----------
# ------ Added 633: California Suite (film) ----------
# ------ Added 634: The Buddy Holly Story ----------
# ------ Added 635: Death on the Nile (1978 film) ----------
# ------ Added 636: The Flight of the Gossamer Condor ----------
# ------ Added 637: Get Out Your Handkerchiefs ----------
# ------ Added 638: Scared Straight! ----------
# ------ Added 639: Special Delivery (1978 film) ----------
# ------ Added 640: Teenage Father ----------
# ------ Added 641: Thank God It's Friday (film) ----------
# ------ Added 642: Superman (1978 film) ----------
# ------ Added 643: Annie Hall ----------
# ------ Added 644: Star Wars (film) ----------
# ------ Added 645: Julia (1977 film) ----------
# ------ Added 646: Close Encounters of the Third Kind ----------
# ------ Added 647: The Goodbye Girl ----------
# ------ Added 648: A Little Night Music (film) ----------
# ------ Added 649: Gravity Is My Enemy ----------
# ------ Added 650: I'll Find a Way ----------
# ------ Added 651: Madame Rosa ----------
# ------ Added 652: The Sand Castle (film) ----------
# ------ Added 653: Who Are the DeBolts? And Where Did They Get Nineteen Kids? ----------
# ------ Added 654: You Light Up My Life (film) ----------
# ------ Added 655: Rocky ----------
# ------ Added 656: Network (1976 film) ----------
# ------ Added 657: All the President's Men (film) ----------
# ------ Added 658: Bound for Glory (1976 film) ----------
# ------ Added 659: A Star Is Born (1976 film) ----------
# ------ Added 660: Fellini's Casanova ----------
# ------ Added 661: The Omen ----------
# ------ Added 662: Black and White in Color ----------
# ------ Added 663: Harlan County, USA ----------
# ------ Added 664: In the Region of Ice ----------
# ------ Added 665: Leisure (film) ----------
# ------ Added 666: Number Our Days ----------
# ------ Added 667: King Kong (1976 film) ----------
# ------ Added 668: Logan's Run (film) ----------
# ------ Added 669: One Flew Over the Cuckoo's Nest (film) ----------
# ------ Added 670: Barry Lyndon ----------
# ------ Added 671: Jaws (film) ----------
# ------ Added 672: Dog Day Afternoon ----------
# ------ Added 673: Nashville (film) ----------
# ------ Added 674: Shampoo (film) ----------
# ------ Added 675: The Sunshine Boys (1975 film) ----------
# ------ Added 676: Angel and Big Joe ----------
# ------ Added 677: Dersu Uzala (1975 film) ----------
# ------ Added 678: The End of the Game (1975 film) ----------
# ------ Added 679: Great (1975 film) ----------
# ------ Added 680: The Man Who Skied Down Everest ----------
# ------ Added 681: The Hindenburg (film) ----------
# ------ Added 682: The Godfather: Part II ----------
# ------ Added 683: The Towering Inferno ----------
# ------ Added 684: The Great Gatsby (1974 film) ----------
# ------ Added 685: Chinatown (1974 film) ----------
# ------ Added 686: Murder on the Orient Express (1974 film) ----------
# ------ Added 687: Earthquake (1974 film) ----------
# ------ Added 688: Alice Doesn't Live Here Anymore ----------
# ------ Added 689: Amarcord ----------
# ------ Added 690: Harry and Tonto ----------
# ------ Added 691: Closed Mondays ----------
# ------ Added 692: Don't (1974 film) ----------
# ------ Added 693: Hearts and Minds (film) ----------
# ------ Added 694: One-Eyed Men Are Kings ----------
# ------ Added 695: The Sting ----------
# ------ Added 696: The Exorcist (film) ----------
# ------ Added 697: The Way We Were ----------
# ------ Added 698: Cries and Whispers ----------
# ------ Added 699: A Touch of Class (film) ----------
# ------ Added 700: Day for Night (film) ----------
# ------ Added 701: Paper Moon (film) ----------
# ------ Added 702: The Paper Chase (film) ----------
# ------ Added 703: Save the Tiger ----------
# ------ Added 704: The Bolero ----------
# ------ Added 705: Frank Film ----------
# ------ Added 706: The Great American Cowboy ----------
# ------ Added 707: Princeton: A Search for Answers ----------
# ------ Added 708: The Godfather ----------
# ------ Added 709: Cabaret (1972 film) ----------
# ------ Added 710: The Poseidon Adventure (1972 film) ----------
# ------ Added 711: Travels with My Aunt (film) ----------
# ------ Added 712: Butterflies Are Free ----------
# ------ Added 713: The Candidate (1972 film) ----------
# ------ Added 714: The Discreet Charm of the Bourgeoisie ----------
# ------ Added 715: A Christmas Carol (1971 film) ----------
# ------ Added 716: Limelight (1952 film) ----------
# ------ Added 717: Marjoe ----------
# ------ Added 718: Norman Rockwell's World... An American Dream ----------
# ------ Added 719: This Tiny World ----------
# ------ Added 720: The French Connection (film) ----------
# ------ Added 721: Fiddler on the Roof (film) ----------
# ------ Added 722: The Last Picture Show ----------
# ------ Added 723: Nicholas and Alexandra ----------
# ------ Added 724: Sentinels of Silence ----------
# ------ Added 725: Bedknobs and Broomsticks ----------
# ------ Added 726: Summer of '42 ----------
# ------ Added 727: The Garden of the Finzi-Continis (film) ----------
# ------ Added 728: The Hospital ----------
# ------ Added 729: Klute ----------
# ------ Added 730: Shaft (1971 film) ----------
# ------ Added 731: The Crunch Bird ----------
# ------ Added 732: The Hellstrom Chronicle ----------
# ------ Added 733: Patton (film) ----------
# ------ Added 734: Ryan's Daughter ----------
# ------ Added 735: Airport (1970 film) ----------
# ------ Added 736: Love Story (1970 film) ----------
# ------ Added 737: MASH (film) ----------
# ------ Added 738: Tora! Tora! Tora! ----------
# ------ Added 739: Women in Love (film) ----------
# ------ Added 740: Lovers and Other Strangers ----------
# ------ Added 741: Woodstock (film) ----------
# ------ Added 742: Cromwell (film) ----------
# ------ Added 743: Investigation of a Citizen Above Suspicion ----------
# ------ Added 744: Interviews with My Lai Veterans ----------
# ------ Added 745: Is It Always Right to Be Right? ----------
# ------ Added 746: Let It Be (1970 film) ----------
# ------ Added 747: The Resurrection of Broncho Billy ----------
# ------ Added 748: Midnight Cowboy ----------
# ------ Added 749: Butch Cassidy and the Sundance Kid ----------
# ------ Added 750: Hello, Dolly! (film) ----------
# ------ Added 751: Z (1969 film) ----------
# ------ Added 752: Anne of the Thousand Days ----------
# ------ Added 753: They Shoot Horses, Don't They? (film) ----------
# ------ Added 754: Marooned (1969 film) ----------
# ------ Added 755: The Magic Machines ----------
# ------ Added 756: The Prime of Miss Jean Brodie (film) ----------
# ------ Added 757: True Grit (1969 film) ----------
# ------ Added 758: Arthur Rubinstein – The Love of Life ----------
# ------ Added 759: Cactus Flower (film) ----------
# ------ Added 760: Czechoslovakia 1968 ----------
# ------ Added 761: It's Tough to Be a Bird ----------
# ------ Added 762: Oliver! (film) ----------
# ------ Added 763: The Lion in Winter (1968 film) ----------
# ------ Added 764: Romeo and Juliet (1968 film) ----------
# ------ Added 765: Funny Girl (film) ----------
# ------ Added 766: 2001: A Space Odyssey (film) ----------
# ------ Added 767: Bullitt ----------
# ------ Added 768: The Producers (1967 film) ----------
# ------ Added 769: Rosemary's Baby (film) ----------
# ------ Added 770: The Subject Was Roses (film) ----------
# ------ Added 771: The Thomas Crown Affair (1968 film) ----------
# ------ Added 772: War and Peace (film series) ----------
# ------ Added 773: Charly ----------
# ------ Added 774: Journey into Self (1968 film) ----------
# ------ Added 775: Robert Kennedy Remembered ----------
# ------ Added 776: Why Man Creates ----------
# ------ Added 777: Winnie the Pooh and the Blustery Day ----------
# ------ Added 778: Planet of the Apes (1968 film) ----------
# ------ Added 779: In the Heat of the Night (film) ----------
# ------ Added 780: Camelot (film) ----------
# ------ Added 781: Bonnie and Clyde (film) ----------
# ------ Added 782: Guess Who's Coming to Dinner ----------
# ------ Added 783: Doctor Dolittle (1967 film) ----------
# ------ Added 784: The Graduate ----------
# ------ Added 785: Thoroughly Modern Millie ----------
# ------ Added 786: Cool Hand Luke ----------
# ------ Added 787: The Dirty Dozen ----------
# ------ Added 788: A Place to Stand (film) ----------
# ------ Added 789: The Anderson Platoon ----------
# ------ Added 790: The Box (1967 film) ----------
# ------ Added 791: Closely Watched Trains ----------
# ------ Added 792: The Redwoods ----------
# ------ Added 793: A Man for All Seasons (1966 film) ----------
# ------ Added 794: Who's Afraid of Virginia Woolf? (film) ----------
# ------ Added 795: Grand Prix (1966 film) ----------
# ------ Added 796: Fantastic Voyage ----------
# ------ Added 797: A Man and a Woman ----------
# ------ Added 798: Born Free ----------
# ------ Added 799: The Fortune Cookie ----------
# ------ Added 800: A Funny Thing Happened on the Way to the Forum (film) ----------
# ------ Added 801: A Herb Alpert and the Tijuana Brass Double Feature ----------
# ------ Added 802: The War Game ----------
# ------ Added 803: Wild Wings ----------
# ------ Added 804: A Year Toward Tomorrow ----------
# ------ Added 805: The Sound of Music (film) ----------
# ------ Added 806: Doctor Zhivago (film) ----------
# ------ Added 807: Darling (1965 film) ----------
# ------ Added 808: Ship of Fools (film) ----------
# ------ Added 809: Cat Ballou ----------
# ------ Added 810: The Great Race ----------
# ------ Added 811: A Patch of Blue ----------
# ------ Added 812: A Thousand Clowns ----------
# ------ Added 813: The Shop on Main Street ----------
# ------ Added 814: The Sandpiper ----------
# ------ Added 815: The Eleanor Roosevelt Story ----------
# ------ Added 816: To Be Alive! ----------
# ------ Added 817: 7 Faces of Dr. Lao ----------
# ------ Added 818: 7th Heaven (1927 film) ----------
# ------ Added 819: 20,000 Leagues Under the Sea (1954 film) ----------
# ------ Added 820: Adventures of Don Juan ----------
# ------ Added 821: The Adventures of Robin Hood ----------
# ------ Added 822: The African Queen (film) ----------
# ------ Added 823: Air Force (film) ----------
# ------ Added 824: The Alamo (1960 film) ----------
# ------ Added 825: The Alaskan Eskimo ----------
# ------ Added 826: Albert Schweitzer (film) ----------
# ------ Added 827: Alexander's Ragtime Band (film) ----------
# ------ Added 828: All About Eve ----------
# ------ Added 829: All Quiet on the Western Front (1930 film) ----------
# ------ Added 830: The Devil and Daniel Webster (film) ----------
# ------ Added 831: All the King's Men (1949 film) ----------
# ------ Added 832: Ama Girls ----------
# ------ Added 833: America America ----------
# ------ Added 834: An American in Paris (film) ----------
# ------ Added 835: Amphibious Fighters ----------
# ------ Added 836: Anastasia (1956 film) ----------
# ------ Added 837: Anchors Aweigh (film) ----------
# ------ Added 838: Anna and the King of Siam (film) ----------
# ------ Added 839: Annie Get Your Gun (film) ----------
# ------ Added 840: Anthony Adverse ----------
# ------ Added 841: The Apartment ----------
# ------ Added 842: Aquatic House Party ----------
# ------ Added 843: Arise, My Love ----------
# ------ Added 844: Around the World in 80 Days (1956 film) ----------
# ------ Added 845: The Awful Truth ----------
# ------ Added 846: The Bachelor and the Bobby-Soxer ----------
# ------ Added 847: The Bad and the Beautiful ----------
# ------ Added 848: Bad Girl (1931 film) ----------
# ------ Added 849: The Barefoot Contessa ----------
# ------ Added 850: The Battle of Midway (film) ----------
# ------ Added 851: Battleground (film) ----------
# ------ Added 852: Bear Country (film) ----------
# ------ Added 853: Becket (1964 film) ----------
# ------ Added 854: The Bells of St. Mary's ----------
# ------ Added 855: Ben-Hur (1959 film) ----------
# ------ Added 856: Benjy (film) ----------
# ------ Added 857: The Bespoke Overcoat ----------
# ------ Added 858: The Best Years of Our Lives ----------
# ------ Added 859: Beyond the Line of Duty ----------
# ------ Added 860: Bicycle Thieves ----------
# ------ Added 861: The Big Broadcast of 1938 ----------
# ------ Added 862: The Big Country ----------
# ------ Added 863: The Big House (1930 film) ----------
# ------ Added 864: Bill and Coo ----------
# ------ Added 865: Birds Anonymous ----------
# ------ Added 866: The Bishop's Wife ----------
# ------ Added 867: Black Fox: The Rise and Fall of Adolf Hitler ----------
# ------ Added 868: Black Narcissus ----------
# ------ Added 869: Black Orpheus ----------
# ------ Added 870: The Black Swan (film) ----------
# ------ Added 871: Blithe Spirit (1945 film) ----------
# ------ Added 872: Blood and Sand (1941 film) ----------
# ------ Added 873: Blood on the Sun ----------
# ------ Added 874: Blossoms in the Dust ----------
# ------ Added 875: Body and Soul (1947 film) ----------
# ------ Added 876: Bored of Education ----------
# ------ Added 877: Born Yesterday (1950 film) ----------
# ------ Added 878: A Boy and His Dog (1946 film) ----------
# ------ Added 879: Boys Town (film) ----------
# ------ Added 880: The Brave One (1956 film) ----------
# ------ Added 881: Breakfast at Tiffany's (film) ----------
# ------ Added 882: The Sound Barrier ----------
# ------ Added 883: The Bridge of San Luis Rey (1929 film) ----------
# ------ Added 884: The Bridge on the River Kwai ----------
# ------ Added 885: The Bridges at Toko-Ri ----------
# ------ Added 886: Broadway Melody of 1936 ----------
# ------ Added 887: The Broadway Melody ----------
# ------ Added 888: Broken Lance ----------
# ------ Added 889: Busy Little Bears ----------
# ------ Added 890: BUtterfield 8 ----------
# ------ Added 891: Calamity Jane (film) ----------
# ------ Added 892: Call Me Madam (film) ----------
# ------ Added 893: Captain Carey, U.S.A. ----------
# ------ Added 894: Captains Courageous (1937 film) ----------
# ------ Added 895: Casablanca (film) ----------
# ------ Added 896: Casals Conducts: 1964 ----------
# ------ Added 897: The Cat Concerto ----------
# ------ Added 898: Cavalcade (1933 film) ----------
# ------ Added 899: Chagall (film) ----------
# ------ Added 900: The Champ (1931 film) ----------
# ------ Added 901: Champion (1949 film) ----------
# ------ Added 902: A Chance to Live ----------
# ------ Added 903: The Charge of the Light Brigade (1936 film) ----------
# ------ Added 904: The Chicken (film) ----------
# ------ Added 905: Churchill's Island ----------
# ------ Added 906: Cimarron (1931 film) ----------
# ------ Added 907: The Circus (1928 film) ----------
# ------ Added 908: Citizen Kane ----------
# ------ Added 909: City of Wax ----------
# ------ Added 910: Cleopatra (1934 film) ----------
# ------ Added 911: Cleopatra (1963 film) ----------
# ------ Added 912: Climbing the Matterhorn ----------
# ------ Added 913: Come and Get It (1936 film) ----------
# ------ Added 914: Come Back, Little Sheba (1952 film) ----------
# ------ Added 915: Coquette (film) ----------
# ------ Added 916: The Country Cousin ----------
# ------ Added 917: The Country Girl (1954 film) ----------
# ------ Added 918: Cover Girl (film) ----------
# ------ Added 919: The Cowboy and the Lady (1938 film) ----------
# ------ Added 920: Crash Dive ----------
# ------ Added 921: Crashing the Water Barrier ----------
# ------ Added 922: The Critic (1963 film) ----------
# ------ Added 923: La Cucaracha (1934 film) ----------
# ------ Added 924: Cyrano de Bergerac (1950 film) ----------
# ------ Added 925: A Damsel in Distress (1937 film) ----------
# ------ Added 926: Dangerous (1935 film) ----------
# ------ Added 927: The Dark Angel (1935 film) ----------
# ------ Added 928: The Dawn Patrol (1930 film) ----------
# ------ Added 929: Day of the Painter ----------
# ------ Added 930: Daybreak in Udi ----------
# ------ Added 931: Days of Wine and Roses (film) ----------
# ------ Added 932: December 7th: The Movie ----------
# ------ Added 933: Declaration of Independence (film) ----------
# ------ Added 934: The Defiant Ones ----------
# ------ Added 935: Der Fuehrer's Face ----------
# ------ Added 936: Desert Victory ----------
# ------ Added 937: Design for Death ----------
# ------ Added 938: Designing Woman ----------
# ------ Added 939: Destination Moon (film) ----------
# ------ Added 940: The Diary of Anne Frank (1959 film) ----------
# ------ Added 941: Disraeli (1929 film) ----------
# ------ Added 942: The Divine Lady ----------
# ------ Added 943: Divorce Italian Style ----------
# ------ Added 944: The Divorcee ----------
# ------ Added 945: Dodsworth (film) ----------
# ...
# ------ Added 1056: Johnny Eager ----------
# ------ Added 1057: The Joker Is Wild ----------
# ------ Added 1058: The Jolson Story ----------
# ------ Added 1059: Judgment at Nuremberg ----------
# ------ Added 1060: Julius Caesar (1953 film) ----------
# ------ Added 1061: Kentucky (film) ----------
# ------ Added 1062: Key Largo (film) ----------
# ------ Added 1063: The King and I (1956 film) ----------
# ------ Added 1064: King of Jazz ----------
# ------ Added 1065: King Solomon's Mines (1950 film) ----------
# ------ Added 1066: Kitty Foyle (film) ----------
# ------ Added 1067: Knighty Knight Bugs ----------
# ------ Added 1068: Kokoda Front Line! ----------
# ------ Added 1069: Kon-Tiki (1950 film) ----------
# ------ Added 1070: Krakatoa (film) ----------
# ------ Added 1071: Kukan ----------
# ------ Added 1072: La Strada ----------
# ------ Added 1073: La Dolce Vita ----------
# ------ Added 1074: Lady Be Good (1941 film) ----------
# ------ Added 1075: The Last Command (1928 film) ----------
# ------ Added 1076: Laura (1944 film) ----------
# ------ Added 1077: The Lavender Hill Mob ----------
# ------ Added 1078: Lawrence of Arabia (film) ----------
# ------ Added 1079: Leave Her to Heaven ----------
# ------ Added 1080: Lend a Paw ----------
# ------ Added 1081: Les Girls ----------
# ------ Added 1082: A Letter to Three Wives ----------
# ------ Added 1083: The Life of Emile Zola ----------
# ------ Added 1084: Light in the Window ----------
# ------ Added 1085: Lili ----------
# ------ Added 1086: Lilies of the Field (1963 film) ----------
# ------ Added 1087: The Kidnappers ----------
# ------ Added 1088: The Little Orphan ----------
# ------ Added 1089: Little Women (1933 film) ----------
# ------ Added 1090: Little Women (1949 film) ----------
# ------ Added 1091: The Lives of a Bengal Lancer (film) ----------
# ------ Added 1092: The Living Desert ----------
# ------ Added 1093: The Longest Day (film) ----------
# ------ Added 1094: Lost Horizon (1937 film) ----------
# ------ Added 1095: The Lost Weekend (film) ----------
# ------ Added 1096: Love Is a Many-Splendored Thing (film) ----------
# ------ Added 1097: Love Me or Leave Me (film) ----------
# ------ Added 1098: Lust for Life (1956 film) ----------
# ------ Added 1099: Magoo's Puddle Jumper ----------
# ------ Added 1100: Main Street on the March! ----------
# ------ Added 1101: The Man Who Knew Too Much (1956 film) ----------
# ------ Added 1102: Manhattan Melodrama ----------
# ------ Added 1103: Marie-Louise (film) ----------
# ------ Added 1104: Marty (film) ----------
# ------ Added 1105: Mary Poppins (film) ----------
# ------ Added 1106: Men Against the Arctic ----------
# ------ Added 1107: The Merry Widow (1934 film) ----------
# ------ Added 1108: A Midsummer Night's Dream (1935 film) ----------
# ------ Added 1109: Mighty Joe Young (1949 film) ----------
# ------ Added 1110: Mildred Pierce (film) ----------
# ------ Added 1111: The Milky Way (1940 film) ----------
# ------ Added 1112: Min and Bill ----------
# ------ Added 1113: Miracle on 34th Street ----------
# ------ Added 1114: The Miracle Worker (1962 film) ----------
# ------ Added 1115: Mister Roberts (1955 film) ----------
# ------ Added 1116: Monsieur Vincent ----------
# ------ Added 1117: Moonbird ----------
# ------ Added 1118: The More the Merrier ----------
# ------ Added 1119: Morning Glory (1933 film) ----------
# ------ Added 1120: Moscow Strikes Back ----------
# ------ Added 1121: Mother Wore Tights ----------
# ------ Added 1122: Moulin Rouge (1952 film) ----------
# ------ Added 1123: Mouse Trouble ----------
# ------ Added 1124: Mr. Deeds Goes to Town ----------
# ------ Added 1125: Mr. Smith Goes to Washington ----------
# ------ Added 1126: Mrs. Miniver ----------
# ------ Added 1127: Munro (film) ----------
# ------ Added 1128: The Music Box ----------
# ------ Added 1129: The Music Man (1962 film) ----------
# ------ Added 1130: Mutiny on the Bounty (1935 film) ----------
# ------ Added 1131: My Fair Lady (film) ----------
# ------ Added 1132: Mon Oncle ----------
# ------ Added 1133: My Gal Sal ----------
# ------ Added 1134: The Naked City ----------
# ------ Added 1135: National Velvet (film) ----------
# ------ Added 1136: Nature's Half Acre ----------
# ------ Added 1137: Naughty Marietta (film) ----------
# ------ Added 1138: Neighbours (1952 film) ----------
# ------ Added 1139: Neptune's Daughter (1949 film) ----------
# ------ Added 1140: Never on Sunday ----------
# ------ Added 1141: The Night of the Iguana (film) ----------
# ------ Added 1142: Nights of Cabiria ----------
# ------ Added 1143: Nine from Little Rock ----------
# ------ Added 1144: None but the Lonely Heart (film) ----------
# ------ Added 1145: North West Mounted Police (film) ----------
# ------ Added 1146: Now, Voyager ----------
# ------ Added 1147: An Occurrence at Owl Creek Bridge (film) ----------
# ------ Added 1148: Of Pups and Puzzles ----------
# ------ Added 1149: Oklahoma! (1955 film) ----------
# ------ Added 1150: The Old Man and the Sea (1958 film) ----------
# ------ Added 1151: The Old Mill ----------
# ------ Added 1152: On the Town (film) ----------
# ------ Added 1153: On the Waterfront ----------
# ------ Added 1154: One Hundred Men and a Girl ----------
# ------ Added 1155: One Night of Love ----------
# ------ Added 1156: One Way Passage ----------
# ------ Added 1157: Overture to The Merry Wives of Windsor ----------
# ------ Added 1158: The Paleface (1948 film) ----------
# ------ Added 1159: Panic in the Streets (film) ----------
# ------ Added 1160: Papa's Delicate Condition ----------
# ------ Added 1161: The Patriot (1928 film) ----------
# ------ Added 1162: Penny Wisdom ----------
# ------ Added 1163: Phantom of the Opera (1943 film) ----------
# ------ Added 1164: The Philadelphia Story (film) ----------
# ------ Added 1165: Picnic (1955 film) ----------
# ------ Added 1166: The Picture of Dorian Gray (1945 film) ----------
# ------ Added 1167: Pillow Talk (film) ----------
# ------ Added 1168: The Pink Phink ----------
# ------ Added 1169: Pinocchio (1940 film) ----------
# ------ Added 1170: A Place in the Sun (1951 film) ----------
# ------ Added 1171: Plymouth Adventure ----------
# ------ Added 1172: Pollyanna (1960 film) ----------
# ------ Added 1173: Porgy and Bess (film) ----------
# ------ Added 1174: Portrait of Jennie ----------
# ------ Added 1175: Prelude to War ----------
# ------ Added 1176: Pride and Prejudice (1940 film) ----------
# ------ Added 1177: The Pride of the Yankees ----------
# ------ Added 1178: Princess O'Rourke ----------
# ------ Added 1179: The Private Life of Henry VIII ----------
# ------ Added 1180: The Private Life of the Gannets ----------
# ------ Added 1181: Project Hope (film) ----------
# ------ Added 1182: The Public Pays ----------
# ------ Added 1183: Pygmalion (1938 film) ----------
# ------ Added 1184: Quicker'n a Wink ----------
# ------ Added 1185: The Quiet Man ----------
# ------ Added 1186: Quiet Please! ----------
# ------ Added 1187: The Rains Came ----------
# ------ Added 1188: Rashomon ----------
# ------ Added 1189: The Razor's Edge (1946 film) ----------
# ------ Added 1190: Reap the Wild Wind ----------
# ------ Added 1191: Rebecca (1940 film) ----------
# ------ Added 1192: The Red Balloon ----------
# ------ Added 1193: The Red Shoes (1948 film) ----------
# ------ Added 1194: The Robe (film) ----------
# ------ Added 1195: Robert Frost: A Lover's Quarrel with the World ----------
# ------ Added 1196: Roman Holiday ----------
# ------ Added 1197: Room at the Top (1959 film) ----------
# ------ Added 1198: The Rose Tattoo (film) ----------
# ------ Added 1199: Sabrina (1954 film) ----------
# ------ Added 1200: Samson and Delilah (1949 film) ----------
# ------ Added 1201: Samurai I: Musashi Miyamoto ----------
# ------ Added 1202: San Francisco (1936 film) ----------
# ------ Added 1203: Sayonara ----------
# ------ Added 1204: The Scoundrel (1935 film) ----------
# ------ Added 1205: The Sea Around Us (film) ----------
# ------ Added 1206: Seal Island (film) ----------
# ------ Added 1207: The Search ----------
# ------ Added 1208: Seawards the Great Ships ----------
# ------ Added 1209: The Secret Land ----------
# ------ Added 1210: Seeds of Destiny ----------
# ------ Added 1211: Separate Tables (film) ----------
# ------ Added 1212: Serengeti Shall Not Die ----------
# ------ Added 1213: Sergeant York (film) ----------
# ------ Added 1214: Seven Brides for Seven Brothers ----------
# ------ Added 1215: Seven Days to Noon ----------
# ------ Added 1216: The Seventh Veil ----------
# ------ Added 1217: Shane (film) ----------
# ------ Added 1218: Shanghai Express (film) ----------
# ------ Added 1219: She Wore a Yellow Ribbon ----------
# ------ Added 1220: Shoeshine (film) ----------
# ------ Added 1221: The Silent World ----------
# ------ Added 1222: The Sin of Madelon Claudet ----------
# ------ Added 1223: Since You Went Away ----------
# ------ Added 1224: Skippy (film) ----------
# ------ Added 1225: Sky Above and Mud Beneath ----------
# ------ Added 1226: The Snake Pit ----------
# ------ Added 1227: Snow White and the Seven Dwarfs (1937 film) ----------
# ------ Added 1228: So Much for So Little ----------
# ------ Added 1229: So This Is Harris! ----------
# ------ Added 1230: The Solid Gold Cadillac ----------
# ------ Added 1231: Some Like It Hot ----------
# ------ Added 1232: Somebody Up There Likes Me (1956 film) ----------
# ------ Added 1233: The Song of Bernadette (film) ----------
# ------ Added 1234: Song of the South ----------
# ------ Added 1235: Song Without End ----------
# ------ Added 1236: Sons and Lovers (film) ----------
# ------ Added 1237: Sons of Liberty (film) ----------
# ------ Added 1238: South Pacific (1958 film) ----------
# ------ Added 1239: Spartacus (film) ----------
# ------ Added 1240: Spawn of the North ----------
# ------ Added 1241: Speaking of Animals and Their Families ----------
# ------ Added 1242: Speedy Gonzales (film) ----------
# ------ Added 1243: Spellbound (1945 film) ----------
# ------ Added 1244: Splendor in the Grass ----------
# ------ Added 1245: Stagecoach (1939 film) ----------
# ------ Added 1246: Stairway to Light ----------
# ------ Added 1247: Stalag 17 ----------
# ------ Added 1248: Star in the Night ----------
# ------ Added 1249: A Star Is Born (1937 film) ----------
# ------ Added 1250: State Fair (1945 film) ----------
# ------ Added 1251: The Story of Louis Pasteur ----------
# ------ Added 1252: The Stratton Story ----------
# ------ Added 1253: Street Angel (1928 film) ----------
# ------ Added 1254: A Streetcar Named Desire (1951 film) ----------
# ------ Added 1255: Strike Up the Band (film) ----------
# ------ Added 1256: Surogat ----------
# ------ Added 1257: Sundays and Cybele ----------
# ------ Added 1258: Sunrise: A Song of Two Humans ----------
# ------ Added 1259: Sunset Boulevard (film) ----------
# ------ Added 1260: Survival City ----------
# ------ Added 1261: Suspicion (1941 film) ----------
# ------ Added 1262: Sweet Bird of Youth (1962 film) ----------
# ------ Added 1263: Sweethearts (1938 film) ----------
# ------ Added 1264: Swing Time (film) ----------
# ------ Added 1265: Symphony of a City ----------
# ------ Added 1266: Tabu: A Story of the South Seas ----------
# ------ Added 1267: Target for Tonight ----------
# ------ Added 1268: Teddy, the Rough Rider ----------
# ------ Added 1269: Tempest (1928 film) ----------
# ------ Added 1270: The Ten Commandments (1956 film) ----------
# ------ Added 1271: That Hamilton Woman ----------
# ------ Added 1272: That Mothers Might Live ----------
# ------ Added 1273: The Thief of Bagdad (1940 film) ----------
# ------ Added 1274: The Third Man ----------
# ------ Added 1275: Thirty Seconds Over Tokyo ----------
# ------ Added 1276: This Above All (film) ----------
# ------ Added 1277: This Is the Army ----------
# ------ Added 1278: This Land Is Mine (film) ----------
# ------ Added 1279: This Mechanical Age ----------
# ------ Added 1280: Three Coins in the Fountain (film) ----------
# ------ Added 1281: The Three Faces of Eve ----------
# ------ Added 1282: Three Little Pigs (film) ----------
# ------ Added 1283: Three Orphan Kittens ----------
# ------ Added 1284: Through a Glass Darkly (film) ----------
# ------ Added 1285: Thunderball (film) ----------
# ------ Added 1286: Thursday's Children ----------
# ------ Added 1287: The Time Machine (1960 film) ----------
# ------ Added 1288: A Time Out of War ----------
# ------ Added 1289: Tin Pan Alley (film) ----------
# ------ Added 1290: The Titan: Story of Michelangelo ----------
# ------ Added 1291: Titanic (1953 film) ----------
# ------ Added 1292: To Catch a Thief ----------
# ------ Added 1293: To Each His Own (1946 film) ----------
# ------ Added 1294: To Kill a Mockingbird (film) ----------
# ------ Added 1295: Tom Jones (1963 film) ----------
# ------ Added 1296: Tom Thumb (film) ----------
# ------ Added 1297: Toot, Whistle, Plunk and Boom ----------
# ------ Added 1298: Topkapi (film) ----------
# ------ Added 1299: The Tortoise and the Hare (film) ----------
# ------ Added 1300: Torture Money ----------
# ------ Added 1301: Toward Independence ----------
# ------ Added 1302: Transatlantic (1931 film) ----------
# ------ Added 1303: The Treasure of the Sierra Madre (film) ----------
# ------ Added 1304: A Tree Grows in Brooklyn (1945 film) ----------
# ------ Added 1305: The True Glory ----------
# ------ Added 1306: The True Story of the Civil War ----------
# ------ Added 1307: Tweetie Pie ----------
# ------ Added 1308: Twelve O'Clock High ----------
# ------ Added 1309: Two Arabian Knights ----------
# ------ Added 1310: The Two Mouseketeers ----------
# ------ Added 1311: Two Women ----------
# ------ Added 1312: The Ugly Duckling (1939 film) ----------
# ------ Added 1313: Underworld (1927 film) ----------
# ------ Added 1314: The V.I.P.s (film) ----------
# ------ Added 1315: Perfect Strangers (1945 film) ----------
# ------ Added 1316: Van Gogh (1948 film) ----------
# ------ Added 1317: The Vanishing Prairie ----------
# ------ Added 1318: The Virgin Spring ----------
# ------ Added 1319: Viva Villa! ----------
# ------ Added 1320: Viva Zapata! ----------
# ------ Added 1321: Waikiki Wedding ----------
# ------ Added 1322: The Walls of Malapaga ----------
# ------ Added 1323: The War of the Worlds (1953 film) ----------
# ------ Added 1324: Watch on the Rhine ----------
# ------ Added 1325: Water Birds ----------
# ------ Added 1326: The Way of All Flesh (1927 film) ----------
# ------ Added 1327: West Side Story (1961 film) ----------
# ------ Added 1328: The Westerner (1940 film) ----------
# ------ Added 1329: The Wetback Hound ----------
# ------ Added 1330: What Ever Happened to Baby Jane? (1962 film) ----------
# ------ Added 1331: When Tomorrow Comes (film) ----------
# ------ Added 1332: When Magoo Flew ----------
# ------ Added 1333: When Worlds Collide (1951 film) ----------
# ------ Added 1334: White Shadows in the South Seas ----------
# ------ Added 1335: White Wilderness (film) ----------
# ------ Added 1336: Who's Who in Animal Land ----------
# ------ Added 1337: Why Korea? ----------
# ------ Added 1338: Wilson (1944 film) ----------
# ------ Added 1339: Wings (1927 film) ----------
# ------ Added 1340: Wings Over Everest ----------
# ------ Added 1341: With a Song in My Heart (film) ----------
# ------ Added 1342: With Byrd at the South Pole ----------
# ------ Added 1343: With the Marines at Tarawa ----------
# ------ Added 1344: The Wizard of Oz (1939 film) ----------
# ------ Added 1345: Woman of the Year ----------
# ------ Added 1346: Wonder Man (film) ----------
# ------ Added 1347: The Wonderful World of the Brothers Grimm ----------
# ------ Added 1348: World of Kids ----------
# ------ Added 1349: World Without Sun ----------
# ------ Added 1350: Wrestling Swordfish ----------
# ------ Added 1351: Written on the Wind ----------
# ------ Added 1352: Wuthering Heights (1939 film) ----------
# ------ Added 1353: Yankee Doodle Dandy ----------
# ------ Added 1354: The Yankee Doodle Mouse ----------
# ------ Added 1355: The Yearling (1946 film) ----------
# ------ Added 1356: Yesterday, Today and Tomorrow ----------
# ------ Added 1357: You Can't Take It with You (film) ----------
# ------ Added 1358: Zorba the Greek (film) ----------
# Finished mobile data

# %% [markdown]
# ## Construct Cumulative Dataset

# %% [markdown]
# References:
# - https://www.geeksforgeeks.org/append-to-json-file-using-python/#
# - Things I learned from example:
#     - the structure of the returned data from the API

# %%
# Load the JSON files: https://www.geeksforgeeks.org/append-to-json-file-using-python/#
my_file3 = open(r"academy_monthly_desktop_201507-202309.json", "r")
desktop_data = json.loads(my_file3.read())
my_file3.close()

my_file4 = open(r"academy_monthly_mobile_201507-202309.json", "r")
mobile_data = json.loads(my_file4.read())
my_file4.close()

cumulative_data = {}

article_count = 0

# For each article
for title in article_names:
    month_list = []
    
    # Modify the retrieved data -------------!!!!!!!!!!!! Got idea for this form of iterating from Prof example
    # Loop through all months of that article
    month_index = 0
    for month in desktop_data[title]: #????????
        
        # Add desktop and mobile view counts
        mobile_month_views = mobile_data[title][month_index]['views']
        desktop_month_views = desktop_data[title][month_index]['views']
        month['views'] = mobile_month_views + desktop_month_views
        
        # Reconstruct list of months
        month_list.append(month)
        
        # Store in a dictionary of articles
        cumulative_data[title] = month_list
        
    article_count += 1
    print("------ Added {}: {} ----------".format(article_count,title))

    
# Save to JSON file - Reference: https://www.geeksforgeeks.org/writing-to-file-in-python/
my_file5 = open(r"academy_monthly_cumulative_201507-202309.json", "w")
my_file5.write(json.dumps(cumulative_data, indent=4)) # !!!!!borrowed part of a line of code from Prof example
my_file5.close()
print("Finished cumulative data")
# Out:
# ------ Added 1: Everything Everywhere All at Once ----------
# ------ Added 2: All Quiet on the Western Front (2022 film) ----------
# ------ Added 3: The Whale (2022 film) ----------
# ------ Added 4: Top Gun: Maverick ----------
# ------ Added 5: Black Panther: Wakanda Forever ----------
# ------ Added 6: Avatar: The Way of Water ----------
# ------ Added 7: Women Talking (film) ----------
# ------ Added 8: Guillermo del Toro's Pinocchio ----------
# ------ Added 9: Navalny (film) ----------
# ------ Added 10: The Elephant Whisperers ----------
# ------ Added 11: An Irish Goodbye ----------
# ------ Added 12: The Boy, the Mole, the Fox and the Horse (film) ----------
# ------ Added 13: RRR (film) ----------
# ------ Added 14: CODA (2021 film) ----------
# ------ Added 15: Dune (2021 film) ----------
# ------ Added 16: The Eyes of Tammy Faye (2021 film) ----------
# ------ Added 17: No Time to Die ----------
# ------ Added 18: The Windshield Wiper ----------
# ------ Added 19: The Long Goodbye (Riz Ahmed album) ----------
# ------ Added 20: The Queen of Basketball ----------
# ------ Added 21: Summer of Soul ----------
# ------ Added 22: Drive My Car (film) ----------
# ------ Added 23: Encanto ----------
# ------ Added 24: West Side Story (2021 film) ----------
# ------ Added 25: Belfast (film) ----------
# ------ Added 26: The Power of the Dog (film) ----------
# ------ Added 27: King Richard (film) ----------
# ------ Added 28: Cruella (film) ----------
# ------ Added 29: Nomadland (film) ----------
# ------ Added 30: The Father (2020 film) ----------
# ------ Added 31: Judas and the Black Messiah ----------
# ------ Added 32: Minari (film) ----------
# ------ Added 33: Mank ----------
# ------ Added 34: Sound of Metal ----------
# ------ Added 35: Ma Rainey's Black Bottom (film) ----------
# ------ Added 36: Promising Young Woman ----------
# ------ Added 37: Tenet (film) ----------
# ------ Added 38: Soul (2020 film) ----------
# ------ Added 39: Another Round (film) ----------
# ------ Added 40: My Octopus Teacher ----------
# ------ Added 41: Colette (2020 film) ----------
# ------ Added 42: If Anything Happens I Love You ----------
# ------ Added 43: Two Distant Strangers ----------
# ------ Added 44: Parasite (2019 film) ----------
# ------ Added 45: Ford v Ferrari ----------
# ------ Added 46: Learning to Skateboard in a Warzone (If You're a Girl) ----------
# ------ Added 47: The Neighbors' Window ----------
# ------ Added 48: Little Women (2019 film) ----------
# ------ Added 49: Marriage Story ----------
# ------ Added 50: Jojo Rabbit ----------
# ------ Added 51: Toy Story 4 ----------
# ------ Added 52: Joker (2019 film) ----------
# ------ Added 53: Once Upon a Time in Hollywood ----------
# ------ Added 54: 1917 (2019 film) ----------
# ------ Added 55: Judy (film) ----------
# ------ Added 56: Bombshell (2019 film) ----------
# ------ Added 57: Rocketman (film) ----------
# ------ Added 58: American Factory ----------
# ------ Added 59: Hair Love ----------
# ------ Added 60: Green Book (film) ----------
# ------ Added 61: Bohemian Rhapsody (film) ----------
# ------ Added 62: Roma (2018 film) ----------
# ------ Added 63: Black Panther (film) ----------
# ------ Added 64: The Favourite ----------
# ------ Added 65: A Star Is Born (2018 film) ----------
# ------ Added 66: Vice (2018 film) ----------
# ------ Added 67: BlacKkKlansman ----------
# ------ Added 68: First Man (film) ----------
# ------ Added 69: If Beale Street Could Talk (film) ----------
# ------ Added 70: Bao (film) ----------
# ------ Added 71: Free Solo ----------
# ------ Added 72: Period. End of Sentence. ----------
# ------ Added 73: Skin (2018 short film) ----------
# ------ Added 74: Spider-Man: Into the Spider-Verse ----------
# ------ Added 75: The Shape of Water ----------
# ------ Added 76: Dunkirk (2017 film) ----------
# ------ Added 77: Three Billboards Outside Ebbing, Missouri ----------
# ------ Added 78: Darkest Hour (film) ----------
# ------ Added 79: Blade Runner 2049 ----------
# ------ Added 80: Coco (2017 film) ----------
# ------ Added 81: Phantom Thread ----------
# ------ Added 82: Call Me by Your Name (film) ----------
# ------ Added 83: Get Out ----------
# ------ Added 84: I, Tonya ----------
# ------ Added 85: Dear Basketball ----------
# ------ Added 86: A Fantastic Woman ----------
# ------ Added 87: Heaven Is a Traffic Jam on the 405 ----------
# ------ Added 88: Icarus (2017 film) ----------
# ------ Added 89: The Silent Child ----------
# ------ Added 90: Flesh and Sand ----------
# ------ Added 91: Moonlight (2016 film) ----------
# ------ Added 92: La La Land (film) ----------
# ------ Added 93: Hacksaw Ridge ----------
# ------ Added 94: Manchester by the Sea (film) ----------
# ------ Added 95: Arrival (film) ----------
# ------ Added 96: Fences (film) ----------
# ------ Added 97: Fantastic Beasts and Where to Find Them (film) ----------
# ------ Added 98: The Jungle Book (2016 film) ----------
# ------ Added 99: O.J.: Made in America ----------
# ------ Added 100: Piper (film) ----------
# ------ Added 101: The Salesman (2016 film) ----------
# ------ Added 102: Sing (2016 Hungarian film) ----------
# ------ Added 103: Suicide Squad (2016 film) ----------
# ------ Added 104: The White Helmets (film) ----------
# ------ Added 105: Zootopia ----------
# ------ Added 106: Spotlight (film) ----------
# ------ Added 107: Mad Max: Fury Road ----------
# ------ Added 108: The Revenant (2015 film) ----------
# ------ Added 109: Bridge of Spies (film) ----------
# ------ Added 110: The Big Short (film) ----------
# ------ Added 111: The Danish Girl (film) ----------
# ------ Added 112: Room (2015 film) ----------
# ------ Added 113: The Hateful Eight ----------
# ------ Added 114: Ex Machina (film) ----------
# ------ Added 115: Inside Out (2015 film) ----------
# ------ Added 116: Amy (2015 film) ----------
# ------ Added 117: Bear Story ----------
# ------ Added 118: A Girl in the River: The Price of Forgiveness ----------
# ------ Added 119: Son of Saul ----------
# ------ Added 120: Spectre (2015 film) ----------
# ------ Added 121: Stutterer (film) ----------
# ------ Added 122: Birdman (film) ----------
# ------ Added 123: The Grand Budapest Hotel ----------
# ------ Added 124: Whiplash (2014 film) ----------
# ------ Added 125: The Imitation Game ----------
# ------ Added 126: American Sniper ----------
# ------ Added 127: Boyhood (2014 film) ----------
# ------ Added 128: Interstellar (film) ----------
# ------ Added 129: The Theory of Everything (2014 film) ----------
# ------ Added 130: Ida (film) ----------
# ------ Added 131: Selma (film) ----------
# ------ Added 132: Citizenfour ----------
# ------ Added 133: Big Hero 6 (film) ----------
# ------ Added 134: Crisis Hotline: Veterans Press 1 ----------
# ------ Added 135: The Phone Call (2013 film) ----------
# ------ Added 136: Still Alice ----------
# ------ Added 137: Feast (2014 film) ----------
# ------ Added 138: 12 Years a Slave (film) ----------
# ------ Added 139: Gravity (2013 film) ----------
# ------ Added 140: Dallas Buyers Club ----------
# ------ Added 141: Frozen (2013 film) ----------
# ------ Added 142: The Great Gatsby (2013 film) ----------
# ------ Added 143: Her (film) ----------
# ------ Added 144: Blue Jasmine ----------
# ------ Added 145: Mr Hublot ----------
# ------ Added 146: The Lady in Number 6 ----------
# ------ Added 147: Helium (film) ----------
# ------ Added 148: The Great Beauty ----------
# ------ Added 149: 20 Feet from Stardom ----------
# ------ Added 150: Argo (2012 film) ----------
# ------ Added 151: Life of Pi (film) ----------
# ------ Added 152: Les Misérables (2012 film) ----------
# ------ Added 153: Lincoln (film) ----------
# ------ Added 154: Django Unchained ----------
# ------ Added 155: Skyfall ----------
# ------ Added 156: Silver Linings Playbook ----------
# ------ Added 157: Zero Dark Thirty ----------
# ------ Added 158: Amour (2012 film) ----------
# ------ Added 159: Anna Karenina (2012 film) ----------
# ------ Added 160: Paperman ----------
# ------ Added 161: Brave (2012 film) ----------
# ------ Added 162: Searching for Sugar Man ----------
# ------ Added 163: Inocente ----------
# ------ Added 164: Curfew (2012 film) ----------
# ------ Added 165: The Artist (film) ----------
# ------ Added 166: Hugo (film) ----------
# ------ Added 167: The Iron Lady (film) ----------
# ------ Added 168: The Descendants ----------
# ------ Added 169: The Girl with the Dragon Tattoo (2011 film) ----------
# ------ Added 170: Midnight in Paris ----------
# ------ Added 171: The Help (film) ----------
# ------ Added 172: A Separation ----------
# ------ Added 173: The Fantastic Flying Books of Mr. Morris Lessmore ----------
# ------ Added 174: The Shore (2011 film) ----------
# ------ Added 175: Undefeated (2011 film) ----------
# ------ Added 176: The Muppets (film) ----------
# ------ Added 177: Saving Face (2012 film) ----------
# ------ Added 178: Beginners ----------
# ------ Added 179: Rango (2011 film) ----------
# ------ Added 180: The King's Speech ----------
# ------ Added 181: Inception ----------
# ------ Added 182: The Social Network ----------
# ------ Added 183: The Fighter ----------
# ------ Added 184: Toy Story 3 ----------
# ------ Added 185: Alice in Wonderland (2010 film) ----------
# ------ Added 186: Black Swan (film) ----------
# ------ Added 187: In a Better World ----------
# ------ Added 188: The Lost Thing ----------
# ------ Added 189: God of Love (film) ----------
# ------ Added 190: The Wolfman (2010 film) ----------
# ------ Added 191: Strangers No More ----------
# ------ Added 192: Inside Job (2010 film) ----------
# ------ Added 193: The Hurt Locker ----------
# ------ Added 194: Avatar (2009 film) ----------
# ------ Added 195: Precious (film) ----------
# ------ Added 196: Up (2009 film) ----------
# ------ Added 197: Crazy Heart ----------
# ------ Added 198: Inglourious Basterds ----------
# ------ Added 199: Star Trek (film) ----------
# ------ Added 200: The Young Victoria ----------
# ------ Added 201: The Blind Side (film) ----------
# ------ Added 202: Music by Prudence ----------
# ------ Added 203: The Secret in Their Eyes ----------
# ------ Added 204: The Cove (film) ----------
# ------ Added 205: The New Tenants ----------
# ------ Added 206: Logorama ----------
# ------ Added 207: Slumdog Millionaire ----------
# ------ Added 208: The Curious Case of Benjamin Button (film) ----------
# ------ Added 209: Milk (2008 American film) ----------
# ------ Added 210: The Dark Knight (film) ----------
# ------ Added 211: WALL-E ----------
# ------ Added 212: The Reader (2008 film) ----------
# ------ Added 213: The Duchess (film) ----------
# ------ Added 214: Departures (2008 film) ----------
# ------ Added 215: Vicky Cristina Barcelona ----------
# ------ Added 216: Smile Pinki ----------
# ------ Added 217: Man on Wire ----------
# ------ Added 218: Toyland (film) ----------
# ------ Added 219: La Maison en Petits Cubes ----------
# ------ Added 220: No Country for Old Men (film) ----------
# ------ Added 221: The Bourne Ultimatum (film) ----------
# ------ Added 222: There Will Be Blood ----------
# ------ Added 223: La Vie en rose (film) ----------
# ------ Added 224: Atonement (2007 film) ----------
# ------ Added 225: Michael Clayton (film) ----------
# ------ Added 226: Ratatouille (film) ----------
# ------ Added 227: Juno (film) ----------
# ------ Added 228: Sweeney Todd: The Demon Barber of Fleet Street (2007 film) ----------
# ------ Added 229: The Golden Compass (film) ----------
# ------ Added 230: Elizabeth: The Golden Age ----------
# ------ Added 231: Taxi to the Dark Side ----------
# ------ Added 232: Peter & the Wolf (2006 film) ----------
# ------ Added 233: Once (film) ----------
# ------ Added 234: Le Mozart des pickpockets ----------
# ------ Added 235: The Counterfeiters (2007 film) ----------
# ------ Added 236: Freeheld (2007 film) ----------
# ------ Added 237: The Departed ----------
# ------ Added 238: Pan's Labyrinth ----------
# ------ Added 239: Dreamgirls (film) ----------
# ------ Added 240: Little Miss Sunshine ----------
# ------ Added 241: An Inconvenient Truth ----------
# ------ Added 242: Babel (film) ----------
# ------ Added 243: The Queen (2006 film) ----------
# ------ Added 244: Letters from Iwo Jima ----------
# ------ Added 245: Pirates of the Caribbean: Dead Man's Chest ----------
# ------ Added 246: The Danish Poet ----------
# ------ Added 247: Happy Feet ----------
# ------ Added 248: The Last King of Scotland (film) ----------
# ------ Added 249: The Lives of Others ----------
# ------ Added 250: Marie Antoinette (2006 film) ----------
# ------ Added 251: West Bank Story ----------
# ------ Added 252: The Blood of Yingzhou District ----------
# ------ Added 253: Crash (2004 film) ----------
# ------ Added 254: Brokeback Mountain ----------
# ------ Added 255: Memoirs of a Geisha (film) ----------
# ------ Added 256: King Kong (2005 film) ----------
# ------ Added 257: Capote (film) ----------
# ------ Added 258: Walk the Line ----------
# ------ Added 259: The Constant Gardener (film) ----------
# ------ Added 260: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe ----------
# ------ Added 261: Hustle & Flow ----------
# ------ Added 262: Syriana ----------
# ------ Added 263: March of the Penguins ----------
# ------ Added 264: Six Shooter (film) ----------
# ------ Added 265: The Moon and the Son: An Imagined Conversation ----------
# ------ Added 266: A Note of Triumph: The Golden Age of Norman Corwin ----------
# ------ Added 267: Tsotsi ----------
# ------ Added 268: Wallace & Gromit: The Curse of the Were-Rabbit ----------
# ------ Added 269: Million Dollar Baby ----------
# ------ Added 270: The Aviator (2004 film) ----------
# ------ Added 271: Ray (film) ----------
# ------ Added 272: The Incredibles ----------
# ------ Added 273: Finding Neverland (film) ----------
# ------ Added 274: Sideways ----------
# ------ Added 275: Lemony Snicket's A Series of Unfortunate Events ----------
# ------ Added 276: Spider-Man 2 ----------
# ------ Added 277: Eternal Sunshine of the Spotless Mind ----------
# ------ Added 278: The Motorcycle Diaries (film) ----------
# ------ Added 279: The Sea Inside ----------
# ------ Added 280: Born into Brothels ----------
# ------ Added 281: Mighty Times: The Children's March ----------
# ------ Added 282: Wasp (2003 film) ----------
# ------ Added 283: Ryan (film) ----------
# ------ Added 284: The Lord of the Rings: The Return of the King ----------
# ------ Added 285: Master and Commander: The Far Side of the World ----------
# ------ Added 286: Mystic River (film) ----------
# ------ Added 287: Cold Mountain (film) ----------
# ------ Added 288: Lost in Translation (film) ----------
# ------ Added 289: Finding Nemo ----------
# ------ Added 290: The Barbarian Invasions ----------
# ------ Added 291: Two Soldiers (2003 film) ----------
# ------ Added 292: Monster (2003 film) ----------
# ------ Added 293: Harvie Krumpet ----------
# ------ Added 294: Chernobyl Heart ----------
# ------ Added 295: The Fog of War ----------
# ------ Added 296: Chicago (2002 film) ----------
# ------ Added 297: The Pianist (2002 film) ----------
# ------ Added 298: The Lord of the Rings: The Two Towers ----------
# ------ Added 299: Frida (film) ----------
# ------ Added 300: The Hours (film) ----------
# ------ Added 301: Road to Perdition ----------
# ------ Added 302: Adaptation (film) ----------
# ------ Added 303: Talk to Her ----------
# ------ Added 304: This Charming Man (film) ----------
# ------ Added 305: Spirited Away ----------
# ------ Added 306: Nowhere in Africa ----------
# ------ Added 307: The ChubbChubbs! ----------
# ------ Added 308: Twin Towers (film) ----------
# ------ Added 309: Bowling for Columbine ----------
# ------ Added 310: 8 Mile (film) ----------
# ------ Added 311: A Beautiful Mind (film) ----------
# ------ Added 312: The Lord of the Rings: The Fellowship of the Ring ----------
# ------ Added 313: Moulin Rouge! ----------
# ------ Added 314: Black Hawk Down (film) ----------
# ------ Added 315: Gosford Park ----------
# ------ Added 316: Monsters, Inc. ----------
# ------ Added 317: Pearl Harbor (film) ----------
# ------ Added 318: Iris (2001 film) ----------
# ------ Added 319: Shrek ----------
# ------ Added 320: Training Day ----------
# ------ Added 321: Monster's Ball ----------
# ------ Added 322: Thoth (film) ----------
# ------ Added 323: For the Birds (film) ----------
# ------ Added 324: No Man's Land (2001 film) ----------
# ------ Added 325: Murder on a Sunday Morning ----------
# ------ Added 326: The Accountant (2001 film) ----------
# ------ Added 327: Gladiator (2000 film) ----------
# ------ Added 328: Crouching Tiger, Hidden Dragon ----------
# ------ Added 329: Traffic (2000 film) ----------
# ------ Added 330: Erin Brockovich (film) ----------
# ------ Added 331: Almost Famous ----------
# ------ Added 332: Wonder Boys (film) ----------
# ------ Added 333: How the Grinch Stole Christmas (2000 film) ----------
# ------ Added 334: U-571 (film) ----------
# ------ Added 335: Pollock (film) ----------
# ------ Added 336: Father and Daughter (film) ----------
# ------ Added 337: Into the Arms of Strangers: Stories of the Kindertransport ----------
# ------ Added 338: Quiero ser (I want to be...) ----------
# ------ Added 339: Big Mama (film) ----------
# ------ Added 340: American Beauty (1999 film) ----------
# ------ Added 341: The Matrix ----------
# ------ Added 342: The Cider House Rules (film) ----------
# ------ Added 343: Topsy-Turvy ----------
# ------ Added 344: Sleepy Hollow (film) ----------
# ------ Added 345: Boys Don't Cry (1999 film) ----------
# ------ Added 346: Tarzan (1999 film) ----------
# ------ Added 347: One Day in September ----------
# ------ Added 348: The Red Violin ----------
# ------ Added 349: The Old Man and the Sea (1999 film) ----------
# ------ Added 350: My Mother Dreams the Satan's Disciples in New York ----------
# ------ Added 351: King Gimp ----------
# ------ Added 352: Girl, Interrupted (film) ----------
# ------ Added 353: All About My Mother ----------
# ------ Added 354: Shakespeare in Love ----------
# ------ Added 355: Saving Private Ryan ----------
# ------ Added 356: Life Is Beautiful ----------
# ------ Added 357: Elizabeth (film) ----------
# ------ Added 358: Gods and Monsters (film) ----------
# ------ Added 359: The Prince of Egypt ----------
# ------ Added 360: Affliction (1997 film) ----------
# ------ Added 361: What Dreams May Come (film) ----------
# ------ Added 362: The Personals: Improvisations on Romance in the Golden Years ----------
# ------ Added 363: The Last Days ----------
# ------ Added 364: Election Night (1998 film) ----------
# ------ Added 365: Bunny (1998 film) ----------
# ------ Added 366: Titanic (1997 film) ----------
# ------ Added 367: Good Will Hunting ----------
# ------ Added 368: L.A. Confidential (film) ----------
# ------ Added 369: As Good as It Gets ----------
# ------ Added 370: The Full Monty ----------
# ------ Added 371: Men in Black (1997 film) ----------
# ------ Added 372: Visas and Virtue ----------
# ------ Added 373: Character (film) ----------
# ------ Added 374: Geri's Game ----------
# ------ Added 375: A Story of Healing ----------
# ------ Added 376: The Long Way Home (1997 film) ----------
# ------ Added 377: The English Patient (film) ----------
# ------ Added 378: Fargo (1996 film) ----------
# ------ Added 379: Shine (film) ----------
# ------ Added 380: Evita (1996 film) ----------
# ------ Added 381: Jerry Maguire ----------
# ------ Added 382: Independence Day (1996 film) ----------
# ------ Added 383: Emma (1996 theatrical film) ----------
# ------ Added 384: Sling Blade (film) ----------
# ------ Added 385: The Ghost and the Darkness ----------
# ------ Added 386: Kolya ----------
# ------ Added 387: The Nutty Professor (1996 film) ----------
# ------ Added 388: Quest (1996 film) ----------
# ------ Added 389: When We Were Kings ----------
# ------ Added 390: Breathing Lessons: The Life and Work of Mark O'Brien ----------
# ------ Added 391: Dear Diary (1996 film) ----------
# ------ Added 392: Braveheart ----------
# ------ Added 393: Apollo 13 (film) ----------
# ------ Added 394: Pocahontas (1995 film) ----------
# ------ Added 395: The Usual Suspects ----------
# ------ Added 396: Restoration (1995 film) ----------
# ------ Added 397: Babe (film) ----------
# ------ Added 398: Sense and Sensibility (film) ----------
# ------ Added 399: Il Postino: The Postman ----------
# ------ Added 400: Dead Man Walking (film) ----------
# ------ Added 401: Leaving Las Vegas ----------
# ------ Added 402: Mighty Aphrodite ----------
# ------ Added 403: Anne Frank Remembered ----------
# ------ Added 404: A Close Shave ----------
# ------ Added 405: Lieberman in Love ----------
# ------ Added 406: One Survivor Remembers ----------
# ------ Added 407: Antonia's Line ----------
# ------ Added 408: Toy Story ----------
# ------ Added 409: Forrest Gump ----------
# ------ Added 410: The Lion King ----------
# ------ Added 411: Speed (1994 film) ----------
# ------ Added 412: Ed Wood (film) ----------
# ------ Added 413: Pulp Fiction ----------
# ------ Added 414: Bullets Over Broadway ----------
# ------ Added 415: The Madness of King George ----------
# ------ Added 416: Legends of the Fall ----------
# ------ Added 417: A Time for Justice ----------
# ------ Added 418: Franz Kafka's It's a Wonderful Life ----------
# ------ Added 419: Maya Lin: A Strong Clear Vision ----------
# ------ Added 420: Burnt by the Sun ----------
# ------ Added 421: Trevor (film) ----------
# ------ Added 422: The Adventures of Priscilla, Queen of the Desert ----------
# ------ Added 423: Bob's Birthday ----------
# ------ Added 424: Blue Sky (1994 film) ----------
# ------ Added 425: Schindler's List ----------
# ------ Added 426: The Piano ----------
# ------ Added 427: Jurassic Park (film) ----------
# ------ Added 428: Philadelphia (film) ----------
# ------ Added 429: The Fugitive (1993 film) ----------
# ------ Added 430: The Age of Innocence (1993 film) ----------
# ------ Added 431: The Wrong Trousers ----------
# ------ Added 432: Belle Epoque (film) ----------
# ------ Added 433: I Am a Promise: The Children of Stanton Elementary School ----------
# ------ Added 434: Mrs. Doubtfire ----------
# ------ Added 435: Schwarzfahrer ----------
# ------ Added 436: Defending Our Lives ----------
# ------ Added 437: Unforgiven ----------
# ------ Added 438: Howards End (film) ----------
# ------ Added 439: Bram Stoker's Dracula (1992 film) ----------
# ------ Added 440: Aladdin (1992 Disney film) ----------
# ------ Added 441: The Crying Game ----------
# ------ Added 442: Scent of a Woman (1992 film) ----------
# ------ Added 443: A River Runs Through It (film) ----------
# ------ Added 444: Indochine (film) ----------
# ------ Added 445: My Cousin Vinny ----------
# ------ Added 446: The Panama Deception ----------
# ------ Added 447: Educating Peter ----------
# ------ Added 448: The Last of the Mohicans (1992 film) ----------
# ------ Added 449: Death Becomes Her ----------
# ------ Added 450: Omnibus (film) ----------
# ------ Added 451: Mona Lisa Descending a Staircase ----------
# ------ Added 452: The Silence of the Lambs (film) ----------
# ------ Added 453: Terminator 2: Judgment Day ----------
# ------ Added 454: Bugsy ----------
# ------ Added 455: JFK (film) ----------
# ------ Added 456: Beauty and the Beast (1991 film) ----------
# ------ Added 457: Thelma & Louise ----------
# ------ Added 458: The Fisher King ----------
# ------ Added 459: In the Shadow of the Stars ----------
# ------ Added 460: Manipulation (film) ----------
# ------ Added 461: Mediterraneo ----------
# ------ Added 462: Session Man (film) ----------
# ------ Added 463: City Slickers ----------
# ------ Added 464: Deadly Deception: General Electric, Nuclear Weapons and Our Environment ----------
# ------ Added 465: Dances with Wolves ----------
# ------ Added 466: Dick Tracy (1990 film) ----------
# ------ Added 467: Ghost (1990 film) ----------
# ------ Added 468: Goodfellas ----------
# ------ Added 469: The Hunt for Red October (film) ----------
# ------ Added 470: Reversal of Fortune ----------
# ------ Added 471: Cyrano de Bergerac (1990 film) ----------
# ------ Added 472: American Dream (film) ----------
# ------ Added 473: Journey of Hope (film) ----------
# ------ Added 474: Days of Waiting: The Life & Art of Estelle Ishigo ----------
# ------ Added 475: Creature Comforts ----------
# ------ Added 476: The Lunch Date ----------
# ------ Added 477: Misery (film) ----------
# ------ Added 478: Total Recall (1990 film) ----------
# ------ Added 479: Driving Miss Daisy ----------
# ------ Added 480: Glory (1989 film) ----------
# ------ Added 481: Born on the Fourth of July (film) ----------
# ------ Added 482: My Left Foot ----------
# ------ Added 483: The Little Mermaid (1989 film) ----------
# ------ Added 484: Dead Poets Society ----------
# ------ Added 485: The Abyss ----------
# ------ Added 486: Indiana Jones and the Last Crusade ----------
# ------ Added 487: Henry V (1989 film) ----------
# ------ Added 488: The Johnstown Flood (1989 film) ----------
# ------ Added 489: Common Threads: Stories from the Quilt ----------
# ------ Added 490: Cinema Paradiso ----------
# ------ Added 491: Work Experience (film) ----------
# ------ Added 492: Batman (1989 film) ----------
# ------ Added 493: Balance (1989 film) ----------
# ------ Added 494: Rain Man ----------
# ------ Added 495: Dangerous Liaisons ----------
# ------ Added 496: Who Framed Roger Rabbit ----------
# ------ Added 497: Mississippi Burning ----------
# ------ Added 498: Working Girl ----------
# ------ Added 499: The Accidental Tourist (film) ----------
# ------ Added 500: A Fish Called Wanda ----------
# ------ Added 501: Pelle the Conqueror ----------
# ------ Added 502: The Accused (1988 film) ----------
# ------ Added 503: The Appointments of Dennis Jennings ----------
# ------ Added 504: Beetlejuice ----------
# ------ Added 505: Bird (1988 film) ----------
# ------ Added 506: Hôtel Terminus: The Life and Times of Klaus Barbie ----------
# ------ Added 507: The Milagro Beanfield War ----------
# ------ Added 508: Tin Toy ----------
# ------ Added 509: You Don't Have to Die ----------
# ------ Added 510: The Last Emperor ----------
# ------ Added 511: Moonstruck ----------
# ------ Added 512: The Untouchables (film) ----------
# ------ Added 513: Babette's Feast ----------
# ------ Added 514: Dirty Dancing ----------
# ------ Added 515: Harry and the Hendersons ----------
# ------ Added 516: Innerspace ----------
# ------ Added 517: The Man Who Planted Trees (film) ----------
# ------ Added 518: Ray's Male Heterosexual Dance Hall ----------
# ------ Added 519: The Ten-Year Lunch ----------
# ------ Added 520: Wall Street (1987 film) ----------
# ------ Added 521: Young at Heart (1987 film) ----------
# ------ Added 522: RoboCop ----------
# ------ Added 523: Platoon (film) ----------
# ------ Added 524: A Room with a View (1985 film) ----------
# ------ Added 525: Hannah and Her Sisters ----------
# ------ Added 526: Aliens (film) ----------
# ------ Added 527: The Mission (1986 film) ----------
# ------ Added 528: Children of a Lesser God (film) ----------
# ------ Added 529: The Color of Money ----------
# ------ Added 530: Top Gun ----------
# ------ Added 531: Round Midnight (film) ----------
# ------ Added 532: Artie Shaw: Time Is All You've Got ----------
# ------ Added 533: The Assault (1986 film) ----------
# ------ Added 534: Down and Out in America ----------
# ------ Added 535: The Fly (1986 film) ----------
# ------ Added 536: A Greek Tragedy ----------
# ------ Added 537: Precious Images ----------
# ------ Added 538: Women – for America, for the World ----------
# ------ Added 539: Out of Africa (film) ----------
# ------ Added 540: Witness (1985 film) ----------
# ------ Added 541: Cocoon (film) ----------
# ------ Added 542: Prizzi's Honor ----------
# ------ Added 543: Back to the Future ----------
# ------ Added 544: Kiss of the Spider Woman (film) ----------
# ------ Added 545: Ran (film) ----------
# ------ Added 546: The Official Story ----------
# ------ Added 547: The Trip to Bountiful ----------
# ------ Added 548: White Nights (1985 film) ----------
# ------ Added 549: Anna & Bella ----------
# ------ Added 550: Broken Rainbow (film) ----------
# ------ Added 551: Mask (1985 film) ----------
# ------ Added 552: Molly's Pilgrim ----------
# ------ Added 553: Witness to War: Dr. Charlie Clements ----------
# ------ Added 554: Amadeus (film) ----------
# ------ Added 555: The Killing Fields (film) ----------
# ------ Added 556: A Passage to India (film) ----------
# ------ Added 557: Places in the Heart ----------
# ------ Added 558: Indiana Jones and the Temple of Doom ----------
# ------ Added 559: Charade (1984 film) ----------
# ------ Added 560: Dangerous Moves ----------
# ------ Added 561: Purple Rain (film) ----------
# ------ Added 562: The Stone Carvers (film) ----------
# ------ Added 563: The Times of Harvey Milk ----------
# ------ Added 564: Up (1984 film) ----------
# ------ Added 565: The Woman in Red (1984 film) ----------
# ------ Added 566: The River (1984 film) ----------
# ------ Added 567: Terms of Endearment ----------
# ------ Added 568: The Right Stuff (film) ----------
# ------ Added 569: Fanny and Alexander ----------
# ------ Added 570: Tender Mercies ----------
# ------ Added 571: Yentl (film) ----------
# ------ Added 572: Flashdance ----------
# ------ Added 573: Boys and Girls (1983 film) ----------
# ------ Added 574: Flamenco at 5:15 ----------
# ------ Added 575: He Makes Me Feel Like Dancin' ----------
# ------ Added 576: Sundae in New York ----------
# ------ Added 577: The Year of Living Dangerously (film) ----------
# ------ Added 578: Return of the Jedi ----------
# ------ Added 579: Gandhi (film) ----------
# ------ Added 580: E.T. the Extra-Terrestrial ----------
# ------ Added 581: An Officer and a Gentleman ----------
# ------ Added 582: Tootsie ----------
# ------ Added 583: Sophie's Choice (film) ----------
# ------ Added 584: Missing (1982 film) ----------
# ------ Added 585: If You Love This Planet ----------
# ------ Added 586: Just Another Missing Kid ----------
# ------ Added 587: A Shocking Accident ----------
# ------ Added 588: Tango (1981 film) ----------
# ------ Added 589: Begin the Beguine (film) ----------
# ------ Added 590: Quest for Fire (film) ----------
# ------ Added 591: Chariots of Fire ----------
# ------ Added 592: Raiders of the Lost Ark ----------
# ------ Added 593: Reds (film) ----------
# ------ Added 594: On Golden Pond (1981 film) ----------
# ------ Added 595: Arthur (1981 film) ----------
# ------ Added 596: An American Werewolf in London ----------
# ------ Added 597: Close Harmony (1981 film) ----------
# ------ Added 598: Crac ----------
# ------ Added 599: Genocide (1981 film) ----------
# ------ Added 600: Mephisto (1981 film) ----------
# ------ Added 601: Violet (1981 film) ----------
# ------ Added 602: Ordinary People ----------
# ------ Added 603: Tess (1979 film) ----------
# ------ Added 604: Raging Bull ----------
# ------ Added 605: Fame (1980 film) ----------
# ------ Added 606: Melvin and Howard ----------
# ------ Added 607: Coal Miner's Daughter (film) ----------
# ------ Added 608: The Empire Strikes Back ----------
# ------ Added 609: The Dollar Bottom ----------
# ------ Added 610: The Fly (1980 film) ----------
# ------ Added 611: From Mao to Mozart: Isaac Stern in China ----------
# ------ Added 612: Karl Hess: Toward Liberty ----------
# ------ Added 613: Moscow Does Not Believe in Tears ----------
# ------ Added 614: Kramer vs. Kramer ----------
# ------ Added 615: All That Jazz (film) ----------
# ------ Added 616: Apocalypse Now ----------
# ------ Added 617: Norma Rae ----------
# ------ Added 618: Breaking Away ----------
# ------ Added 619: Alien (film) ----------
# ------ Added 620: Being There ----------
# ------ Added 621: A Little Romance ----------
# ------ Added 622: Best Boy (film) ----------
# ------ Added 623: Board and Care ----------
# ------ Added 624: Every Child (film) ----------
# ------ Added 625: Paul Robeson: Tribute to an Artist ----------
# ------ Added 626: The Tin Drum (film) ----------
# ------ Added 627: The Black Stallion (film) ----------
# ------ Added 628: The Deer Hunter ----------
# ------ Added 629: Coming Home (1978 film) ----------
# ------ Added 630: Midnight Express (film) ----------
# ------ Added 631: Heaven Can Wait (1978 film) ----------
# ------ Added 632: Days of Heaven ----------
# ------ Added 633: California Suite (film) ----------
# ------ Added 634: The Buddy Holly Story ----------
# ------ Added 635: Death on the Nile (1978 film) ----------
# ------ Added 636: The Flight of the Gossamer Condor ----------
# ------ Added 637: Get Out Your Handkerchiefs ----------
# ------ Added 638: Scared Straight! ----------
# ------ Added 639: Special Delivery (1978 film) ----------
# ------ Added 640: Teenage Father ----------
# ------ Added 641: Thank God It's Friday (film) ----------
# ------ Added 642: Superman (1978 film) ----------
# ------ Added 643: Annie Hall ----------
# ------ Added 644: Star Wars (film) ----------
# ------ Added 645: Julia (1977 film) ----------
# ------ Added 646: Close Encounters of the Third Kind ----------
# ------ Added 647: The Goodbye Girl ----------
# ------ Added 648: A Little Night Music (film) ----------
# ------ Added 649: Gravity Is My Enemy ----------
# ------ Added 650: I'll Find a Way ----------
# ------ Added 651: Madame Rosa ----------
# ------ Added 652: The Sand Castle (film) ----------
# ------ Added 653: Who Are the DeBolts? And Where Did They Get Nineteen Kids? ----------
# ------ Added 654: You Light Up My Life (film) ----------
# ------ Added 655: Rocky ----------
# ------ Added 656: Network (1976 film) ----------
# ------ Added 657: All the President's Men (film) ----------
# ------ Added 658: Bound for Glory (1976 film) ----------
# ------ Added 659: A Star Is Born (1976 film) ----------
# ------ Added 660: Fellini's Casanova ----------
# ------ Added 661: The Omen ----------
# ------ Added 662: Black and White in Color ----------
# ------ Added 663: Harlan County, USA ----------
# ------ Added 664: In the Region of Ice ----------
# ------ Added 665: Leisure (film) ----------
# ------ Added 666: Number Our Days ----------
# ------ Added 667: King Kong (1976 film) ----------
# ------ Added 668: Logan's Run (film) ----------
# ------ Added 669: One Flew Over the Cuckoo's Nest (film) ----------
# ------ Added 670: Barry Lyndon ----------
# ------ Added 671: Jaws (film) ----------
# ------ Added 672: Dog Day Afternoon ----------
# ------ Added 673: Nashville (film) ----------
# ------ Added 674: Shampoo (film) ----------
# ------ Added 675: The Sunshine Boys (1975 film) ----------
# ------ Added 676: Angel and Big Joe ----------
# ------ Added 677: Dersu Uzala (1975 film) ----------
# ------ Added 678: The End of the Game (1975 film) ----------
# ------ Added 679: Great (1975 film) ----------
# ------ Added 680: The Man Who Skied Down Everest ----------
# ------ Added 681: The Hindenburg (film) ----------
# ------ Added 682: The Godfather: Part II ----------
# ------ Added 683: The Towering Inferno ----------
# ------ Added 684: The Great Gatsby (1974 film) ----------
# ------ Added 685: Chinatown (1974 film) ----------
# ------ Added 686: Murder on the Orient Express (1974 film) ----------
# ------ Added 687: Earthquake (1974 film) ----------
# ------ Added 688: Alice Doesn't Live Here Anymore ----------
# ------ Added 689: Amarcord ----------
# ------ Added 690: Harry and Tonto ----------
# ------ Added 691: Closed Mondays ----------
# ------ Added 692: Don't (1974 film) ----------
# ------ Added 693: Hearts and Minds (film) ----------
# ------ Added 694: One-Eyed Men Are Kings ----------
# ------ Added 695: The Sting ----------
# ------ Added 696: The Exorcist (film) ----------
# ------ Added 697: The Way We Were ----------
# ------ Added 698: Cries and Whispers ----------
# ------ Added 699: A Touch of Class (film) ----------
# ------ Added 700: Day for Night (film) ----------
# ------ Added 701: Paper Moon (film) ----------
# ------ Added 702: The Paper Chase (film) ----------
# ------ Added 703: Save the Tiger ----------
# ------ Added 704: The Bolero ----------
# ------ Added 705: Frank Film ----------
# ------ Added 706: The Great American Cowboy ----------
# ------ Added 707: Princeton: A Search for Answers ----------
# ------ Added 708: The Godfather ----------
# ------ Added 709: Cabaret (1972 film) ----------
# ------ Added 710: The Poseidon Adventure (1972 film) ----------
# ------ Added 711: Travels with My Aunt (film) ----------
# ------ Added 712: Butterflies Are Free ----------
# ------ Added 713: The Candidate (1972 film) ----------
# ------ Added 714: The Discreet Charm of the Bourgeoisie ----------
# ------ Added 715: A Christmas Carol (1971 film) ----------
# ------ Added 716: Limelight (1952 film) ----------
# ------ Added 717: Marjoe ----------
# ------ Added 718: Norman Rockwell's World... An American Dream ----------
# ------ Added 719: This Tiny World ----------
# ------ Added 720: The French Connection (film) ----------
# ------ Added 721: Fiddler on the Roof (film) ----------
# ------ Added 722: The Last Picture Show ----------
# ------ Added 723: Nicholas and Alexandra ----------
# ------ Added 724: Sentinels of Silence ----------
# ------ Added 725: Bedknobs and Broomsticks ----------
# ------ Added 726: Summer of '42 ----------
# ------ Added 727: The Garden of the Finzi-Continis (film) ----------
# ------ Added 728: The Hospital ----------
# ------ Added 729: Klute ----------
# ------ Added 730: Shaft (1971 film) ----------
# ------ Added 731: The Crunch Bird ----------
# ------ Added 732: The Hellstrom Chronicle ----------
# ------ Added 733: Patton (film) ----------
# ------ Added 734: Ryan's Daughter ----------
# ------ Added 735: Airport (1970 film) ----------
# ------ Added 736: Love Story (1970 film) ----------
# ------ Added 737: MASH (film) ----------
# ------ Added 738: Tora! Tora! Tora! ----------
# ------ Added 739: Women in Love (film) ----------
# ------ Added 740: Lovers and Other Strangers ----------
# ------ Added 741: Woodstock (film) ----------
# ------ Added 742: Cromwell (film) ----------
# ------ Added 743: Investigation of a Citizen Above Suspicion ----------
# ------ Added 744: Interviews with My Lai Veterans ----------
# ------ Added 745: Is It Always Right to Be Right? ----------
# ------ Added 746: Let It Be (1970 film) ----------
# ------ Added 747: The Resurrection of Broncho Billy ----------
# ------ Added 748: Midnight Cowboy ----------
# ------ Added 749: Butch Cassidy and the Sundance Kid ----------
# ------ Added 750: Hello, Dolly! (film) ----------
# ------ Added 751: Z (1969 film) ----------
# ------ Added 752: Anne of the Thousand Days ----------
# ------ Added 753: They Shoot Horses, Don't They? (film) ----------
# ------ Added 754: Marooned (1969 film) ----------
# ------ Added 755: The Magic Machines ----------
# ------ Added 756: The Prime of Miss Jean Brodie (film) ----------
# ------ Added 757: True Grit (1969 film) ----------
# ------ Added 758: Arthur Rubinstein – The Love of Life ----------
# ------ Added 759: Cactus Flower (film) ----------
# ------ Added 760: Czechoslovakia 1968 ----------
# ------ Added 761: It's Tough to Be a Bird ----------
# ------ Added 762: Oliver! (film) ----------
# ------ Added 763: The Lion in Winter (1968 film) ----------
# ------ Added 764: Romeo and Juliet (1968 film) ----------
# ------ Added 765: Funny Girl (film) ----------
# ------ Added 766: 2001: A Space Odyssey (film) ----------
# ------ Added 767: Bullitt ----------
# ------ Added 768: The Producers (1967 film) ----------
# ------ Added 769: Rosemary's Baby (film) ----------
# ------ Added 770: The Subject Was Roses (film) ----------
# ------ Added 771: The Thomas Crown Affair (1968 film) ----------
# ------ Added 772: War and Peace (film series) ----------
# ------ Added 773: Charly ----------
# ------ Added 774: Journey into Self (1968 film) ----------
# ------ Added 775: Robert Kennedy Remembered ----------
# ------ Added 776: Why Man Creates ----------
# ------ Added 777: Winnie the Pooh and the Blustery Day ----------
# ------ Added 778: Planet of the Apes (1968 film) ----------
# ------ Added 779: In the Heat of the Night (film) ----------
# ------ Added 780: Camelot (film) ----------
# ------ Added 781: Bonnie and Clyde (film) ----------
# ------ Added 782: Guess Who's Coming to Dinner ----------
# ------ Added 783: Doctor Dolittle (1967 film) ----------
# ------ Added 784: The Graduate ----------
# ------ Added 785: Thoroughly Modern Millie ----------
# ------ Added 786: Cool Hand Luke ----------
# ------ Added 787: The Dirty Dozen ----------
# ------ Added 788: A Place to Stand (film) ----------
# ------ Added 789: The Anderson Platoon ----------
# ------ Added 790: The Box (1967 film) ----------
# ------ Added 791: Closely Watched Trains ----------
# ------ Added 792: The Redwoods ----------
# ------ Added 793: A Man for All Seasons (1966 film) ----------
# ------ Added 794: Who's Afraid of Virginia Woolf? (film) ----------
# ------ Added 795: Grand Prix (1966 film) ----------
# ------ Added 796: Fantastic Voyage ----------
# ------ Added 797: A Man and a Woman ----------
# ------ Added 798: Born Free ----------
# ------ Added 799: The Fortune Cookie ----------
# ------ Added 800: A Funny Thing Happened on the Way to the Forum (film) ----------
# ------ Added 801: A Herb Alpert and the Tijuana Brass Double Feature ----------
# ------ Added 802: The War Game ----------
# ------ Added 803: Wild Wings ----------
# ------ Added 804: A Year Toward Tomorrow ----------
# ------ Added 805: The Sound of Music (film) ----------
# ------ Added 806: Doctor Zhivago (film) ----------
# ------ Added 807: Darling (1965 film) ----------
# ------ Added 808: Ship of Fools (film) ----------
# ------ Added 809: Cat Ballou ----------
# ------ Added 810: The Great Race ----------
# ------ Added 811: A Patch of Blue ----------
# ------ Added 812: A Thousand Clowns ----------
# ------ Added 813: The Shop on Main Street ----------
# ------ Added 814: The Sandpiper ----------
# ------ Added 815: The Eleanor Roosevelt Story ----------
# ------ Added 816: To Be Alive! ----------
# ------ Added 817: 7 Faces of Dr. Lao ----------
# ------ Added 818: 7th Heaven (1927 film) ----------
# ------ Added 819: 20,000 Leagues Under the Sea (1954 film) ----------
# ------ Added 820: Adventures of Don Juan ----------
# ------ Added 821: The Adventures of Robin Hood ----------
# ------ Added 822: The African Queen (film) ----------
# ------ Added 823: Air Force (film) ----------
# ------ Added 824: The Alamo (1960 film) ----------
# ------ Added 825: The Alaskan Eskimo ----------
# ------ Added 826: Albert Schweitzer (film) ----------
# ------ Added 827: Alexander's Ragtime Band (film) ----------
# ------ Added 828: All About Eve ----------
# ------ Added 829: All Quiet on the Western Front (1930 film) ----------
# ------ Added 830: The Devil and Daniel Webster (film) ----------
# ------ Added 831: All the King's Men (1949 film) ----------
# ------ Added 832: Ama Girls ----------
# ------ Added 833: America America ----------
# ------ Added 834: An American in Paris (film) ----------
# ------ Added 835: Amphibious Fighters ----------
# ------ Added 836: Anastasia (1956 film) ----------
# ------ Added 837: Anchors Aweigh (film) ----------
# ------ Added 838: Anna and the King of Siam (film) ----------
# ------ Added 839: Annie Get Your Gun (film) ----------
# ------ Added 840: Anthony Adverse ----------
# ------ Added 841: The Apartment ----------
# ------ Added 842: Aquatic House Party ----------
# ------ Added 843: Arise, My Love ----------
# ------ Added 844: Around the World in 80 Days (1956 film) ----------
# ------ Added 845: The Awful Truth ----------
# ------ Added 846: The Bachelor and the Bobby-Soxer ----------
# ------ Added 847: The Bad and the Beautiful ----------
# ------ Added 848: Bad Girl (1931 film) ----------
# ------ Added 849: The Barefoot Contessa ----------
# ------ Added 850: The Battle of Midway (film) ----------
# ------ Added 851: Battleground (film) ----------
# ------ Added 852: Bear Country (film) ----------
# ------ Added 853: Becket (1964 film) ----------
# ------ Added 854: The Bells of St. Mary's ----------
# ------ Added 855: Ben-Hur (1959 film) ----------
# ------ Added 856: Benjy (film) ----------
# ------ Added 857: The Bespoke Overcoat ----------
# ------ Added 858: The Best Years of Our Lives ----------
# ------ Added 859: Beyond the Line of Duty ----------
# ------ Added 860: Bicycle Thieves ----------
# ------ Added 861: The Big Broadcast of 1938 ----------
# ------ Added 862: The Big Country ----------
# ------ Added 863: The Big House (1930 film) ----------
# ------ Added 864: Bill and Coo ----------
# ------ Added 865: Birds Anonymous ----------
# ------ Added 866: The Bishop's Wife ----------
# ------ Added 867: Black Fox: The Rise and Fall of Adolf Hitler ----------
# ------ Added 868: Black Narcissus ----------
# ------ Added 869: Black Orpheus ----------
# ------ Added 870: The Black Swan (film) ----------
# ------ Added 871: Blithe Spirit (1945 film) ----------
# ------ Added 872: Blood and Sand (1941 film) ----------
# ------ Added 873: Blood on the Sun ----------
# ------ Added 874: Blossoms in the Dust ----------
# ------ Added 875: Body and Soul (1947 film) ----------
# ------ Added 876: Bored of Education ----------
# ------ Added 877: Born Yesterday (1950 film) ----------
# ------ Added 878: A Boy and His Dog (1946 film) ----------
# ------ Added 879: Boys Town (film) ----------
# ------ Added 880: The Brave One (1956 film) ----------
# ------ Added 881: Breakfast at Tiffany's (film) ----------
# ------ Added 882: The Sound Barrier ----------
# ------ Added 883: The Bridge of San Luis Rey (1929 film) ----------
# ------ Added 884: The Bridge on the River Kwai ----------
# ------ Added 885: The Bridges at Toko-Ri ----------
# ------ Added 886: Broadway Melody of 1936 ----------
# ------ Added 887: The Broadway Melody ----------
# ------ Added 888: Broken Lance ----------
# ------ Added 889: Busy Little Bears ----------
# ------ Added 890: BUtterfield 8 ----------
# ------ Added 891: Calamity Jane (film) ----------
# ------ Added 892: Call Me Madam (film) ----------
# ------ Added 893: Captain Carey, U.S.A. ----------
# ------ Added 894: Captains Courageous (1937 film) ----------
# ------ Added 895: Casablanca (film) ----------
# ------ Added 896: Casals Conducts: 1964 ----------
# ------ Added 897: The Cat Concerto ----------
# ------ Added 898: Cavalcade (1933 film) ----------
# ------ Added 899: Chagall (film) ----------
# ------ Added 900: The Champ (1931 film) ----------
# ------ Added 901: Champion (1949 film) ----------
# ------ Added 902: A Chance to Live ----------
# ------ Added 903: The Charge of the Light Brigade (1936 film) ----------
# ------ Added 904: The Chicken (film) ----------
# ------ Added 905: Churchill's Island ----------
# ------ Added 906: Cimarron (1931 film) ----------
# ------ Added 907: The Circus (1928 film) ----------
# ------ Added 908: Citizen Kane ----------
# ------ Added 909: City of Wax ----------
# ------ Added 910: Cleopatra (1934 film) ----------
# ------ Added 911: Cleopatra (1963 film) ----------
# ------ Added 912: Climbing the Matterhorn ----------
# ------ Added 913: Come and Get It (1936 film) ----------
# ------ Added 914: Come Back, Little Sheba (1952 film) ----------
# ------ Added 915: Coquette (film) ----------
# ------ Added 916: The Country Cousin ----------
# ------ Added 917: The Country Girl (1954 film) ----------
# ------ Added 918: Cover Girl (film) ----------
# ------ Added 919: The Cowboy and the Lady (1938 film) ----------
# ------ Added 920: Crash Dive ----------
# ------ Added 921: Crashing the Water Barrier ----------
# ------ Added 922: The Critic (1963 film) ----------
# ------ Added 923: La Cucaracha (1934 film) ----------
# ------ Added 924: Cyrano de Bergerac (1950 film) ----------
# ------ Added 925: A Damsel in Distress (1937 film) ----------
# ------ Added 926: Dangerous (1935 film) ----------
# ------ Added 927: The Dark Angel (1935 film) ----------
# ------ Added 928: The Dawn Patrol (1930 film) ----------
# ------ Added 929: Day of the Painter ----------
# ------ Added 930: Daybreak in Udi ----------
# ------ Added 931: Days of Wine and Roses (film) ----------
# ------ Added 932: December 7th: The Movie ----------
# ------ Added 933: Declaration of Independence (film) ----------
# ------ Added 934: The Defiant Ones ----------
# ------ Added 935: Der Fuehrer's Face ----------
# ------ Added 936: Desert Victory ----------
# ------ Added 937: Design for Death ----------
# ------ Added 938: Designing Woman ----------
# ------ Added 939: Destination Moon (film) ----------
# ------ Added 940: The Diary of Anne Frank (1959 film) ----------
# ------ Added 941: Disraeli (1929 film) ----------
# ------ Added 942: The Divine Lady ----------
# ------ Added 943: Divorce Italian Style ----------
# ------ Added 944: The Divorcee ----------
# ------ Added 945: Dodsworth (film) ----------
# ...
# ------ Added 1056: Johnny Eager ----------
# ------ Added 1057: The Joker Is Wild ----------
# ------ Added 1058: The Jolson Story ----------
# ------ Added 1059: Judgment at Nuremberg ----------
# ------ Added 1060: Julius Caesar (1953 film) ----------
# ------ Added 1061: Kentucky (film) ----------
# ------ Added 1062: Key Largo (film) ----------
# ------ Added 1063: The King and I (1956 film) ----------
# ------ Added 1064: King of Jazz ----------
# ------ Added 1065: King Solomon's Mines (1950 film) ----------
# ------ Added 1066: Kitty Foyle (film) ----------
# ------ Added 1067: Knighty Knight Bugs ----------
# ------ Added 1068: Kokoda Front Line! ----------
# ------ Added 1069: Kon-Tiki (1950 film) ----------
# ------ Added 1070: Krakatoa (film) ----------
# ------ Added 1071: Kukan ----------
# ------ Added 1072: La Strada ----------
# ------ Added 1073: La Dolce Vita ----------
# ------ Added 1074: Lady Be Good (1941 film) ----------
# ------ Added 1075: The Last Command (1928 film) ----------
# ------ Added 1076: Laura (1944 film) ----------
# ------ Added 1077: The Lavender Hill Mob ----------
# ------ Added 1078: Lawrence of Arabia (film) ----------
# ------ Added 1079: Leave Her to Heaven ----------
# ------ Added 1080: Lend a Paw ----------
# ------ Added 1081: Les Girls ----------
# ------ Added 1082: A Letter to Three Wives ----------
# ------ Added 1083: The Life of Emile Zola ----------
# ------ Added 1084: Light in the Window ----------
# ------ Added 1085: Lili ----------
# ------ Added 1086: Lilies of the Field (1963 film) ----------
# ------ Added 1087: The Kidnappers ----------
# ------ Added 1088: The Little Orphan ----------
# ------ Added 1089: Little Women (1933 film) ----------
# ------ Added 1090: Little Women (1949 film) ----------
# ------ Added 1091: The Lives of a Bengal Lancer (film) ----------
# ------ Added 1092: The Living Desert ----------
# ------ Added 1093: The Longest Day (film) ----------
# ------ Added 1094: Lost Horizon (1937 film) ----------
# ------ Added 1095: The Lost Weekend (film) ----------
# ------ Added 1096: Love Is a Many-Splendored Thing (film) ----------
# ------ Added 1097: Love Me or Leave Me (film) ----------
# ------ Added 1098: Lust for Life (1956 film) ----------
# ------ Added 1099: Magoo's Puddle Jumper ----------
# ------ Added 1100: Main Street on the March! ----------
# ------ Added 1101: The Man Who Knew Too Much (1956 film) ----------
# ------ Added 1102: Manhattan Melodrama ----------
# ------ Added 1103: Marie-Louise (film) ----------
# ------ Added 1104: Marty (film) ----------
# ------ Added 1105: Mary Poppins (film) ----------
# ------ Added 1106: Men Against the Arctic ----------
# ------ Added 1107: The Merry Widow (1934 film) ----------
# ------ Added 1108: A Midsummer Night's Dream (1935 film) ----------
# ------ Added 1109: Mighty Joe Young (1949 film) ----------
# ------ Added 1110: Mildred Pierce (film) ----------
# ------ Added 1111: The Milky Way (1940 film) ----------
# ------ Added 1112: Min and Bill ----------
# ------ Added 1113: Miracle on 34th Street ----------
# ------ Added 1114: The Miracle Worker (1962 film) ----------
# ------ Added 1115: Mister Roberts (1955 film) ----------
# ------ Added 1116: Monsieur Vincent ----------
# ------ Added 1117: Moonbird ----------
# ------ Added 1118: The More the Merrier ----------
# ------ Added 1119: Morning Glory (1933 film) ----------
# ------ Added 1120: Moscow Strikes Back ----------
# ------ Added 1121: Mother Wore Tights ----------
# ------ Added 1122: Moulin Rouge (1952 film) ----------
# ------ Added 1123: Mouse Trouble ----------
# ------ Added 1124: Mr. Deeds Goes to Town ----------
# ------ Added 1125: Mr. Smith Goes to Washington ----------
# ------ Added 1126: Mrs. Miniver ----------
# ------ Added 1127: Munro (film) ----------
# ------ Added 1128: The Music Box ----------
# ------ Added 1129: The Music Man (1962 film) ----------
# ------ Added 1130: Mutiny on the Bounty (1935 film) ----------
# ------ Added 1131: My Fair Lady (film) ----------
# ------ Added 1132: Mon Oncle ----------
# ------ Added 1133: My Gal Sal ----------
# ------ Added 1134: The Naked City ----------
# ------ Added 1135: National Velvet (film) ----------
# ------ Added 1136: Nature's Half Acre ----------
# ------ Added 1137: Naughty Marietta (film) ----------
# ------ Added 1138: Neighbours (1952 film) ----------
# ------ Added 1139: Neptune's Daughter (1949 film) ----------
# ------ Added 1140: Never on Sunday ----------
# ------ Added 1141: The Night of the Iguana (film) ----------
# ------ Added 1142: Nights of Cabiria ----------
# ------ Added 1143: Nine from Little Rock ----------
# ------ Added 1144: None but the Lonely Heart (film) ----------
# ------ Added 1145: North West Mounted Police (film) ----------
# ------ Added 1146: Now, Voyager ----------
# ------ Added 1147: An Occurrence at Owl Creek Bridge (film) ----------
# ------ Added 1148: Of Pups and Puzzles ----------
# ------ Added 1149: Oklahoma! (1955 film) ----------
# ------ Added 1150: The Old Man and the Sea (1958 film) ----------
# ------ Added 1151: The Old Mill ----------
# ------ Added 1152: On the Town (film) ----------
# ------ Added 1153: On the Waterfront ----------
# ------ Added 1154: One Hundred Men and a Girl ----------
# ------ Added 1155: One Night of Love ----------
# ------ Added 1156: One Way Passage ----------
# ------ Added 1157: Overture to The Merry Wives of Windsor ----------
# ------ Added 1158: The Paleface (1948 film) ----------
# ------ Added 1159: Panic in the Streets (film) ----------
# ------ Added 1160: Papa's Delicate Condition ----------
# ------ Added 1161: The Patriot (1928 film) ----------
# ------ Added 1162: Penny Wisdom ----------
# ------ Added 1163: Phantom of the Opera (1943 film) ----------
# ------ Added 1164: The Philadelphia Story (film) ----------
# ------ Added 1165: Picnic (1955 film) ----------
# ------ Added 1166: The Picture of Dorian Gray (1945 film) ----------
# ------ Added 1167: Pillow Talk (film) ----------
# ------ Added 1168: The Pink Phink ----------
# ------ Added 1169: Pinocchio (1940 film) ----------
# ------ Added 1170: A Place in the Sun (1951 film) ----------
# ------ Added 1171: Plymouth Adventure ----------
# ------ Added 1172: Pollyanna (1960 film) ----------
# ------ Added 1173: Porgy and Bess (film) ----------
# ------ Added 1174: Portrait of Jennie ----------
# ------ Added 1175: Prelude to War ----------
# ------ Added 1176: Pride and Prejudice (1940 film) ----------
# ------ Added 1177: The Pride of the Yankees ----------
# ------ Added 1178: Princess O'Rourke ----------
# ------ Added 1179: The Private Life of Henry VIII ----------
# ------ Added 1180: The Private Life of the Gannets ----------
# ------ Added 1181: Project Hope (film) ----------
# ------ Added 1182: The Public Pays ----------
# ------ Added 1183: Pygmalion (1938 film) ----------
# ------ Added 1184: Quicker'n a Wink ----------
# ------ Added 1185: The Quiet Man ----------
# ------ Added 1186: Quiet Please! ----------
# ------ Added 1187: The Rains Came ----------
# ------ Added 1188: Rashomon ----------
# ------ Added 1189: The Razor's Edge (1946 film) ----------
# ------ Added 1190: Reap the Wild Wind ----------
# ------ Added 1191: Rebecca (1940 film) ----------
# ------ Added 1192: The Red Balloon ----------
# ------ Added 1193: The Red Shoes (1948 film) ----------
# ------ Added 1194: The Robe (film) ----------
# ------ Added 1195: Robert Frost: A Lover's Quarrel with the World ----------
# ------ Added 1196: Roman Holiday ----------
# ------ Added 1197: Room at the Top (1959 film) ----------
# ------ Added 1198: The Rose Tattoo (film) ----------
# ------ Added 1199: Sabrina (1954 film) ----------
# ------ Added 1200: Samson and Delilah (1949 film) ----------
# ------ Added 1201: Samurai I: Musashi Miyamoto ----------
# ------ Added 1202: San Francisco (1936 film) ----------
# ------ Added 1203: Sayonara ----------
# ------ Added 1204: The Scoundrel (1935 film) ----------
# ------ Added 1205: The Sea Around Us (film) ----------
# ------ Added 1206: Seal Island (film) ----------
# ------ Added 1207: The Search ----------
# ------ Added 1208: Seawards the Great Ships ----------
# ------ Added 1209: The Secret Land ----------
# ------ Added 1210: Seeds of Destiny ----------
# ------ Added 1211: Separate Tables (film) ----------
# ------ Added 1212: Serengeti Shall Not Die ----------
# ------ Added 1213: Sergeant York (film) ----------
# ------ Added 1214: Seven Brides for Seven Brothers ----------
# ------ Added 1215: Seven Days to Noon ----------
# ------ Added 1216: The Seventh Veil ----------
# ------ Added 1217: Shane (film) ----------
# ------ Added 1218: Shanghai Express (film) ----------
# ------ Added 1219: She Wore a Yellow Ribbon ----------
# ------ Added 1220: Shoeshine (film) ----------
# ------ Added 1221: The Silent World ----------
# ------ Added 1222: The Sin of Madelon Claudet ----------
# ------ Added 1223: Since You Went Away ----------
# ------ Added 1224: Skippy (film) ----------
# ------ Added 1225: Sky Above and Mud Beneath ----------
# ------ Added 1226: The Snake Pit ----------
# ------ Added 1227: Snow White and the Seven Dwarfs (1937 film) ----------
# ------ Added 1228: So Much for So Little ----------
# ------ Added 1229: So This Is Harris! ----------
# ------ Added 1230: The Solid Gold Cadillac ----------
# ------ Added 1231: Some Like It Hot ----------
# ------ Added 1232: Somebody Up There Likes Me (1956 film) ----------
# ------ Added 1233: The Song of Bernadette (film) ----------
# ------ Added 1234: Song of the South ----------
# ------ Added 1235: Song Without End ----------
# ------ Added 1236: Sons and Lovers (film) ----------
# ------ Added 1237: Sons of Liberty (film) ----------
# ------ Added 1238: South Pacific (1958 film) ----------
# ------ Added 1239: Spartacus (film) ----------
# ------ Added 1240: Spawn of the North ----------
# ------ Added 1241: Speaking of Animals and Their Families ----------
# ------ Added 1242: Speedy Gonzales (film) ----------
# ------ Added 1243: Spellbound (1945 film) ----------
# ------ Added 1244: Splendor in the Grass ----------
# ------ Added 1245: Stagecoach (1939 film) ----------
# ------ Added 1246: Stairway to Light ----------
# ------ Added 1247: Stalag 17 ----------
# ------ Added 1248: Star in the Night ----------
# ------ Added 1249: A Star Is Born (1937 film) ----------
# ------ Added 1250: State Fair (1945 film) ----------
# ------ Added 1251: The Story of Louis Pasteur ----------
# ------ Added 1252: The Stratton Story ----------
# ------ Added 1253: Street Angel (1928 film) ----------
# ------ Added 1254: A Streetcar Named Desire (1951 film) ----------
# ------ Added 1255: Strike Up the Band (film) ----------
# ------ Added 1256: Surogat ----------
# ------ Added 1257: Sundays and Cybele ----------
# ------ Added 1258: Sunrise: A Song of Two Humans ----------
# ------ Added 1259: Sunset Boulevard (film) ----------
# ------ Added 1260: Survival City ----------
# ------ Added 1261: Suspicion (1941 film) ----------
# ------ Added 1262: Sweet Bird of Youth (1962 film) ----------
# ------ Added 1263: Sweethearts (1938 film) ----------
# ------ Added 1264: Swing Time (film) ----------
# ------ Added 1265: Symphony of a City ----------
# ------ Added 1266: Tabu: A Story of the South Seas ----------
# ------ Added 1267: Target for Tonight ----------
# ------ Added 1268: Teddy, the Rough Rider ----------
# ------ Added 1269: Tempest (1928 film) ----------
# ------ Added 1270: The Ten Commandments (1956 film) ----------
# ------ Added 1271: That Hamilton Woman ----------
# ------ Added 1272: That Mothers Might Live ----------
# ------ Added 1273: The Thief of Bagdad (1940 film) ----------
# ------ Added 1274: The Third Man ----------
# ------ Added 1275: Thirty Seconds Over Tokyo ----------
# ------ Added 1276: This Above All (film) ----------
# ------ Added 1277: This Is the Army ----------
# ------ Added 1278: This Land Is Mine (film) ----------
# ------ Added 1279: This Mechanical Age ----------
# ------ Added 1280: Three Coins in the Fountain (film) ----------
# ------ Added 1281: The Three Faces of Eve ----------
# ------ Added 1282: Three Little Pigs (film) ----------
# ------ Added 1283: Three Orphan Kittens ----------
# ------ Added 1284: Through a Glass Darkly (film) ----------
# ------ Added 1285: Thunderball (film) ----------
# ------ Added 1286: Thursday's Children ----------
# ------ Added 1287: The Time Machine (1960 film) ----------
# ------ Added 1288: A Time Out of War ----------
# ------ Added 1289: Tin Pan Alley (film) ----------
# ------ Added 1290: The Titan: Story of Michelangelo ----------
# ------ Added 1291: Titanic (1953 film) ----------
# ------ Added 1292: To Catch a Thief ----------
# ------ Added 1293: To Each His Own (1946 film) ----------
# ------ Added 1294: To Kill a Mockingbird (film) ----------
# ------ Added 1295: Tom Jones (1963 film) ----------
# ------ Added 1296: Tom Thumb (film) ----------
# ------ Added 1297: Toot, Whistle, Plunk and Boom ----------
# ------ Added 1298: Topkapi (film) ----------
# ------ Added 1299: The Tortoise and the Hare (film) ----------
# ------ Added 1300: Torture Money ----------
# ------ Added 1301: Toward Independence ----------
# ------ Added 1302: Transatlantic (1931 film) ----------
# ------ Added 1303: The Treasure of the Sierra Madre (film) ----------
# ------ Added 1304: A Tree Grows in Brooklyn (1945 film) ----------
# ------ Added 1305: The True Glory ----------
# ------ Added 1306: The True Story of the Civil War ----------
# ------ Added 1307: Tweetie Pie ----------
# ------ Added 1308: Twelve O'Clock High ----------
# ------ Added 1309: Two Arabian Knights ----------
# ------ Added 1310: The Two Mouseketeers ----------
# ------ Added 1311: Two Women ----------
# ------ Added 1312: The Ugly Duckling (1939 film) ----------
# ------ Added 1313: Underworld (1927 film) ----------
# ------ Added 1314: The V.I.P.s (film) ----------
# ------ Added 1315: Perfect Strangers (1945 film) ----------
# ------ Added 1316: Van Gogh (1948 film) ----------
# ------ Added 1317: The Vanishing Prairie ----------
# ------ Added 1318: The Virgin Spring ----------
# ------ Added 1319: Viva Villa! ----------
# ------ Added 1320: Viva Zapata! ----------
# ------ Added 1321: Waikiki Wedding ----------
# ------ Added 1322: The Walls of Malapaga ----------
# ------ Added 1323: The War of the Worlds (1953 film) ----------
# ------ Added 1324: Watch on the Rhine ----------
# ------ Added 1325: Water Birds ----------
# ------ Added 1326: The Way of All Flesh (1927 film) ----------
# ------ Added 1327: West Side Story (1961 film) ----------
# ------ Added 1328: The Westerner (1940 film) ----------
# ------ Added 1329: The Wetback Hound ----------
# ------ Added 1330: What Ever Happened to Baby Jane? (1962 film) ----------
# ------ Added 1331: When Tomorrow Comes (film) ----------
# ------ Added 1332: When Magoo Flew ----------
# ------ Added 1333: When Worlds Collide (1951 film) ----------
# ------ Added 1334: White Shadows in the South Seas ----------
# ------ Added 1335: White Wilderness (film) ----------
# ------ Added 1336: Who's Who in Animal Land ----------
# ------ Added 1337: Why Korea? ----------
# ------ Added 1338: Wilson (1944 film) ----------
# ------ Added 1339: Wings (1927 film) ----------
# ------ Added 1340: Wings Over Everest ----------
# ------ Added 1341: With a Song in My Heart (film) ----------
# ------ Added 1342: With Byrd at the South Pole ----------
# ------ Added 1343: With the Marines at Tarawa ----------
# ------ Added 1344: The Wizard of Oz (1939 film) ----------
# ------ Added 1345: Woman of the Year ----------
# ------ Added 1346: Wonder Man (film) ----------
# ------ Added 1347: The Wonderful World of the Brothers Grimm ----------
# ------ Added 1348: World of Kids ----------
# ------ Added 1349: World Without Sun ----------
# ------ Added 1350: Wrestling Swordfish ----------
# ------ Added 1351: Written on the Wind ----------
# ------ Added 1352: Wuthering Heights (1939 film) ----------
# ------ Added 1353: Yankee Doodle Dandy ----------
# ------ Added 1354: The Yankee Doodle Mouse ----------
# ------ Added 1355: The Yearling (1946 film) ----------
# ------ Added 1356: Yesterday, Today and Tomorrow ----------
# ------ Added 1357: You Can't Take It with You (film) ----------
# ------ Added 1358: Zorba the Greek (film) ----------
# Finished cumulative data

# %% [markdown]
# ## Step 2: Analysis

# %% [markdown]
# **Maximum Average and Minimum Average**

# %% [markdown]
# Begin the analysis by caclulating the average monthly page requests for desktop and mobile access

# %%
# Create lists for the data: 
desktop_avgs_list = []
mobile_avgs_list = []

# Calculate the average monthly views for desktop
for title in article_names: # loop through each article
    monthly_views_list = []    
    for month in desktop_data[title]: # loop through each month
        monthly_views_list.append(month['views'])
    
    # Find avg for title: Source: https://www.geeksforgeeks.org/find-average-list-python/#
    desktop_avgs_list.append(sum(monthly_views_list) / len(monthly_views_list))

# Calculate the average monthly views for mobile
for title in article_names: # loop through each article
    monthly_views_list = []    
    for month in mobile_data[title]: # loop through each month #Source???? wouldn't have thought
        # to do for ____ in one level down without seeing it... Have to cite? Where is the line?
        monthly_views_list.append(month['views'])
    
    # Find avg for title: Source: https://www.geeksforgeeks.org/find-average-list-python/#
    mobile_avgs_list.append(sum(monthly_views_list) / len(monthly_views_list))

# %% [markdown]
# Find the miniumum and maximum averages

# %%
# Convert dictionaries to dataFrames
# Source: https://www.geeksforgeeks.org/create-a-pandas-dataframe-from-lists/
df_desktop = pd.DataFrame(list(zip(article_names, desktop_avgs_list)), columns=['Name', 'Avg_views'])
df_mobile = pd.DataFrame(list(zip(article_names, mobile_avgs_list)), columns=['Name', 'Avg_views'])

# Find the min and max values
# Source: https://www.geeksforgeeks.org/how-to-sort-pandas-dataframe/
# https://stackoverflow.com/questions/48719937/getting-typeerror-reduction-operation-argmax-not-allowed-for-this-dtype-when
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html
# https://www.geeksforgeeks.org/python-pandas-dataframe-idxmax/
# https://www.geeksforgeeks.org/find-maximum-values-position-in-columns-and-rows-of-a-dataframe-in-pandas/
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

df_desktop.sort_values(by=['Avg_views'], inplace=True) 
desktop_min_title = df_desktop.iloc[0,0]
desktop_max_title = df_desktop.iloc[-1,0]

df_mobile.sort_values(by=['Avg_views'], inplace=True)
mobile_min_title = df_mobile.iloc[0,0]
mobile_max_title = df_mobile.iloc[-1,0]

# Make lists of time-series data
desktop_min_dates = []
desktop_max_dates = []
mobile_min_dates = []
mobile_max_dates = []

desktop_min_values = []
desktop_max_values = []
mobile_min_values = []
mobile_max_values = []

for month in desktop_data[desktop_min_title]:
    desktop_min_dates.append(month['timestamp'])
    desktop_min_values.append(month['views'])
    
for month in desktop_data[desktop_max_title]:
    desktop_max_dates.append(month['timestamp'])
    desktop_max_values.append(month['views'])
    
for month in mobile_data[mobile_min_title]:
    mobile_min_dates.append(month['timestamp'])
    mobile_min_values.append(month['views'])

for month in mobile_data[mobile_max_title]:
    mobile_max_dates.append(month['timestamp'])
    mobile_max_values.append(month['views'])

# %% [markdown]
# Sources:
# - https://www.geeksforgeeks.org/line-chart-in-matplotlib-python/
# - https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/#

# %%
x = mobile_min_dates
y = mobile_min_values
plt.plot(x, y, label = 'min mobile')

x1 = mobile_max_dates
y1 = mobile_max_values
plt.plot(x1, y1, label = 'max mobile')

x2 = desktop_min_dates
y2 = desktop_min_values
plt.plot(x2, y2, label = 'min desktop')

x3 = desktop_max_dates
y3 = desktop_max_values
plt.plot(x3, y3, label = 'max desktop')

# Add legend
plt.legend()

plt.xlabel("Time")
plt.ylabel("# Monthly Views")
plt.title("Maximum Average and Minimum Average")

plt.show()

# %% [markdown]
# If I have more time worry about date formatting, else skip:
# - https://docs.python.org/3/library/datetime.html
# - https://docs.python.org/3/library/datetime.html#datetime.datetime.strptime
# - https://stackoverflow.com/questions/19934248/nameerror-name-datetime-is-not-defined
# - https://stackoverflow.com/questions/19480028/attributeerror-datetime-module-has-no-attribute-strptime

# %%
# desktop_min_dates = [datetime.datetime.strptime(e, "%Y") for e in desktop_min_dates]

# %% [markdown]
# **Top 10 Peak Page Views:**

# %% [markdown]
# Plot a time series chart for top 10 desktop and mobile pages (based on peak viewership)

# %%
# Find peak views for desktop articles
peak_desktop_article_views = []

for title in article_names:
    monthly_views_list = []
    for month in desktop_data[title]: # Loop through each month !!!! Source: can I copy my own line
        # without citing?
        monthly_views_list.append(month['views'])
    
    # Find peak month for each article. Source: https://www.geeksforgeeks.org/python-list-max-method/   
    peak_desktop_article_views.append(max(monthly_views_list))  
    
# Find peak views for mobile articles
peak_mobile_article_views = []

for title in article_names:
    monthly_views_list = []
    for month in mobile_data[title]: # Loop through each month !!!! Source: can I copy my own line
        # without citing?
        monthly_views_list.append(month['views'])
    
    # Find peak month for each article. Source: https://www.geeksforgeeks.org/python-list-max-method/   
    peak_mobile_article_views.append(max(monthly_views_list)) 
    
# Create data frames to sort and find top 10 desktop and mobile articles
# Source: https://www.geeksforgeeks.org/create-a-pandas-dataframe-from-lists/
df_desktop = pd.DataFrame(list(zip(article_names, peak_desktop_article_views)),
                          columns=['Name', 'Peak_views'])
df_mobile = pd.DataFrame(list(zip(article_names, peak_mobile_article_views)),
                         columns=['Name', 'Peak_views'])

# Find the top 10 articles for desktop and mobile
# Source: https://www.geeksforgeeks.org/how-to-sort-pandas-dataframe/
# https://stackoverflow.com/questions/48719937/getting-typeerror-reduction-operation-argmax-not-allowed-for-this-dtype-when
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html
# https://www.geeksforgeeks.org/python-pandas-dataframe-idxmax/
# https://www.geeksforgeeks.org/find-maximum-values-position-in-columns-and-rows-of-a-dataframe-in-pandas/
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

df_desktop.sort_values(by=['Peak_views'], ascending=False, inplace=True)
df_desktop_top_titles = df_desktop.iloc[0:10, 0] # Source: https://pandas.pydata.org/docs/user_guide/indexing.html
desktop_top_titles_ls = df_desktop_top_titles.tolist() # Source: https://www.geeksforgeeks.org/python-pandas-series-tolist/

df_mobile.sort_values(by=['Peak_views'], ascending=False, inplace=True)
df_mobile_top_titles = df_mobile.iloc[0:10, 0] # Source: https://pandas.pydata.org/docs/user_guide/indexing.html
mobile_top_titles_ls = df_mobile_top_titles.tolist() # Source: https://www.geeksforgeeks.org/python-pandas-series-tolist/

# Make lists of time-series data
desktop_dates_2d_ls = []
mobile_dates_2d_ls = []

desktop_values_2d_ls = []
mobile_values_2d_ls = []

# Iterate through top desktop articles
for title in desktop_top_titles_ls:
    article_views = []
    article_dates = []
    
    for month in desktop_data[title]:
        article_dates.append(month['timestamp'])
        article_views.append(month['views'])
        
    desktop_dates_2d_ls.append(article_dates)
    desktop_values_2d_ls.append(article_views)
    
# Iterate through top mobile articles
for title in mobile_top_titles_ls:
    article_dates = []
    article_views = []
    
    for month in mobile_data[title]:
        article_dates.append(month['timestamp'])
        article_views.append(month['views'])
    
    mobile_dates_2d_ls.append(article_dates)
    mobile_values_2d_ls.append(article_views)

# %% [markdown]
# Plot the data

# %%
# Plot the desktop time series data
for i in range(10):
    x = desktop_dates_2d_ls[i]
    y = desktop_values_2d_ls[i]
    article_label = desktop_top_titles_ls[i]
    plt.plot(x, y, label = article_label)

# Plot the mobile time series data
for i in range(10):
    x = mobile_dates_2d_ls[i]
    y = mobile_values_2d_ls[i]
    article_label = mobile_top_titles_ls[i]
    plt.plot(x, y, label = article_label)

# Add legend
plt.legend()

plt.xlabel("Time")
plt.ylabel("# Monthly Views")
plt.title("Top 10 Peak Page Views")

plt.show()

# %% [markdown]
# Error!!!!!!

# %%
df_desktop.head()
# Out:
#                                          Name  Peak_views
# 0           Everything Everywhere All at Once        5821
# 1  All Quiet on the Western Front (2022 film)        2752
# 2                       The Whale (2022 film)      226298
# 3                           Top Gun: Maverick         130
# 4              Black Panther: Wakanda Forever       51560

# %%
df_mobile.head()
# Out:
#                                          Name  Peak_views
# 0           Everything Everywhere All at Once     3405530
# 1  All Quiet on the Western Front (2022 film)      743310
# 2                       The Whale (2022 film)     1779836
# 3                           Top Gun: Maverick     3562193
# 4              Black Panther: Wakanda Forever     4367172

# %%
desktop_data['Black Panther: Wakanda Forever']
# Out:
# [{'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021050100',
#   'agent': 'user',
#   'views': 30262},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021060100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021070100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021080100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021090100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021100100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021110100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2021120100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022010100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022020100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022030100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022040100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022050100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022060100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022070100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022080100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022090100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022100100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022110100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2022120100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023010100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023020100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023030100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023040100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023050100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023060100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023070100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023080100',
#   'agent': 'user',
#   'views': 51560},
#  {'project': 'en.wikipedia',
#   'article': 'Black_Panther:_Wakanda_Forever',
#   'granularity': 'monthly',
#   'timestamp': '2023090100',
#   'agent': 'user',
#   'views': 51560}]

# %% [markdown]
# End of error cells

# %% [markdown]
# **Fewest Months of Data:**

# %% [markdown]
# Plot a time series chart for the 10 articles with fewest months of data for desktop access and fewest months of data for mobile access, respectively.
